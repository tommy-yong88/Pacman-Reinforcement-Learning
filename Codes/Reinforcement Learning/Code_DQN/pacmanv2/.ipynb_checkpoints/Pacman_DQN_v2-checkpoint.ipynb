# %%
from __future__ import division
import argparse

from PIL import Image
from PIL import ImageFilter
import numpy as np
import gym
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from keras.optimizers import Adam
from keras.optimizers import SGD
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

import random
from datetime import datetime
import matplotlib.pyplot as plt

INPUT_SHAPE = (88, 80)
WINDOW_LENGTH = 4
ENV_NAME = 'MsPacman-v4'
# Out:
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
#Atari Processor
class AtariProcessor(Processor):
    
    def process_observation(self, observation):
        # Crop and resize the image
        img = observation[1:176:2, ::2]
        # Convert the image to greyscale
        img = img.mean(axis=2)
        # Next we normalize the image from -1 to +1
        img = (img - 128) / 128-1
        return img.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
#Make Environment
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)
n_actions = env.action_space.n
print("Number of Actions:", n_actions)
print(env.env.get_action_meanings())
observation = env.reset()

print("\n\nObserved Starting Position")
plt.imshow(observation)
plt.show() #show initial state

print("Preprocessed Starting Position")
plt.imshow(AtariProcessor.process_observation('',observation))
plt.show() #show preprocessed initial state
# Out:
# Number of Actions: 9
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']
#
#
# Observed Starting Position
# Preprocessed Starting Position

# %%
# Using the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
if K.image_dim_ordering() == 'tf':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_dim_ordering() == 'th':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(n_actions))
model.add(Activation('linear'))
print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 88, 80, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 19, 32)        8224
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 19, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 8, 64)          32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 6, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2688)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1376768
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 4617
# _________________________________________________________________
# activation_5 (Activation)    (None, 9)                 0
# =================================================================
# Total params: 1,459,369
# Trainable params: 1,459,369
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Hyperparameters
num_steps = 5000000
learning_rate = 0.00025
discount_factor = 0.99
steps_train = 4
start_steps = 5000
eps_min = 0.1
eps_max = 1.0
eps_decay_steps = 500000
batch = 20000

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

#DecayingEpsilon
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=eps_max, value_min=eps_min, value_test=.05,
                              nb_steps=eps_decay_steps)

dqn = DQNAgent(model=model, nb_actions=n_actions, policy=policy, memory=memory, processor=processor, nb_steps_warmup=start_steps, 
               gamma=discount_factor, target_model_update=batch,train_interval=steps_train, delta_clip=1.)

dqn.compile(Adam(lr=learning_rate), metrics=['mae'])
# Out:
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\rl\util.py:79: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#Train

weights_filename = 'dqn_{}_weights.h5f'.format(ENV_NAME)

checkpoint_weights_filename = 'dqn_' + ENV_NAME + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(ENV_NAME)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=200000)]
callbacks += [FileLogger(log_filename, interval=100)]
 

history = dqn.fit(env, callbacks=callbacks, nb_steps=num_steps, log_interval=batch, visualize=False)

# After training is done, we save the final weights one more time.
dqn.save_weights(weights_filename, overwrite=True)

# Finally, evaluate our algorithm for 10 episodes.
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Training for 5000000 steps ...
# Interval 1 (0 steps performed)
# 20000/20000 [==============================] - 198s 10ms/step - reward: 0.0345
# 28 episodes - episode_reward: 24.000 [10.000, 48.000] - loss: 0.017 - mean_absolute_error: 0.036 - mean_q: 0.030 - mean_eps: 0.978 - ale.lives: 2.020
#
# Interval 2 (20000 steps performed)
# 20000/20000 [==============================] - 228s 11ms/step - reward: 0.0323
# 31 episodes - episode_reward: 21.097 [10.000, 37.000] - loss: 0.016 - mean_absolute_error: 0.048 - mean_q: 0.059 - mean_eps: 0.946 - ale.lives: 2.053
#
# Interval 3 (40000 steps performed)
# 20000/20000 [==============================] - 228s 11ms/step - reward: 0.0331
# 30 episodes - episode_reward: 22.400 [11.000, 38.000] - loss: 0.016 - mean_absolute_error: 0.091 - mean_q: 0.115 - mean_eps: 0.910 - ale.lives: 2.072
#
# Interval 4 (60000 steps performed)
# 20000/20000 [==============================] - 230s 11ms/step - reward: 0.0352
# 29 episodes - episode_reward: 24.276 [15.000, 52.000] - loss: 0.015 - mean_absolute_error: 0.118 - mean_q: 0.154 - mean_eps: 0.874 - ale.lives: 2.069
#
# Interval 5 (80000 steps performed)
# 20000/20000 [==============================] - 233s 12ms/step - reward: 0.0379
# 29 episodes - episode_reward: 26.207 [16.000, 55.000] - loss: 0.016 - mean_absolute_error: 0.163 - mean_q: 0.213 - mean_eps: 0.838 - ale.lives: 2.035
#
# Interval 6 (100000 steps performed)
# 20000/20000 [==============================] - 231s 12ms/step - reward: 0.0382
# 29 episodes - episode_reward: 25.724 [13.000, 51.000] - loss: 0.016 - mean_absolute_error: 0.201 - mean_q: 0.263 - mean_eps: 0.802 - ale.lives: 2.042
#
# Interval 7 (120000 steps performed)
# 20000/20000 [==============================] - 232s 12ms/step - reward: 0.0402
# 30 episodes - episode_reward: 27.167 [11.000, 47.000] - loss: 0.017 - mean_absolute_error: 0.257 - mean_q: 0.333 - mean_eps: 0.766 - ale.lives: 2.073
#
# Interval 8 (140000 steps performed)
# 20000/20000 [==============================] - 233s 12ms/step - reward: 0.0389
# 31 episodes - episode_reward: 24.839 [14.000, 48.000] - loss: 0.018 - mean_absolute_error: 0.322 - mean_q: 0.413 - mean_eps: 0.730 - ale.lives: 2.093
#
# Interval 9 (160000 steps performed)
# 20000/20000 [==============================] - 233s 12ms/step - reward: 0.0427
# 28 episodes - episode_reward: 30.750 [15.000, 53.000] - loss: 0.020 - mean_absolute_error: 0.389 - mean_q: 0.493 - mean_eps: 0.694 - ale.lives: 2.038
#
# Interval 10 (180000 steps performed)
# 20000/20000 [==============================] - 234s 12ms/step - reward: 0.0421
# 29 episodes - episode_reward: 28.586 [12.000, 44.000] - loss: 0.020 - mean_absolute_error: 0.443 - mean_q: 0.558 - mean_eps: 0.658 - ale.lives: 2.044
#
# Interval 11 (200000 steps performed)
# 20000/20000 [==============================] - 235s 12ms/step - reward: 0.0445
# 28 episodes - episode_reward: 32.286 [15.000, 54.000] - loss: 0.022 - mean_absolute_error: 0.498 - mean_q: 0.625 - mean_eps: 0.622 - ale.lives: 2.121
#
# Interval 12 (220000 steps performed)
# 20000/20000 [==============================] - 235s 12ms/step - reward: 0.0455
# 26 episodes - episode_reward: 33.154 [20.000, 48.000] - loss: 0.023 - mean_absolute_error: 0.591 - mean_q: 0.735 - mean_eps: 0.586 - ale.lives: 2.072
#
# Interval 13 (240000 steps performed)
# 20000/20000 [==============================] - 236s 12ms/step - reward: 0.0493
# 30 episodes - episode_reward: 34.633 [17.000, 72.000] - loss: 0.025 - mean_absolute_error: 0.664 - mean_q: 0.821 - mean_eps: 0.550 - ale.lives: 2.108
#
# Interval 14 (260000 steps performed)
# 20000/20000 [==============================] - 236s 12ms/step - reward: 0.0498
# 29 episodes - episode_reward: 32.966 [14.000, 57.000] - loss: 0.028 - mean_absolute_error: 0.747 - mean_q: 0.920 - mean_eps: 0.514 - ale.lives: 2.142
#
# Interval 15 (280000 steps performed)
# 20000/20000 [==============================] - 237s 12ms/step - reward: 0.0497
# 27 episodes - episode_reward: 38.296 [19.000, 71.000] - loss: 0.030 - mean_absolute_error: 0.825 - mean_q: 1.011 - mean_eps: 0.478 - ale.lives: 2.044
#
# Interval 16 (300000 steps performed)
# 20000/20000 [==============================] - 239s 12ms/step - reward: 0.0511
# 24 episodes - episode_reward: 40.792 [24.000, 74.000] - loss: 0.031 - mean_absolute_error: 0.908 - mean_q: 1.108 - mean_eps: 0.442 - ale.lives: 2.121
#
# Interval 17 (320000 steps performed)
# 20000/20000 [==============================] - 239s 12ms/step - reward: 0.0510
# 26 episodes - episode_reward: 40.885 [26.000, 59.000] - loss: 0.032 - mean_absolute_error: 0.951 - mean_q: 1.156 - mean_eps: 0.406 - ale.lives: 2.058
#
# Interval 18 (340000 steps performed)
# 20000/20000 [==============================] - 240s 12ms/step - reward: 0.0534
# 23 episodes - episode_reward: 43.261 [24.000, 64.000] - loss: 0.033 - mean_absolute_error: 1.039 - mean_q: 1.257 - mean_eps: 0.370 - ale.lives: 2.079
#
# Interval 19 (360000 steps performed)
# 20000/20000 [==============================] - 241s 12ms/step - reward: 0.0548
# 25 episodes - episode_reward: 46.280 [28.000, 75.000] - loss: 0.035 - mean_absolute_error: 1.113 - mean_q: 1.341 - mean_eps: 0.334 - ale.lives: 2.137
#
# Interval 20 (380000 steps performed)
# 20000/20000 [==============================] - 244s 12ms/step - reward: 0.0573
# 24 episodes - episode_reward: 46.667 [34.000, 64.000] - loss: 0.037 - mean_absolute_error: 1.197 - mean_q: 1.439 - mean_eps: 0.298 - ale.lives: 2.048
#
# Interval 21 (400000 steps performed)
# 20000/20000 [==============================] - 245s 12ms/step - reward: 0.0561
# 26 episodes - episode_reward: 43.577 [22.000, 77.000] - loss: 0.038 - mean_absolute_error: 1.263 - mean_q: 1.512 - mean_eps: 0.262 - ale.lives: 2.168
#
# Interval 22 (420000 steps performed)
# 20000/20000 [==============================] - 246s 12ms/step - reward: 0.0558
# 23 episodes - episode_reward: 49.000 [27.000, 80.000] - loss: 0.039 - mean_absolute_error: 1.324 - mean_q: 1.580 - mean_eps: 0.226 - ale.lives: 2.129
#
# Interval 23 (440000 steps performed)
# 20000/20000 [==============================] - 249s 12ms/step - reward: 0.0609
# 24 episodes - episode_reward: 49.417 [28.000, 76.000] - loss: 0.040 - mean_absolute_error: 1.384 - mean_q: 1.647 - mean_eps: 0.190 - ale.lives: 2.077
#
# Interval 24 (460000 steps performed)
# 20000/20000 [==============================] - 250s 12ms/step - reward: 0.0633
# 25 episodes - episode_reward: 51.920 [34.000, 83.000] - loss: 0.040 - mean_absolute_error: 1.437 - mean_q: 1.703 - mean_eps: 0.154 - ale.lives: 2.159
#
# Interval 25 (480000 steps performed)
# 20000/20000 [==============================] - 251s 13ms/step - reward: 0.0635
# 22 episodes - episode_reward: 56.545 [35.000, 80.000] - loss: 0.040 - mean_absolute_error: 1.466 - mean_q: 1.736 - mean_eps: 0.118 - ale.lives: 2.180
#
# Interval 26 (500000 steps performed)
# 20000/20000 [==============================] - 253s 13ms/step - reward: 0.0636
# 24 episodes - episode_reward: 53.167 [28.000, 105.000] - loss: 0.043 - mean_absolute_error: 1.576 - mean_q: 1.864 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 27 (520000 steps performed)
# 20000/20000 [==============================] - 255s 13ms/step - reward: 0.0578
# 22 episodes - episode_reward: 52.500 [38.000, 72.000] - loss: 0.043 - mean_absolute_error: 1.665 - mean_q: 1.963 - mean_eps: 0.100 - ale.lives: 2.069
#
# Interval 28 (540000 steps performed)
# 20000/20000 [==============================] - 256s 13ms/step - reward: 0.0616
# 24 episodes - episode_reward: 52.958 [31.000, 91.000] - loss: 0.046 - mean_absolute_error: 1.747 - mean_q: 2.058 - mean_eps: 0.100 - ale.lives: 2.052
#
# Interval 29 (560000 steps performed)
# 20000/20000 [==============================] - 259s 13ms/step - reward: 0.0638
# 21 episodes - episode_reward: 58.810 [36.000, 89.000] - loss: 0.047 - mean_absolute_error: 1.835 - mean_q: 2.155 - mean_eps: 0.100 - ale.lives: 2.071
#
# Interval 30 (580000 steps performed)
# 20000/20000 [==============================] - 261s 13ms/step - reward: 0.0624
# 23 episodes - episode_reward: 54.565 [20.000, 77.000] - loss: 0.049 - mean_absolute_error: 1.877 - mean_q: 2.202 - mean_eps: 0.100 - ale.lives: 2.105
#
# Interval 31 (600000 steps performed)
# 20000/20000 [==============================] - 261s 13ms/step - reward: 0.0649
# 23 episodes - episode_reward: 57.913 [37.000, 97.000] - loss: 0.049 - mean_absolute_error: 1.895 - mean_q: 2.223 - mean_eps: 0.100 - ale.lives: 2.069
#
# Interval 32 (620000 steps performed)
# 20000/20000 [==============================] - 254s 13ms/step - reward: 0.0672
# 24 episodes - episode_reward: 55.167 [35.000, 75.000] - loss: 0.051 - mean_absolute_error: 1.970 - mean_q: 2.304 - mean_eps: 0.100 - ale.lives: 2.130
#
# Interval 33 (640000 steps performed)
# 20000/20000 [==============================] - 258s 13ms/step - reward: 0.0654
# 22 episodes - episode_reward: 59.000 [37.000, 81.000] - loss: 0.051 - mean_absolute_error: 2.039 - mean_q: 2.383 - mean_eps: 0.100 - ale.lives: 2.132
#
# Interval 34 (660000 steps performed)
# 20000/20000 [==============================] - 260s 13ms/step - reward: 0.0662
# 23 episodes - episode_reward: 57.957 [37.000, 87.000] - loss: 0.052 - mean_absolute_error: 2.087 - mean_q: 2.437 - mean_eps: 0.100 - ale.lives: 2.078
#
# Interval 35 (680000 steps performed)
# 20000/20000 [==============================] - 274s 14ms/step - reward: 0.0630
# 22 episodes - episode_reward: 56.864 [37.000, 83.000] - loss: 0.052 - mean_absolute_error: 2.128 - mean_q: 2.484 - mean_eps: 0.100 - ale.lives: 2.097
#
# Interval 36 (700000 steps performed)
# 20000/20000 [==============================] - 264s 13ms/step - reward: 0.0611
# 22 episodes - episode_reward: 54.591 [32.000, 84.000] - loss: 0.054 - mean_absolute_error: 2.255 - mean_q: 2.626 - mean_eps: 0.100 - ale.lives: 2.134
#
# Interval 37 (720000 steps performed)
# 20000/20000 [==============================] - 265s 13ms/step - reward: 0.0635
# 24 episodes - episode_reward: 53.042 [32.000, 80.000] - loss: 0.055 - mean_absolute_error: 2.364 - mean_q: 2.748 - mean_eps: 0.100 - ale.lives: 2.173
#
# Interval 38 (740000 steps performed)
# 20000/20000 [==============================] - 268s 13ms/step - reward: 0.0649
# 21 episodes - episode_reward: 61.714 [28.000, 89.000] - loss: 0.056 - mean_absolute_error: 2.422 - mean_q: 2.814 - mean_eps: 0.100 - ale.lives: 2.163
#
# Interval 39 (760000 steps performed)
# 20000/20000 [==============================] - 277s 14ms/step - reward: 0.0640
# 23 episodes - episode_reward: 57.087 [30.000, 130.000] - loss: 0.056 - mean_absolute_error: 2.475 - mean_q: 2.872 - mean_eps: 0.100 - ale.lives: 2.121
#
# Interval 40 (780000 steps performed)
# 20000/20000 [==============================] - 275s 14ms/step - reward: 0.0630
# 23 episodes - episode_reward: 53.783 [29.000, 93.000] - loss: 0.061 - mean_absolute_error: 2.503 - mean_q: 2.905 - mean_eps: 0.100 - ale.lives: 2.188
#
# Interval 41 (800000 steps performed)
# 20000/20000 [==============================] - 278s 14ms/step - reward: 0.0669
# 25 episodes - episode_reward: 53.640 [37.000, 80.000] - loss: 0.061 - mean_absolute_error: 2.590 - mean_q: 3.000 - mean_eps: 0.100 - ale.lives: 2.096
#
# Interval 42 (820000 steps performed)
# 20000/20000 [==============================] - 279s 14ms/step - reward: 0.0673
# 25 episodes - episode_reward: 53.800 [33.000, 76.000] - loss: 0.061 - mean_absolute_error: 2.665 - mean_q: 3.086 - mean_eps: 0.100 - ale.lives: 2.094
#
# Interval 43 (840000 steps performed)
# 20000/20000 [==============================] - 279s 14ms/step - reward: 0.0707
# 23 episodes - episode_reward: 61.130 [35.000, 98.000] - loss: 0.065 - mean_absolute_error: 2.751 - mean_q: 3.185 - mean_eps: 0.100 - ale.lives: 2.110
#
# Interval 44 (860000 steps performed)
# 20000/20000 [==============================] - 282s 14ms/step - reward: 0.0650
# 24 episodes - episode_reward: 54.208 [36.000, 74.000] - loss: 0.064 - mean_absolute_error: 2.764 - mean_q: 3.198 - mean_eps: 0.100 - ale.lives: 1.966
#
# Interval 45 (880000 steps performed)
# 20000/20000 [==============================] - 286s 14ms/step - reward: 0.0640
# 23 episodes - episode_reward: 57.565 [39.000, 90.000] - loss: 0.066 - mean_absolute_error: 2.843 - mean_q: 3.284 - mean_eps: 0.100 - ale.lives: 2.051
#
# Interval 46 (900000 steps performed)
# 20000/20000 [==============================] - 290s 14ms/step - reward: 0.0678
# 23 episodes - episode_reward: 56.348 [34.000, 84.000] - loss: 0.067 - mean_absolute_error: 2.874 - mean_q: 3.320 - mean_eps: 0.100 - ale.lives: 2.075
#
# Interval 47 (920000 steps performed)
# 20000/20000 [==============================] - 301s 15ms/step - reward: 0.0712
# 24 episodes - episode_reward: 60.375 [33.000, 88.000] - loss: 0.068 - mean_absolute_error: 2.902 - mean_q: 3.351 - mean_eps: 0.100 - ale.lives: 2.224
#
# Interval 48 (940000 steps performed)
# 20000/20000 [==============================] - 294s 15ms/step - reward: 0.0693
# 25 episodes - episode_reward: 55.360 [30.000, 98.000] - loss: 0.068 - mean_absolute_error: 2.935 - mean_q: 3.387 - mean_eps: 0.100 - ale.lives: 2.116
#
# Interval 49 (960000 steps performed)
# 20000/20000 [==============================] - 294s 15ms/step - reward: 0.0684
# 24 episodes - episode_reward: 57.125 [32.000, 91.000] - loss: 0.069 - mean_absolute_error: 2.997 - mean_q: 3.460 - mean_eps: 0.100 - ale.lives: 2.146
#
# Interval 50 (980000 steps performed)
# 20000/20000 [==============================] - 297s 15ms/step - reward: 0.0616
# 23 episodes - episode_reward: 53.826 [34.000, 89.000] - loss: 0.071 - mean_absolute_error: 3.062 - mean_q: 3.530 - mean_eps: 0.100 - ale.lives: 2.183
#
# Interval 51 (1000000 steps performed)
# 20000/20000 [==============================] - 299s 15ms/step - reward: 0.0673
# 24 episodes - episode_reward: 56.500 [36.000, 87.000] - loss: 0.071 - mean_absolute_error: 3.065 - mean_q: 3.531 - mean_eps: 0.100 - ale.lives: 2.071
#
# Interval 52 (1020000 steps performed)
# 20000/20000 [==============================] - 295s 15ms/step - reward: 0.0670
# 24 episodes - episode_reward: 55.000 [35.000, 88.000] - loss: 0.071 - mean_absolute_error: 3.100 - mean_q: 3.567 - mean_eps: 0.100 - ale.lives: 2.163
#
# Interval 53 (1040000 steps performed)
# 20000/20000 [==============================] - 300s 15ms/step - reward: 0.0686
# 25 episodes - episode_reward: 55.000 [32.000, 82.000] - loss: 0.071 - mean_absolute_error: 3.119 - mean_q: 3.588 - mean_eps: 0.100 - ale.lives: 2.152
#
# Interval 54 (1060000 steps performed)
# 20000/20000 [==============================] - 304s 15ms/step - reward: 0.0729
# 27 episodes - episode_reward: 55.000 [33.000, 84.000] - loss: 0.073 - mean_absolute_error: 3.135 - mean_q: 3.608 - mean_eps: 0.100 - ale.lives: 2.080
#
# Interval 55 (1080000 steps performed)
# 20000/20000 [==============================] - 301s 15ms/step - reward: 0.0708
# 24 episodes - episode_reward: 59.375 [35.000, 103.000] - loss: 0.073 - mean_absolute_error: 3.188 - mean_q: 3.670 - mean_eps: 0.100 - ale.lives: 2.078
#
# Interval 56 (1100000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0678
# 21 episodes - episode_reward: 64.381 [38.000, 109.000] - loss: 0.072 - mean_absolute_error: 3.227 - mean_q: 3.708 - mean_eps: 0.100 - ale.lives: 2.147
#
# Interval 57 (1120000 steps performed)
# 20000/20000 [==============================] - 344s 17ms/step - reward: 0.0770
# 23 episodes - episode_reward: 65.565 [37.000, 97.000] - loss: 0.073 - mean_absolute_error: 3.215 - mean_q: 3.693 - mean_eps: 0.100 - ale.lives: 2.127
#
# Interval 58 (1140000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0717
# 24 episodes - episode_reward: 60.208 [38.000, 95.000] - loss: 0.073 - mean_absolute_error: 3.270 - mean_q: 3.756 - mean_eps: 0.100 - ale.lives: 2.141
#
# Interval 59 (1160000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0751
# 22 episodes - episode_reward: 69.409 [47.000, 106.000] - loss: 0.073 - mean_absolute_error: 3.318 - mean_q: 3.811 - mean_eps: 0.100 - ale.lives: 2.235
#
# Interval 60 (1180000 steps performed)
# 20000/20000 [==============================] - 345s 17ms/step - reward: 0.0735
# 21 episodes - episode_reward: 70.000 [47.000, 100.000] - loss: 0.071 - mean_absolute_error: 3.357 - mean_q: 3.852 - mean_eps: 0.100 - ale.lives: 2.061
#
# Interval 61 (1200000 steps performed)
# 20000/20000 [==============================] - 341s 17ms/step - reward: 0.0709
# 23 episodes - episode_reward: 59.391 [30.000, 86.000] - loss: 0.073 - mean_absolute_error: 3.364 - mean_q: 3.859 - mean_eps: 0.100 - ale.lives: 2.067
#
# Interval 62 (1220000 steps performed)
# 20000/20000 [==============================] - 340s 17ms/step - reward: 0.0732
# 24 episodes - episode_reward: 63.250 [38.000, 94.000] - loss: 0.072 - mean_absolute_error: 3.381 - mean_q: 3.880 - mean_eps: 0.100 - ale.lives: 2.094
#
# Interval 63 (1240000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0748
# 23 episodes - episode_reward: 64.043 [42.000, 101.000] - loss: 0.075 - mean_absolute_error: 3.407 - mean_q: 3.909 - mean_eps: 0.100 - ale.lives: 2.147
#
# Interval 64 (1260000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0731
# 25 episodes - episode_reward: 57.400 [23.000, 93.000] - loss: 0.073 - mean_absolute_error: 3.435 - mean_q: 3.940 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 65 (1280000 steps performed)
# 20000/20000 [==============================] - 330s 17ms/step - reward: 0.0761
# 25 episodes - episode_reward: 61.160 [36.000, 85.000] - loss: 0.074 - mean_absolute_error: 3.516 - mean_q: 4.031 - mean_eps: 0.100 - ale.lives: 2.112
#
# Interval 66 (1300000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0741
# 22 episodes - episode_reward: 69.364 [40.000, 98.000] - loss: 0.073 - mean_absolute_error: 3.533 - mean_q: 4.048 - mean_eps: 0.100 - ale.lives: 2.010
#
# Interval 67 (1320000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0747
# 25 episodes - episode_reward: 58.240 [36.000, 86.000] - loss: 0.074 - mean_absolute_error: 3.520 - mean_q: 4.034 - mean_eps: 0.100 - ale.lives: 2.159
#
# Interval 68 (1340000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0762
# 22 episodes - episode_reward: 68.318 [31.000, 98.000] - loss: 0.073 - mean_absolute_error: 3.548 - mean_q: 4.065 - mean_eps: 0.100 - ale.lives: 2.121
#
# Interval 69 (1360000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0771
# 25 episodes - episode_reward: 62.520 [31.000, 101.000] - loss: 0.075 - mean_absolute_error: 3.587 - mean_q: 4.108 - mean_eps: 0.100 - ale.lives: 2.172
#
# Interval 70 (1380000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0776
# 25 episodes - episode_reward: 63.200 [29.000, 107.000] - loss: 0.076 - mean_absolute_error: 3.633 - mean_q: 4.162 - mean_eps: 0.100 - ale.lives: 2.036
#
# Interval 71 (1400000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0715
# 21 episodes - episode_reward: 67.571 [40.000, 101.000] - loss: 0.076 - mean_absolute_error: 3.722 - mean_q: 4.263 - mean_eps: 0.100 - ale.lives: 2.172
#
# Interval 72 (1420000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0785
# 26 episodes - episode_reward: 59.462 [34.000, 91.000] - loss: 0.076 - mean_absolute_error: 3.722 - mean_q: 4.264 - mean_eps: 0.100 - ale.lives: 2.167
#
# Interval 73 (1440000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0751
# 22 episodes - episode_reward: 68.727 [33.000, 117.000] - loss: 0.074 - mean_absolute_error: 3.738 - mean_q: 4.278 - mean_eps: 0.100 - ale.lives: 2.111
#
# Interval 74 (1460000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0804
# 24 episodes - episode_reward: 66.417 [30.000, 102.000] - loss: 0.073 - mean_absolute_error: 3.768 - mean_q: 4.310 - mean_eps: 0.100 - ale.lives: 2.079
#
# Interval 75 (1480000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0783
# 26 episodes - episode_reward: 61.385 [38.000, 96.000] - loss: 0.077 - mean_absolute_error: 3.830 - mean_q: 4.381 - mean_eps: 0.100 - ale.lives: 2.097
#
# Interval 76 (1500000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0780
# 22 episodes - episode_reward: 69.636 [27.000, 107.000] - loss: 0.073 - mean_absolute_error: 3.842 - mean_q: 4.395 - mean_eps: 0.100 - ale.lives: 2.092
#
# Interval 77 (1520000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0799
# 23 episodes - episode_reward: 69.087 [32.000, 105.000] - loss: 0.072 - mean_absolute_error: 3.861 - mean_q: 4.416 - mean_eps: 0.100 - ale.lives: 2.148
#
# Interval 78 (1540000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0788
# 23 episodes - episode_reward: 70.174 [39.000, 119.000] - loss: 0.076 - mean_absolute_error: 3.910 - mean_q: 4.472 - mean_eps: 0.100 - ale.lives: 2.046
#
# Interval 79 (1560000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0782
# 23 episodes - episode_reward: 64.478 [43.000, 86.000] - loss: 0.078 - mean_absolute_error: 3.966 - mean_q: 4.535 - mean_eps: 0.100 - ale.lives: 2.169
#
# Interval 80 (1580000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0743
# 23 episodes - episode_reward: 66.652 [30.000, 112.000] - loss: 0.078 - mean_absolute_error: 4.008 - mean_q: 4.583 - mean_eps: 0.100 - ale.lives: 2.231
#
# Interval 81 (1600000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0779
# 21 episodes - episode_reward: 73.429 [46.000, 105.000] - loss: 0.078 - mean_absolute_error: 4.048 - mean_q: 4.628 - mean_eps: 0.100 - ale.lives: 2.131
#
# Interval 82 (1620000 steps performed)
# 20000/20000 [==============================] - 336s 17ms/step - reward: 0.0769
# 23 episodes - episode_reward: 68.739 [27.000, 107.000] - loss: 0.082 - mean_absolute_error: 4.107 - mean_q: 4.697 - mean_eps: 0.100 - ale.lives: 2.136
#
# Interval 83 (1640000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0749
# 23 episodes - episode_reward: 62.870 [36.000, 89.000] - loss: 0.085 - mean_absolute_error: 4.166 - mean_q: 4.763 - mean_eps: 0.100 - ale.lives: 2.085
#
# Interval 84 (1660000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0760
# 21 episodes - episode_reward: 71.333 [36.000, 100.000] - loss: 0.088 - mean_absolute_error: 4.234 - mean_q: 4.843 - mean_eps: 0.100 - ale.lives: 1.954
#
# Interval 85 (1680000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.07621
# 23 episodes - episode_reward: 69.826 [32.000, 100.000] - loss: 0.085 - mean_absolute_error: 4.264 - mean_q: 4.878 - mean_eps: 0.100 - ale.lives: 2.132
#
# Interval 86 (1700000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0818
# 21 episodes - episode_reward: 76.429 [41.000, 127.000] - loss: 0.083 - mean_absolute_error: 4.301 - mean_q: 4.916 - mean_eps: 0.100 - ale.lives: 2.141
#
# Interval 87 (1720000 steps performed)
# 20000/20000 [==============================] - 344s 17ms/step - reward: 0.0777
# 23 episodes - episode_reward: 68.087 [31.000, 96.000] - loss: 0.081 - mean_absolute_error: 4.356 - mean_q: 4.980 - mean_eps: 0.100 - ale.lives: 2.113
#
# Interval 88 (1740000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0798
# 26 episodes - episode_reward: 61.500 [36.000, 96.000] - loss: 0.082 - mean_absolute_error: 4.356 - mean_q: 4.979 - mean_eps: 0.100 - ale.lives: 2.206
#
# Interval 89 (1760000 steps performed)
# 20000/20000 [==============================] - 338s 17ms/step - reward: 0.0838
# 24 episodes - episode_reward: 68.500 [23.000, 112.000] - loss: 0.081 - mean_absolute_error: 4.360 - mean_q: 4.985 - mean_eps: 0.100 - ale.lives: 2.204
#
# Interval 90 (1780000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0784
# 24 episodes - episode_reward: 67.875 [24.000, 100.000] - loss: 0.083 - mean_absolute_error: 4.342 - mean_q: 4.963 - mean_eps: 0.100 - ale.lives: 2.077
#
# Interval 91 (1800000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0803
# 23 episodes - episode_reward: 68.304 [33.000, 108.000] - loss: 0.083 - mean_absolute_error: 4.432 - mean_q: 5.062 - mean_eps: 0.100 - ale.lives: 2.049
#
# Interval 92 (1820000 steps performed)
# 20000/20000 [==============================] - 336s 17ms/step - reward: 0.0737
# 21 episodes - episode_reward: 71.857 [36.000, 114.000] - loss: 0.085 - mean_absolute_error: 4.479 - mean_q: 5.116 - mean_eps: 0.100 - ale.lives: 2.093
#
# Interval 93 (1840000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0796
# 22 episodes - episode_reward: 71.591 [37.000, 116.000] - loss: 0.085 - mean_absolute_error: 4.552 - mean_q: 5.199 - mean_eps: 0.100 - ale.lives: 2.134
#
# Interval 94 (1860000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0812
# 24 episodes - episode_reward: 68.375 [40.000, 99.000] - loss: 0.083 - mean_absolute_error: 4.560 - mean_q: 5.204 - mean_eps: 0.100 - ale.lives: 2.025
#
# Interval 95 (1880000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0828
# 25 episodes - episode_reward: 65.880 [37.000, 95.000] - loss: 0.086 - mean_absolute_error: 4.623 - mean_q: 5.277 - mean_eps: 0.100 - ale.lives: 2.053
#
# Interval 96 (1900000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0782
# 24 episodes - episode_reward: 65.500 [30.000, 104.000] - loss: 0.084 - mean_absolute_error: 4.639 - mean_q: 5.296 - mean_eps: 0.100 - ale.lives: 2.088
#
# Interval 97 (1920000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0795
# 22 episodes - episode_reward: 72.000 [40.000, 101.000] - loss: 0.083 - mean_absolute_error: 4.585 - mean_q: 5.235 - mean_eps: 0.100 - ale.lives: 2.029
#
# Interval 98 (1940000 steps performed)
# 20000/20000 [==============================] - 355s 18ms/step - reward: 0.0830
# 22 episodes - episode_reward: 73.045 [40.000, 108.000] - loss: 0.082 - mean_absolute_error: 4.566 - mean_q: 5.214 - mean_eps: 0.100 - ale.lives: 2.150
#
# Interval 99 (1960000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0785
# 23 episodes - episode_reward: 69.652 [34.000, 102.000] - loss: 0.083 - mean_absolute_error: 4.657 - mean_q: 5.314 - mean_eps: 0.100 - ale.lives: 2.143
#
# Interval 100 (1980000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0809
# 22 episodes - episode_reward: 74.182 [51.000, 127.000] - loss: 0.083 - mean_absolute_error: 4.686 - mean_q: 5.348 - mean_eps: 0.100 - ale.lives: 2.125
#
# Interval 101 (2000000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0783
# 21 episodes - episode_reward: 72.381 [38.000, 106.000] - loss: 0.089 - mean_absolute_error: 4.706 - mean_q: 5.373 - mean_eps: 0.100 - ale.lives: 2.132
#
# Interval 102 (2020000 steps performed)
# 20000/20000 [==============================] - 336s 17ms/step - reward: 0.0765
# 22 episodes - episode_reward: 69.000 [33.000, 109.000] - loss: 0.086 - mean_absolute_error: 4.770 - mean_q: 5.444 - mean_eps: 0.100 - ale.lives: 2.036
#
# Interval 103 (2040000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0790
# 23 episodes - episode_reward: 68.565 [34.000, 108.000] - loss: 0.087 - mean_absolute_error: 4.800 - mean_q: 5.477 - mean_eps: 0.100 - ale.lives: 2.082
#
# Interval 104 (2060000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0790
# 24 episodes - episode_reward: 67.250 [36.000, 88.000] - loss: 0.085 - mean_absolute_error: 4.846 - mean_q: 5.530 - mean_eps: 0.100 - ale.lives: 2.156
#
# Interval 105 (2080000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0775
# 23 episodes - episode_reward: 69.174 [41.000, 98.000] - loss: 0.086 - mean_absolute_error: 4.853 - mean_q: 5.539 - mean_eps: 0.100 - ale.lives: 2.098
#
# Interval 106 (2100000 steps performed)
# 20000/20000 [==============================] - 323s 16ms/step - reward: 0.0843
# 23 episodes - episode_reward: 72.435 [37.000, 109.000] - loss: 0.089 - mean_absolute_error: 4.932 - mean_q: 5.630 - mean_eps: 0.100 - ale.lives: 2.096
#
# Interval 107 (2120000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0827
# 22 episodes - episode_reward: 76.136 [43.000, 101.000] - loss: 0.090 - mean_absolute_error: 4.977 - mean_q: 5.679 - mean_eps: 0.100 - ale.lives: 2.095
#
# Interval 108 (2140000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0840
# 20 episodes - episode_reward: 81.600 [53.000, 113.000] - loss: 0.091 - mean_absolute_error: 5.040 - mean_q: 5.751 - mean_eps: 0.100 - ale.lives: 2.099
#
# Interval 109 (2160000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0845
# 23 episodes - episode_reward: 74.087 [29.000, 111.000] - loss: 0.092 - mean_absolute_error: 5.044 - mean_q: 5.756 - mean_eps: 0.100 - ale.lives: 2.108
#
# Interval 110 (2180000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0805
# 22 episodes - episode_reward: 72.318 [36.000, 104.000] - loss: 0.092 - mean_absolute_error: 5.099 - mean_q: 5.818 - mean_eps: 0.100 - ale.lives: 2.063
#
# Interval 111 (2200000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0852
# 24 episodes - episode_reward: 71.542 [35.000, 113.000] - loss: 0.091 - mean_absolute_error: 5.136 - mean_q: 5.864 - mean_eps: 0.100 - ale.lives: 2.106
#
# Interval 112 (2220000 steps performed)
# 20000/20000 [==============================] - 338s 17ms/step - reward: 0.0834
# 24 episodes - episode_reward: 71.250 [51.000, 102.000] - loss: 0.095 - mean_absolute_error: 5.199 - mean_q: 5.936 - mean_eps: 0.100 - ale.lives: 2.097
#
# Interval 113 (2240000 steps performed)
# 20000/20000 [==============================] - 341s 17ms/step - reward: 0.0858
# 22 episodes - episode_reward: 74.182 [41.000, 119.000] - loss: 0.094 - mean_absolute_error: 5.216 - mean_q: 5.957 - mean_eps: 0.100 - ale.lives: 2.138
#
# Interval 114 (2260000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0862
# 24 episodes - episode_reward: 73.167 [45.000, 103.000] - loss: 0.095 - mean_absolute_error: 5.232 - mean_q: 5.971 - mean_eps: 0.100 - ale.lives: 2.071
#
# Interval 115 (2280000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0862
# 23 episodes - episode_reward: 74.652 [36.000, 95.000] - loss: 0.093 - mean_absolute_error: 5.213 - mean_q: 5.950 - mean_eps: 0.100 - ale.lives: 2.080
#
# Interval 116 (2300000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0843
# 23 episodes - episode_reward: 76.000 [37.000, 100.000] - loss: 0.092 - mean_absolute_error: 5.299 - mean_q: 6.045 - mean_eps: 0.100 - ale.lives: 2.080
#
# Interval 117 (2320000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0851
# 23 episodes - episode_reward: 74.000 [48.000, 99.000] - loss: 0.096 - mean_absolute_error: 5.339 - mean_q: 6.093 - mean_eps: 0.100 - ale.lives: 2.183
#
# Interval 118 (2340000 steps performed)
# 20000/20000 [==============================] - 346s 17ms/step - reward: 0.0842
# 20 episodes - episode_reward: 82.850 [40.000, 120.000] - loss: 0.099 - mean_absolute_error: 5.437 - mean_q: 6.198 - mean_eps: 0.100 - ale.lives: 2.135
#
# Interval 119 (2360000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0824
# 23 episodes - episode_reward: 72.087 [25.000, 101.000] - loss: 0.094 - mean_absolute_error: 5.504 - mean_q: 6.276 - mean_eps: 0.100 - ale.lives: 2.112
#
# Interval 120 (2380000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0849
# 22 episodes - episode_reward: 75.909 [36.000, 102.000] - loss: 0.095 - mean_absolute_error: 5.519 - mean_q: 6.295 - mean_eps: 0.100 - ale.lives: 2.108
#
# Interval 121 (2400000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0848
# 22 episodes - episode_reward: 75.909 [42.000, 120.000] - loss: 0.096 - mean_absolute_error: 5.505 - mean_q: 6.279 - mean_eps: 0.100 - ale.lives: 2.164
#
# Interval 122 (2420000 steps performed)
# 20000/20000 [==============================] - 343s 17ms/step - reward: 0.0851
# 25 episodes - episode_reward: 67.920 [33.000, 92.000] - loss: 0.097 - mean_absolute_error: 5.523 - mean_q: 6.298 - mean_eps: 0.100 - ale.lives: 2.148
#
# Interval 123 (2440000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0833
# 21 episodes - episode_reward: 78.857 [29.000, 104.000] - loss: 0.096 - mean_absolute_error: 5.551 - mean_q: 6.331 - mean_eps: 0.100 - ale.lives: 2.097
#
# Interval 124 (2460000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0828
# 23 episodes - episode_reward: 74.261 [40.000, 101.000] - loss: 0.096 - mean_absolute_error: 5.562 - mean_q: 6.343 - mean_eps: 0.100 - ale.lives: 2.169
#
# Interval 125 (2480000 steps performed)
# 20000/20000 [==============================] - 325s 16ms/step - reward: 0.0869
# 25 episodes - episode_reward: 69.800 [33.000, 116.000] - loss: 0.096 - mean_absolute_error: 5.597 - mean_q: 6.384 - mean_eps: 0.100 - ale.lives: 2.105
#
# Interval 126 (2500000 steps performed)
# 20000/20000 [==============================] - 326s 16ms/step - reward: 0.0886
# 24 episodes - episode_reward: 71.792 [41.000, 105.000] - loss: 0.096 - mean_absolute_error: 5.680 - mean_q: 6.476 - mean_eps: 0.100 - ale.lives: 2.080
#
# Interval 127 (2520000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0861
# 25 episodes - episode_reward: 69.600 [34.000, 129.000] - loss: 0.099 - mean_absolute_error: 5.698 - mean_q: 6.497 - mean_eps: 0.100 - ale.lives: 2.200
#
# Interval 128 (2540000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0895
# 24 episodes - episode_reward: 74.125 [36.000, 112.000] - loss: 0.096 - mean_absolute_error: 5.748 - mean_q: 6.551 - mean_eps: 0.100 - ale.lives: 2.067
#
# Interval 129 (2560000 steps performed)
# 20000/20000 [==============================] - 326s 16ms/step - reward: 0.0861
# 21 episodes - episode_reward: 82.857 [36.000, 111.000] - loss: 0.095 - mean_absolute_error: 5.780 - mean_q: 6.587 - mean_eps: 0.100 - ale.lives: 2.120
#
# Interval 130 (2580000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0841
# 24 episodes - episode_reward: 71.917 [35.000, 118.000] - loss: 0.099 - mean_absolute_error: 5.804 - mean_q: 6.616 - mean_eps: 0.100 - ale.lives: 2.061
#
# Interval 131 (2600000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0862
# 24 episodes - episode_reward: 69.000 [39.000, 115.000] - loss: 0.097 - mean_absolute_error: 5.832 - mean_q: 6.648 - mean_eps: 0.100 - ale.lives: 2.126
#
# Interval 132 (2620000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0848
# 21 episodes - episode_reward: 80.381 [33.000, 108.000] - loss: 0.099 - mean_absolute_error: 5.876 - mean_q: 6.696 - mean_eps: 0.100 - ale.lives: 2.094
#
# Interval 133 (2640000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0838
# 22 episodes - episode_reward: 77.636 [35.000, 109.000] - loss: 0.098 - mean_absolute_error: 5.918 - mean_q: 6.743 - mean_eps: 0.100 - ale.lives: 2.130
#
# Interval 134 (2660000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0795
# 21 episodes - episode_reward: 77.810 [42.000, 122.000] - loss: 0.097 - mean_absolute_error: 5.888 - mean_q: 6.709 - mean_eps: 0.100 - ale.lives: 2.105
#
# Interval 135 (2680000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0914
# 23 episodes - episode_reward: 75.870 [51.000, 116.000] - loss: 0.097 - mean_absolute_error: 5.888 - mean_q: 6.709 - mean_eps: 0.100 - ale.lives: 2.103
#
# Interval 136 (2700000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0878
# 21 episodes - episode_reward: 84.190 [58.000, 123.000] - loss: 0.098 - mean_absolute_error: 5.947 - mean_q: 6.780 - mean_eps: 0.100 - ale.lives: 2.195
#
# Interval 137 (2720000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.08340s - reward:
# 21 episodes - episode_reward: 82.762 [28.000, 115.000] - loss: 0.095 - mean_absolute_error: 5.969 - mean_q: 6.804 - mean_eps: 0.100 - ale.lives: 2.165
#
# Interval 138 (2740000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0904
# 23 episodes - episode_reward: 75.391 [35.000, 103.000] - loss: 0.101 - mean_absolute_error: 6.017 - mean_q: 6.856 - mean_eps: 0.100 - ale.lives: 2.150
#
# Interval 139 (2760000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0864
# 22 episodes - episode_reward: 79.864 [55.000, 102.000] - loss: 0.096 - mean_absolute_error: 6.057 - mean_q: 6.902 - mean_eps: 0.100 - ale.lives: 2.208
#
# Interval 140 (2780000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0867
# 21 episodes - episode_reward: 81.952 [29.000, 115.000] - loss: 0.096 - mean_absolute_error: 6.044 - mean_q: 6.888 - mean_eps: 0.100 - ale.lives: 2.183
#
# Interval 141 (2800000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0879
# 21 episodes - episode_reward: 82.190 [28.000, 113.000] - loss: 0.097 - mean_absolute_error: 6.069 - mean_q: 6.916 - mean_eps: 0.100 - ale.lives: 2.158
#
# Interval 142 (2820000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.08660s - reward: 0
# 22 episodes - episode_reward: 82.273 [16.000, 114.000] - loss: 0.097 - mean_absolute_error: 6.153 - mean_q: 7.010 - mean_eps: 0.100 - ale.lives: 2.198
#
# Interval 143 (2840000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0896
# 23 episodes - episode_reward: 77.565 [32.000, 107.000] - loss: 0.101 - mean_absolute_error: 6.160 - mean_q: 7.019 - mean_eps: 0.100 - ale.lives: 2.195
#
# Interval 144 (2860000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0906
# 23 episodes - episode_reward: 77.870 [44.000, 122.000] - loss: 0.098 - mean_absolute_error: 6.145 - mean_q: 7.002 - mean_eps: 0.100 - ale.lives: 2.222
#
# Interval 145 (2880000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0911
# 23 episodes - episode_reward: 77.957 [42.000, 99.000] - loss: 0.097 - mean_absolute_error: 6.147 - mean_q: 7.006 - mean_eps: 0.100 - ale.lives: 2.147
#
# Interval 146 (2900000 steps performed)
# 20000/20000 [==============================] - 330s 17ms/step - reward: 0.0876
# 21 episodes - episode_reward: 83.905 [52.000, 121.000] - loss: 0.102 - mean_absolute_error: 6.200 - mean_q: 7.065 - mean_eps: 0.100 - ale.lives: 2.238
#
# Interval 147 (2920000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.08410s - r
# 21 episodes - episode_reward: 80.286 [39.000, 113.000] - loss: 0.096 - mean_absolute_error: 6.190 - mean_q: 7.051 - mean_eps: 0.100 - ale.lives: 2.161
#
# Interval 148 (2940000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0895
# 19 episodes - episode_reward: 93.947 [68.000, 119.000] - loss: 0.097 - mean_absolute_error: 6.188 - mean_q: 7.049 - mean_eps: 0.100 - ale.lives: 2.181
#
# Interval 149 (2960000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.08350s - reward:
# 21 episodes - episode_reward: 79.571 [42.000, 128.000] - loss: 0.099 - mean_absolute_error: 6.200 - mean_q: 7.064 - mean_eps: 0.100 - ale.lives: 2.200
#
# Interval 150 (2980000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0881
# 23 episodes - episode_reward: 76.957 [54.000, 105.000] - loss: 0.098 - mean_absolute_error: 6.205 - mean_q: 7.068 - mean_eps: 0.100 - ale.lives: 2.205
#
# Interval 151 (3000000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0920
# 21 episodes - episode_reward: 87.095 [55.000, 109.000] - loss: 0.100 - mean_absolute_error: 6.241 - mean_q: 7.110 - mean_eps: 0.100 - ale.lives: 2.123
#
# Interval 152 (3020000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0929
# 21 episodes - episode_reward: 86.190 [72.000, 113.000] - loss: 0.099 - mean_absolute_error: 6.286 - mean_q: 7.161 - mean_eps: 0.100 - ale.lives: 2.160
#
# Interval 153 (3040000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0937
# 21 episodes - episode_reward: 90.810 [56.000, 126.000] - loss: 0.100 - mean_absolute_error: 6.329 - mean_q: 7.209 - mean_eps: 0.100 - ale.lives: 2.054
#
# Interval 154 (3060000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0885
# 23 episodes - episode_reward: 79.087 [47.000, 115.000] - loss: 0.103 - mean_absolute_error: 6.349 - mean_q: 7.232 - mean_eps: 0.100 - ale.lives: 2.217
#
# Interval 155 (3080000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0973
# 21 episodes - episode_reward: 90.286 [69.000, 125.000] - loss: 0.101 - mean_absolute_error: 6.357 - mean_q: 7.242 - mean_eps: 0.100 - ale.lives: 2.217
#
# Interval 156 (3100000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0922
# 24 episodes - episode_reward: 79.042 [56.000, 118.000] - loss: 0.100 - mean_absolute_error: 6.356 - mean_q: 7.240 - mean_eps: 0.100 - ale.lives: 2.218
#
# Interval 157 (3120000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0937
# 21 episodes - episode_reward: 87.667 [64.000, 109.000] - loss: 0.103 - mean_absolute_error: 6.408 - mean_q: 7.300 - mean_eps: 0.100 - ale.lives: 2.282
#
# Interval 158 (3140000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0916
# 21 episodes - episode_reward: 90.143 [40.000, 117.000] - loss: 0.099 - mean_absolute_error: 6.408 - mean_q: 7.300 - mean_eps: 0.100 - ale.lives: 2.115
#
# Interval 159 (3160000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0921
# 20 episodes - episode_reward: 87.800 [41.000, 117.000] - loss: 0.101 - mean_absolute_error: 6.418 - mean_q: 7.312 - mean_eps: 0.100 - ale.lives: 2.168
#
# Interval 160 (3180000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0935
# 21 episodes - episode_reward: 91.905 [39.000, 124.000] - loss: 0.097 - mean_absolute_error: 6.442 - mean_q: 7.338 - mean_eps: 0.100 - ale.lives: 2.116
#
# Interval 161 (3200000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0969
# 22 episodes - episode_reward: 86.818 [48.000, 117.000] - loss: 0.105 - mean_absolute_error: 6.536 - mean_q: 7.446 - mean_eps: 0.100 - ale.lives: 2.163
#
# Interval 162 (3220000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0911
# 20 episodes - episode_reward: 92.750 [54.000, 128.000] - loss: 0.107 - mean_absolute_error: 6.572 - mean_q: 7.486 - mean_eps: 0.100 - ale.lives: 2.140
#
# Interval 163 (3240000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0871
# 19 episodes - episode_reward: 90.105 [55.000, 126.000] - loss: 0.102 - mean_absolute_error: 6.626 - mean_q: 7.548 - mean_eps: 0.100 - ale.lives: 2.147
#
# Interval 164 (3260000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0881
# 21 episodes - episode_reward: 83.857 [44.000, 124.000] - loss: 0.102 - mean_absolute_error: 6.621 - mean_q: 7.540 - mean_eps: 0.100 - ale.lives: 2.240
#
# Interval 165 (3280000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0853
# 21 episodes - episode_reward: 81.095 [59.000, 103.000] - loss: 0.105 - mean_absolute_error: 6.674 - mean_q: 7.599 - mean_eps: 0.100 - ale.lives: 2.197
#
# Interval 166 (3300000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0944
# 22 episodes - episode_reward: 83.500 [39.000, 114.000] - loss: 0.102 - mean_absolute_error: 6.695 - mean_q: 7.625 - mean_eps: 0.100 - ale.lives: 2.246
#
# Interval 167 (3320000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0893
# 21 episodes - episode_reward: 87.333 [38.000, 113.000] - loss: 0.105 - mean_absolute_error: 6.773 - mean_q: 7.713 - mean_eps: 0.100 - ale.lives: 2.141
#
# Interval 168 (3340000 steps performed)
# 20000/20000 [==============================] - 330s 17ms/step - reward: 0.0842
# 20 episodes - episode_reward: 86.000 [35.000, 119.000] - loss: 0.105 - mean_absolute_error: 6.749 - mean_q: 7.686 - mean_eps: 0.100 - ale.lives: 2.239
#
# Interval 169 (3360000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.08770s -
# 20 episodes - episode_reward: 86.750 [32.000, 121.000] - loss: 0.102 - mean_absolute_error: 6.748 - mean_q: 7.685 - mean_eps: 0.100 - ale.lives: 2.213
#
# Interval 170 (3380000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0876
# 19 episodes - episode_reward: 91.526 [66.000, 115.000] - loss: 0.106 - mean_absolute_error: 6.797 - mean_q: 7.739 - mean_eps: 0.100 - ale.lives: 2.143
#
# Interval 171 (3400000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0888
# 19 episodes - episode_reward: 91.316 [57.000, 120.000] - loss: 0.105 - mean_absolute_error: 6.800 - mean_q: 7.743 - mean_eps: 0.100 - ale.lives: 2.225
#
# Interval 172 (3420000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0932
# 21 episodes - episode_reward: 89.762 [41.000, 126.000] - loss: 0.105 - mean_absolute_error: 6.775 - mean_q: 7.714 - mean_eps: 0.100 - ale.lives: 2.205
#
# Interval 173 (3440000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0857
# 20 episodes - episode_reward: 89.300 [43.000, 121.000] - loss: 0.107 - mean_absolute_error: 6.784 - mean_q: 7.726 - mean_eps: 0.100 - ale.lives: 2.110
#
# Interval 174 (3460000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0934
# 21 episodes - episode_reward: 86.333 [64.000, 132.000] - loss: 0.105 - mean_absolute_error: 6.781 - mean_q: 7.722 - mean_eps: 0.100 - ale.lives: 2.192
#
# Interval 175 (3480000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0827
# 21 episodes - episode_reward: 78.667 [36.000, 123.000] - loss: 0.107 - mean_absolute_error: 6.765 - mean_q: 7.702 - mean_eps: 0.100 - ale.lives: 2.224
#
# Interval 176 (3500000 steps performed)
# 20000/20000 [==============================] - 349s 17ms/step - reward: 0.0910
# 21 episodes - episode_reward: 86.667 [62.000, 114.000] - loss: 0.107 - mean_absolute_error: 6.757 - mean_q: 7.694 - mean_eps: 0.100 - ale.lives: 2.148
#
# Interval 177 (3520000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0906
# 21 episodes - episode_reward: 85.333 [50.000, 117.000] - loss: 0.104 - mean_absolute_error: 6.797 - mean_q: 7.738 - mean_eps: 0.100 - ale.lives: 2.128
#
# Interval 178 (3540000 steps performed)
# 20000/20000 [==============================] - 330s 17ms/step - reward: 0.0891
# 22 episodes - episode_reward: 82.909 [39.000, 128.000] - loss: 0.105 - mean_absolute_error: 6.884 - mean_q: 7.838 - mean_eps: 0.100 - ale.lives: 2.186
#
# Interval 179 (3560000 steps performed)
# ...
#
# Interval 193 (3840000 steps performed)
# 20000/20000 [==============================] - 336s 17ms/step - reward: 0.0896
# 21 episodes - episode_reward: 87.619 [45.000, 106.000] - loss: 0.103 - mean_absolute_error: 7.217 - mean_q: 8.215 - mean_eps: 0.100 - ale.lives: 2.213
#
# Interval 194 (3860000 steps performed)
# 20000/20000 [==============================] - 341s 17ms/step - reward: 0.0891
# 20 episodes - episode_reward: 87.450 [47.000, 127.000] - loss: 0.104 - mean_absolute_error: 7.236 - mean_q: 8.235 - mean_eps: 0.100 - ale.lives: 2.205
#
# Interval 195 (3880000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0916
# 20 episodes - episode_reward: 89.200 [59.000, 118.000] - loss: 0.103 - mean_absolute_error: 7.271 - mean_q: 8.275 - mean_eps: 0.100 - ale.lives: 2.200
#
# Interval 196 (3900000 steps performed)
# 20000/20000 [==============================] - 334s 17ms/step - reward: 0.0916
# 19 episodes - episode_reward: 95.474 [41.000, 120.000] - loss: 0.105 - mean_absolute_error: 7.262 - mean_q: 8.265 - mean_eps: 0.100 - ale.lives: 2.249
#
# Interval 197 (3920000 steps performed)
# 20000/20000 [==============================] - 359s 18ms/step - reward: 0.0880
# 21 episodes - episode_reward: 85.095 [48.000, 121.000] - loss: 0.102 - mean_absolute_error: 7.261 - mean_q: 8.262 - mean_eps: 0.100 - ale.lives: 2.210
#
# Interval 198 (3940000 steps performed)
# 20000/20000 [==============================] - 336s 17ms/step - reward: 0.0905
# 20 episodes - episode_reward: 92.950 [54.000, 112.000] - loss: 0.105 - mean_absolute_error: 7.302 - mean_q: 8.310 - mean_eps: 0.100 - ale.lives: 2.247
#
# Interval 199 (3960000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0846
# 20 episodes - episode_reward: 86.400 [48.000, 133.000] - loss: 0.104 - mean_absolute_error: 7.301 - mean_q: 8.310 - mean_eps: 0.100 - ale.lives: 2.111
#
# Interval 200 (3980000 steps performed)
# 20000/20000 [==============================] - 344s 17ms/step - reward: 0.0918
# 19 episodes - episode_reward: 92.947 [50.000, 120.000] - loss: 0.104 - mean_absolute_error: 7.303 - mean_q: 8.313 - mean_eps: 0.100 - ale.lives: 2.182
#
# Interval 201 (4000000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0928
# 21 episodes - episode_reward: 88.524 [61.000, 112.000] - loss: 0.105 - mean_absolute_error: 7.299 - mean_q: 8.309 - mean_eps: 0.100 - ale.lives: 2.194
#
# Interval 202 (4020000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0854
# 21 episodes - episode_reward: 84.286 [46.000, 116.000] - loss: 0.105 - mean_absolute_error: 7.399 - mean_q: 8.420 - mean_eps: 0.100 - ale.lives: 2.142
#
# Interval 203 (4040000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0848
# 18 episodes - episode_reward: 92.667 [56.000, 132.000] - loss: 0.103 - mean_absolute_error: 7.476 - mean_q: 8.508 - mean_eps: 0.100 - ale.lives: 2.079
#
# Interval 204 (4060000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0905
# 20 episodes - episode_reward: 92.050 [59.000, 111.000] - loss: 0.108 - mean_absolute_error: 7.460 - mean_q: 8.489 - mean_eps: 0.100 - ale.lives: 2.141
#
# Interval 205 (4080000 steps performed)
# 20000/20000 [==============================] - 338s 17ms/step - reward: 0.0891
# 21 episodes - episode_reward: 82.810 [34.000, 126.000] - loss: 0.110 - mean_absolute_error: 7.479 - mean_q: 8.509 - mean_eps: 0.100 - ale.lives: 2.178
#
# Interval 206 (4100000 steps performed)
# 20000/20000 [==============================] - 337s 17ms/step - reward: 0.0936
# 20 episodes - episode_reward: 93.100 [55.000, 119.000] - loss: 0.107 - mean_absolute_error: 7.463 - mean_q: 8.492 - mean_eps: 0.100 - ale.lives: 2.052
#
# Interval 207 (4120000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0874
# 19 episodes - episode_reward: 94.842 [63.000, 122.000] - loss: 0.106 - mean_absolute_error: 7.472 - mean_q: 8.502 - mean_eps: 0.100 - ale.lives: 2.145
#
# Interval 208 (4140000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0903
# 19 episodes - episode_reward: 90.316 [53.000, 124.000] - loss: 0.105 - mean_absolute_error: 7.429 - mean_q: 8.455 - mean_eps: 0.100 - ale.lives: 2.196
#
# Interval 209 (4160000 steps performed)
# 20000/20000 [==============================] - 342s 17ms/step - reward: 0.0925
# 21 episodes - episode_reward: 90.286 [45.000, 133.000] - loss: 0.106 - mean_absolute_error: 7.446 - mean_q: 8.478 - mean_eps: 0.100 - ale.lives: 2.190
#
# Interval 210 (4180000 steps performed)
# 20000/20000 [==============================] - 338s 17ms/step - reward: 0.0896
# 21 episodes - episode_reward: 84.810 [27.000, 122.000] - loss: 0.109 - mean_absolute_error: 7.503 - mean_q: 8.540 - mean_eps: 0.100 - ale.lives: 2.154
#
# Interval 211 (4200000 steps performed)
# 20000/20000 [==============================] - 336s 17ms/step - reward: 0.0888
# 20 episodes - episode_reward: 89.500 [39.000, 124.000] - loss: 0.107 - mean_absolute_error: 7.536 - mean_q: 8.575 - mean_eps: 0.100 - ale.lives: 2.215
#
# Interval 212 (4220000 steps performed)
# 20000/20000 [==============================] - 342s 17ms/step - reward: 0.0905
# 19 episodes - episode_reward: 93.526 [57.000, 122.000] - loss: 0.105 - mean_absolute_error: 7.584 - mean_q: 8.632 - mean_eps: 0.100 - ale.lives: 2.115
#
# Interval 213 (4240000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0890
# 21 episodes - episode_reward: 84.762 [53.000, 121.000] - loss: 0.107 - mean_absolute_error: 7.557 - mean_q: 8.603 - mean_eps: 0.100 - ale.lives: 2.199
#
# Interval 214 (4260000 steps performed)
# 20000/20000 [==============================] - 326s 16ms/step - reward: 0.0909
# 21 episodes - episode_reward: 86.952 [50.000, 112.000] - loss: 0.106 - mean_absolute_error: 7.556 - mean_q: 8.602 - mean_eps: 0.100 - ale.lives: 2.238
#
# Interval 215 (4280000 steps performed)
# 20000/20000 [==============================] - 316s 16ms/step - reward: 0.0832
# 17 episodes - episode_reward: 99.118 [65.000, 143.000] - loss: 0.105 - mean_absolute_error: 7.524 - mean_q: 8.562 - mean_eps: 0.100 - ale.lives: 2.198
#
# Interval 216 (4300000 steps performed)
# 20000/20000 [==============================] - 317s 16ms/step - reward: 0.0902
# 20 episodes - episode_reward: 88.800 [57.000, 126.000] - loss: 0.112 - mean_absolute_error: 7.552 - mean_q: 8.595 - mean_eps: 0.100 - ale.lives: 2.206
#
# Interval 217 (4320000 steps performed)
# 20000/20000 [==============================] - 318s 16ms/step - reward: 0.0921
# 20 episodes - episode_reward: 91.500 [64.000, 130.000] - loss: 0.105 - mean_absolute_error: 7.523 - mean_q: 8.563 - mean_eps: 0.100 - ale.lives: 2.191
#
# Interval 218 (4340000 steps performed)
# 20000/20000 [==============================] - 318s 16ms/step - reward: 0.0935
# 19 episodes - episode_reward: 97.053 [57.000, 143.000] - loss: 0.109 - mean_absolute_error: 7.535 - mean_q: 8.573 - mean_eps: 0.100 - ale.lives: 2.176
#
# Interval 219 (4360000 steps performed)
# 20000/20000 [==============================] - 317s 16ms/step - reward: 0.0885
# 19 episodes - episode_reward: 94.421 [64.000, 119.000] - loss: 0.108 - mean_absolute_error: 7.610 - mean_q: 8.659 - mean_eps: 0.100 - ale.lives: 2.186
#
# Interval 220 (4380000 steps performed)
# 20000/20000 [==============================] - 317s 16ms/step - reward: 0.0904
# 20 episodes - episode_reward: 94.400 [59.000, 118.000] - loss: 0.109 - mean_absolute_error: 7.631 - mean_q: 8.684 - mean_eps: 0.100 - ale.lives: 2.300
#
# Interval 221 (4400000 steps performed)
# 20000/20000 [==============================] - 326s 16ms/step - reward: 0.0886
# 19 episodes - episode_reward: 92.842 [69.000, 114.000] - loss: 0.109 - mean_absolute_error: 7.594 - mean_q: 8.642 - mean_eps: 0.100 - ale.lives: 2.205
#
# Interval 222 (4420000 steps performed)
# 20000/20000 [==============================] - 318s 16ms/step - reward: 0.0926
# 18 episodes - episode_reward: 99.278 [36.000, 128.000] - loss: 0.106 - mean_absolute_error: 7.574 - mean_q: 8.618 - mean_eps: 0.100 - ale.lives: 2.191
#
# Interval 223 (4440000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0915
# 20 episodes - episode_reward: 94.450 [64.000, 119.000] - loss: 0.108 - mean_absolute_error: 7.616 - mean_q: 8.667 - mean_eps: 0.100 - ale.lives: 2.163
#
# Interval 224 (4460000 steps performed)
# 20000/20000 [==============================] - 316s 16ms/step - reward: 0.08650s - rew
# 18 episodes - episode_reward: 91.556 [58.000, 119.000] - loss: 0.109 - mean_absolute_error: 7.585 - mean_q: 8.632 - mean_eps: 0.100 - ale.lives: 2.143
#
# Interval 225 (4480000 steps performed)
# 20000/20000 [==============================] - 315s 16ms/step - reward: 0.0823
# 20 episodes - episode_reward: 85.000 [51.000, 112.000] - loss: 0.103 - mean_absolute_error: 7.618 - mean_q: 8.670 - mean_eps: 0.100 - ale.lives: 2.153
#
# Interval 226 (4500000 steps performed)
# 20000/20000 [==============================] - 315s 16ms/step - reward: 0.0870
# 19 episodes - episode_reward: 89.368 [43.000, 120.000] - loss: 0.108 - mean_absolute_error: 7.633 - mean_q: 8.687 - mean_eps: 0.100 - ale.lives: 2.221
#
# Interval 227 (4520000 steps performed)
# 20000/20000 [==============================] - 316s 16ms/step - reward: 0.0914
# 21 episodes - episode_reward: 87.238 [53.000, 114.000] - loss: 0.107 - mean_absolute_error: 7.635 - mean_q: 8.690 - mean_eps: 0.100 - ale.lives: 2.175
#
# Interval 228 (4540000 steps performed)
# 20000/20000 [==============================] - 322s 16ms/step - reward: 0.0856
# 18 episodes - episode_reward: 96.722 [64.000, 122.000] - loss: 0.104 - mean_absolute_error: 7.713 - mean_q: 8.776 - mean_eps: 0.100 - ale.lives: 2.209
#
# Interval 229 (4560000 steps performed)
# 20000/20000 [==============================] - 348s 17ms/step - reward: 0.0877
# 21 episodes - episode_reward: 84.095 [51.000, 128.000] - loss: 0.107 - mean_absolute_error: 7.753 - mean_q: 8.821 - mean_eps: 0.100 - ale.lives: 2.213
#
# Interval 230 (4580000 steps performed)
# 20000/20000 [==============================] - 341s 17ms/step - reward: 0.0866
# 18 episodes - episode_reward: 94.667 [69.000, 115.000] - loss: 0.106 - mean_absolute_error: 7.739 - mean_q: 8.805 - mean_eps: 0.100 - ale.lives: 2.259
#
# Interval 231 (4600000 steps performed)
# 20000/20000 [==============================] - 339s 17ms/step - reward: 0.0824
# 18 episodes - episode_reward: 93.000 [55.000, 116.000] - loss: 0.111 - mean_absolute_error: 7.793 - mean_q: 8.865 - mean_eps: 0.100 - ale.lives: 2.123
#
# Interval 232 (4620000 steps performed)
# 20000/20000 [==============================] - 340s 17ms/step - reward: 0.0905
# 21 episodes - episode_reward: 86.619 [43.000, 117.000] - loss: 0.108 - mean_absolute_error: 7.799 - mean_q: 8.870 - mean_eps: 0.100 - ale.lives: 2.146
#
# Interval 233 (4640000 steps performed)
# 20000/20000 [==============================] - 335s 17ms/step - reward: 0.0955
# 20 episodes - episode_reward: 92.300 [55.000, 135.000] - loss: 0.110 - mean_absolute_error: 7.802 - mean_q: 8.876 - mean_eps: 0.100 - ale.lives: 2.210
#
# Interval 234 (4660000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0867
# 19 episodes - episode_reward: 92.316 [59.000, 119.000] - loss: 0.108 - mean_absolute_error: 7.835 - mean_q: 8.912 - mean_eps: 0.100 - ale.lives: 2.199
#
# Interval 235 (4680000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0895
# 20 episodes - episode_reward: 87.750 [57.000, 107.000] - loss: 0.108 - mean_absolute_error: 7.785 - mean_q: 8.855 - mean_eps: 0.100 - ale.lives: 2.156
#
# Interval 236 (4700000 steps performed)
# 20000/20000 [==============================] - 327s 16ms/step - reward: 0.0887
# 20 episodes - episode_reward: 89.600 [25.000, 122.000] - loss: 0.105 - mean_absolute_error: 7.781 - mean_q: 8.850 - mean_eps: 0.100 - ale.lives: 2.230
#
# Interval 237 (4720000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0904
# 20 episodes - episode_reward: 90.400 [42.000, 117.000] - loss: 0.102 - mean_absolute_error: 7.843 - mean_q: 8.920 - mean_eps: 0.100 - ale.lives: 2.121
#
# Interval 238 (4740000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0877
# 21 episodes - episode_reward: 84.857 [46.000, 119.000] - loss: 0.107 - mean_absolute_error: 7.864 - mean_q: 8.943 - mean_eps: 0.100 - ale.lives: 2.247
#
# Interval 239 (4760000 steps performed)
# 20000/20000 [==============================] - 322s 16ms/step - reward: 0.0890
# 19 episodes - episode_reward: 92.000 [64.000, 111.000] - loss: 0.102 - mean_absolute_error: 7.830 - mean_q: 8.904 - mean_eps: 0.100 - ale.lives: 2.235
#
# Interval 240 (4780000 steps performed)
# 20000/20000 [==============================] - 324s 16ms/step - reward: 0.0880
# 19 episodes - episode_reward: 95.158 [61.000, 120.000] - loss: 0.110 - mean_absolute_error: 7.807 - mean_q: 8.878 - mean_eps: 0.100 - ale.lives: 2.088
#
# Interval 241 (4800000 steps performed)
# 20000/20000 [==============================] - 322s 16ms/step - reward: 0.0877
# 20 episodes - episode_reward: 88.550 [49.000, 110.000] - loss: 0.104 - mean_absolute_error: 7.789 - mean_q: 8.859 - mean_eps: 0.100 - ale.lives: 2.227
#
# Interval 242 (4820000 steps performed)
# 20000/20000 [==============================] - 320s 16ms/step - reward: 0.0917
# 21 episodes - episode_reward: 86.286 [43.000, 119.000] - loss: 0.107 - mean_absolute_error: 7.767 - mean_q: 8.834 - mean_eps: 0.100 - ale.lives: 2.222
#
# Interval 243 (4840000 steps performed)
# 20000/20000 [==============================] - 329s 16ms/step - reward: 0.0888
# 20 episodes - episode_reward: 89.050 [42.000, 115.000] - loss: 0.103 - mean_absolute_error: 7.774 - mean_q: 8.841 - mean_eps: 0.100 - ale.lives: 2.228
#
# Interval 244 (4860000 steps performed)
# 20000/20000 [==============================] - 333s 17ms/step - reward: 0.0898
# 20 episodes - episode_reward: 91.600 [56.000, 116.000] - loss: 0.102 - mean_absolute_error: 7.722 - mean_q: 8.782 - mean_eps: 0.100 - ale.lives: 2.220
#
# Interval 245 (4880000 steps performed)
# 20000/20000 [==============================] - 325s 16ms/step - reward: 0.0954
# 20 episodes - episode_reward: 94.750 [33.000, 118.000] - loss: 0.103 - mean_absolute_error: 7.689 - mean_q: 8.744 - mean_eps: 0.100 - ale.lives: 2.249
#
# Interval 246 (4900000 steps performed)
# 20000/20000 [==============================] - 332s 17ms/step - reward: 0.0882
# 19 episodes - episode_reward: 88.947 [64.000, 122.000] - loss: 0.105 - mean_absolute_error: 7.693 - mean_q: 8.750 - mean_eps: 0.100 - ale.lives: 2.178
#
# Interval 247 (4920000 steps performed)
# 20000/20000 [==============================] - 331s 17ms/step - reward: 0.0920
# 21 episodes - episode_reward: 92.429 [55.000, 125.000] - loss: 0.104 - mean_absolute_error: 7.683 - mean_q: 8.737 - mean_eps: 0.100 - ale.lives: 2.251
#
# Interval 248 (4940000 steps performed)
# 20000/20000 [==============================] - 330s 16ms/step - reward: 0.0901
# 20 episodes - episode_reward: 85.500 [53.000, 117.000] - loss: 0.102 - mean_absolute_error: 7.662 - mean_q: 8.712 - mean_eps: 0.100 - ale.lives: 2.169
#
# Interval 249 (4960000 steps performed)
# 20000/20000 [==============================] - 328s 16ms/step - reward: 0.0914
# 21 episodes - episode_reward: 90.000 [43.000, 121.000] - loss: 0.097 - mean_absolute_error: 7.699 - mean_q: 8.757 - mean_eps: 0.100 - ale.lives: 2.250
#
# Interval 250 (4980000 steps performed)
# 20000/20000 [==============================] - 330s 17ms/step - reward: 0.0891
# done, took 78885.124 seconds
# Testing for 10 episodes ...
# Episode 1: reward: 72.000, steps: 925
# Episode 2: reward: 37.000, steps: 492
# Episode 3: reward: 43.000, steps: 522
# Episode 4: reward: 106.000, steps: 1019
# Episode 5: reward: 105.000, steps: 1116
# Episode 6: reward: 99.000, steps: 1148
# Episode 7: reward: 97.000, steps: 1284
# Episode 8: reward: 126.000, steps: 1624
# Episode 9: reward: 98.000, steps: 1114
# Episode 10: reward: 78.000, steps: 994

# %%
#Training Performance
plt.plot(history.history['episode_reward'])
plt.title('DQN Performance')
plt.ylabel('Reward')
plt.xlabel('Episode')
plt.show()

# %%
#Test
#Atari Testing Processor (Change Reward Metric)
class AtariProcessor_test(Processor):
    
    def process_observation(self, observation):
        # Crop
        img = observation[1:176:2, ::2]
        # Convert the image to greyscale
        img = np.dot(img[...,:3], [0.299, 0.587, 0.144])
        # Resize
        img = img.reshape(INPUT_SHAPE)
        return img.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return reward

weights_filename = 'dqn_{}_weights.h5f'.format(ENV_NAME)

processor = AtariProcessor_test()
dqn = DQNAgent(model=model, nb_actions=n_actions, policy=policy, memory=memory, processor=processor, nb_steps_warmup=start_steps, 
               gamma=discount_factor, target_model_update=batch,train_interval=steps_train, delta_clip=1.)
dqn.compile(Adam(lr=learning_rate), metrics=['mae'])


dqn.load_weights(weights_filename)
history2 = dqn.test(env, nb_episodes=100, visualize=False)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 110.000, steps: 712
# Episode 2: reward: 380.000, steps: 809
# Episode 3: reward: 810.000, steps: 852
# Episode 4: reward: 850.000, steps: 956
# Episode 5: reward: 110.000, steps: 702
# Episode 6: reward: 210.000, steps: 887
# Episode 7: reward: 250.000, steps: 852
# Episode 8: reward: 250.000, steps: 799
# Episode 9: reward: 230.000, steps: 852
# Episode 10: reward: 430.000, steps: 904
# Episode 11: reward: 410.000, steps: 776
# Episode 12: reward: 110.000, steps: 709
# Episode 13: reward: 380.000, steps: 804
# Episode 14: reward: 210.000, steps: 886
# Episode 15: reward: 810.000, steps: 851
# Episode 16: reward: 250.000, steps: 929
# Episode 17: reward: 110.000, steps: 716
# Episode 18: reward: 430.000, steps: 862
# Episode 19: reward: 230.000, steps: 805
# Episode 20: reward: 380.000, steps: 798
# Episode 21: reward: 210.000, steps: 1150
# Episode 22: reward: 230.000, steps: 834
# Episode 23: reward: 450.000, steps: 866
# Episode 24: reward: 230.000, steps: 1121
# Episode 25: reward: 110.000, steps: 711
# Episode 26: reward: 230.000, steps: 1007
# Episode 27: reward: 110.000, steps: 703
# Episode 28: reward: 110.000, steps: 701
# Episode 29: reward: 110.000, steps: 717
# Episode 30: reward: 110.000, steps: 711
# Episode 31: reward: 110.000, steps: 706
# Episode 32: reward: 850.000, steps: 944
# Episode 33: reward: 110.000, steps: 718
# Episode 34: reward: 250.000, steps: 795
# Episode 35: reward: 210.000, steps: 894
# Episode 36: reward: 210.000, steps: 882
# Episode 37: reward: 450.000, steps: 819
# Episode 38: reward: 850.000, steps: 951
# Episode 39: reward: 380.000, steps: 949
# Episode 40: reward: 110.000, steps: 699
# Episode 41: reward: 250.000, steps: 796
# Episode 42: reward: 250.000, steps: 882
# Episode 43: reward: 110.000, steps: 714
# Episode 44: reward: 110.000, steps: 705
# Episode 45: reward: 110.000, steps: 707
# Episode 46: reward: 230.000, steps: 788
# Episode 47: reward: 250.000, steps: 793
# Episode 48: reward: 250.000, steps: 780
# Episode 49: reward: 250.000, steps: 792
# Episode 50: reward: 430.000, steps: 857
# Episode 51: reward: 210.000, steps: 862
# Episode 52: reward: 70.000, steps: 715
# Episode 53: reward: 110.000, steps: 721
# Episode 54: reward: 230.000, steps: 912
# Episode 55: reward: 230.000, steps: 1110
# Episode 56: reward: 430.000, steps: 864
# Episode 57: reward: 110.000, steps: 709
# Episode 58: reward: 210.000, steps: 910
# Episode 59: reward: 210.000, steps: 847
# Episode 60: reward: 210.000, steps: 897
# Episode 61: reward: 250.000, steps: 803
# Episode 62: reward: 430.000, steps: 875
# Episode 63: reward: 380.000, steps: 773
# Episode 64: reward: 110.000, steps: 713
# Episode 65: reward: 230.000, steps: 813
# Episode 66: reward: 230.000, steps: 1014
# Episode 67: reward: 110.000, steps: 711
# Episode 68: reward: 210.000, steps: 870
# Episode 69: reward: 230.000, steps: 946
# Episode 70: reward: 810.000, steps: 850
# Episode 71: reward: 180.000, steps: 740
# Episode 72: reward: 210.000, steps: 896
# Episode 73: reward: 110.000, steps: 694
# Episode 74: reward: 180.000, steps: 1010
# Episode 75: reward: 110.000, steps: 700
# Episode 76: reward: 180.000, steps: 1019
# Episode 77: reward: 250.000, steps: 794
# Episode 78: reward: 430.000, steps: 852
# Episode 79: reward: 210.000, steps: 799
# Episode 80: reward: 110.000, steps: 704
# Episode 81: reward: 250.000, steps: 858
# Episode 82: reward: 250.000, steps: 890
# Episode 83: reward: 70.000, steps: 703
# Episode 84: reward: 180.000, steps: 792
# Episode 85: reward: 210.000, steps: 890
# Episode 86: reward: 380.000, steps: 795
# Episode 87: reward: 250.000, steps: 917
# Episode 88: reward: 70.000, steps: 706
# Episode 89: reward: 180.000, steps: 809
# Episode 90: reward: 250.000, steps: 785
# Episode 91: reward: 110.000, steps: 708
# Episode 92: reward: 250.000, steps: 886
# Episode 93: reward: 210.000, steps: 1068
# Episode 94: reward: 380.000, steps: 792
# Episode 95: reward: 210.000, steps: 924
# Episode 96: reward: 110.000, steps: 710
# Episode 97: reward: 210.000, steps: 1023
# Episode 98: reward: 230.000, steps: 1132
# Episode 99: reward: 430.000, steps: 879
# Episode 100: reward: 230.000, steps: 954

# %%
import statistics 

#Testing Plot
plt.plot(history2.history['episode_reward'])
plt.title('DQN Gameplay Performance')
plt.ylabel('Score')
plt.xlabel('Episode')
plt.show()

print("Average Score: ", statistics.mean(history2.history['episode_reward']))
print("Standard Deviation: ", statistics.stdev(history2.history['episode_reward']))
print("Average Steps Taken Per Episode: ", statistics.mean(history2.history['nb_steps']))
# Out:
# Average Score:  260.6
# Standard Deviation:  176.47399442147477
# Average Steps Taken Per Episode:  834.97
