# %%
from __future__ import division
import argparse

from PIL import Image
from PIL import ImageFilter
import numpy as np
import gym
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from keras.optimizers import Adam
from keras.optimizers import SGD
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

import random
from datetime import datetime
import matplotlib.pyplot as plt

INPUT_SHAPE = (88, 80)
WINDOW_LENGTH = 4
ENV_NAME = 'MsPacman-v4'
# Out:
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
#Atari Processor
class AtariProcessor(Processor):
    
    def process_observation(self, observation):
        # Crop
        img = observation[1:176:2, ::2]
        # Convert the image to greyscale
        img = np.dot(img[...,:3], [0.299, 0.587, 0.144])
        # Resize
        img = img.reshape(INPUT_SHAPE)
        return img.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return reward

# %%
#Make Environment
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)
n_actions = env.action_space.n
print("Number of Actions:", n_actions)
print(env.env.get_action_meanings())
observation = env.reset()

print("\n\nObserved Starting Position")
plt.imshow(observation)
plt.show() #show initial state

print("Preprocessed Starting Position")
plt.imshow(AtariProcessor.process_observation('',observation))
plt.show() #show preprocessed initial state
# Out:
# Number of Actions: 9
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']
#
#
# Observed Starting Position
# Preprocessed Starting Position

# %%
# Using the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
if K.image_dim_ordering() == 'tf':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_dim_ordering() == 'th':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(n_actions))
model.add(Activation('linear'))
print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 88, 80, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 19, 32)        8224
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 19, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 8, 64)          32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 6, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2688)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1376768
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 4617
# _________________________________________________________________
# activation_5 (Activation)    (None, 9)                 0
# =================================================================
# Total params: 1,459,369
# Trainable params: 1,459,369
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Hyperparameters
num_steps = 5000000
learning_rate = 0.001
discount_factor = 0.99
steps_train = 4
start_steps = 2000
eps_min = 0.05 #End with 0.05 epsilon (explore less)
eps_max = 0.65 #Start with 0.65 epsilon (explore more)
eps_decay_steps = 4500000
batch = 25000

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

#DecayingEpsilon
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=eps_max, value_min=eps_min, value_test=.05,
                              nb_steps=eps_decay_steps)

dqn = DQNAgent(model=model, nb_actions=n_actions, policy=policy, memory=memory, processor=processor, nb_steps_warmup=start_steps, 
               gamma=discount_factor, target_model_update=batch,train_interval=steps_train, delta_clip=1.)

dqn.compile(Adam(lr=learning_rate), metrics=['mae'])
# Out:
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\rl\util.py:79: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#Train

weights_filename = 'dqn_{}_weights.h5f'.format(ENV_NAME)

checkpoint_weights_filename = 'dqn_' + ENV_NAME + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(ENV_NAME)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=500000)]
callbacks += [FileLogger(log_filename, interval=100)]
 

history = dqn.fit(env, callbacks=callbacks, nb_steps=num_steps, log_interval=batch)

# After training is done, we save the final weights one more time.
dqn.save_weights(weights_filename, overwrite=True)

# Finally, evaluate our algorithm for 10 episodes.
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Training for 5000000 steps ...
# Interval 1 (0 steps performed)
# 25000/25000 [==============================] - 268s 11ms/step - reward: 0.5432
# 35 episodes - episode_reward: 384.000 [150.000, 1180.000] - loss: 0.523 - mean_absolute_error: 0.125 - mean_q: 0.087 - mean_eps: 0.648 - ale.lives: 2.090
#
# Interval 2 (25000 steps performed)
# 25000/25000 [==============================] - 276s 11ms/step - reward: 0.6608
# 32 episodes - episode_reward: 511.562 [170.000, 1970.000] - loss: 0.577 - mean_absolute_error: 0.173 - mean_q: 0.127 - mean_eps: 0.645 - ale.lives: 1.996
#
# Interval 3 (50000 steps performed)
# 25000/25000 [==============================] - 281s 11ms/step - reward: 0.64280s -
# 31 episodes - episode_reward: 489.677 [250.000, 1750.000] - loss: 0.568 - mean_absolute_error: 0.217 - mean_q: 0.179 - mean_eps: 0.642 - ale.lives: 1.998
#
# Interval 4 (75000 steps performed)
# 25000/25000 [==============================] - 283s 11ms/step - reward: 0.66640s - reward: 0.66
# 32 episodes - episode_reward: 554.375 [150.000, 1790.000] - loss: 0.602 - mean_absolute_error: 0.263 - mean_q: 0.225 - mean_eps: 0.638 - ale.lives: 2.031
#
# Interval 5 (100000 steps performed)
# 25000/25000 [==============================] - 284s 11ms/step - reward: 0.6352
# 33 episodes - episode_reward: 461.212 [100.000, 1840.000] - loss: 0.574 - mean_absolute_error: 0.305 - mean_q: 0.277 - mean_eps: 0.635 - ale.lives: 2.072
#
# Interval 6 (125000 steps performed)
# 25000/25000 [==============================] - 284s 11ms/step - reward: 0.5980
# 35 episodes - episode_reward: 446.857 [110.000, 1170.000] - loss: 0.573 - mean_absolute_error: 0.355 - mean_q: 0.332 - mean_eps: 0.632 - ale.lives: 2.100
#
# Interval 7 (150000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.5592
# 35 episodes - episode_reward: 378.286 [130.000, 1030.000] - loss: 0.609 - mean_absolute_error: 0.406 - mean_q: 0.385 - mean_eps: 0.628 - ale.lives: 2.051
#
# Interval 8 (175000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.5464
# 33 episodes - episode_reward: 435.455 [90.000, 2260.000] - loss: 0.573 - mean_absolute_error: 0.437 - mean_q: 0.424 - mean_eps: 0.625 - ale.lives: 2.107
#
# Interval 9 (200000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.5648
# 33 episodes - episode_reward: 421.212 [90.000, 990.000] - loss: 0.604 - mean_absolute_error: 0.482 - mean_q: 0.472 - mean_eps: 0.622 - ale.lives: 2.087
#
# Interval 10 (225000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.5536
# 33 episodes - episode_reward: 404.545 [190.000, 1040.000] - loss: 0.569 - mean_absolute_error: 0.519 - mean_q: 0.518 - mean_eps: 0.618 - ale.lives: 2.094
#
# Interval 11 (250000 steps performed)
# 25000/25000 [==============================] - 289s 12ms/step - reward: 0.5464
# 35 episodes - episode_reward: 408.857 [190.000, 1340.000] - loss: 0.567 - mean_absolute_error: 0.555 - mean_q: 0.558 - mean_eps: 0.615 - ale.lives: 2.054
#
# Interval 12 (275000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.5088
# 35 episodes - episode_reward: 356.571 [110.000, 880.000] - loss: 0.569 - mean_absolute_error: 0.598 - mean_q: 0.606 - mean_eps: 0.612 - ale.lives: 2.114
#
# Interval 13 (300000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.7344
# 31 episodes - episode_reward: 591.935 [110.000, 1800.000] - loss: 0.562 - mean_absolute_error: 0.636 - mean_q: 0.651 - mean_eps: 0.608 - ale.lives: 2.047
#
# Interval 14 (325000 steps performed)
# 25000/25000 [==============================] - 290s 12ms/step - reward: 0.5364
# 34 episodes - episode_reward: 376.471 [140.000, 1000.000] - loss: 0.555 - mean_absolute_error: 0.669 - mean_q: 0.690 - mean_eps: 0.605 - ale.lives: 2.077
#
# Interval 15 (350000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.62840s - reward: 0.6
# 34 episodes - episode_reward: 486.471 [120.000, 1850.000] - loss: 0.565 - mean_absolute_error: 0.707 - mean_q: 0.731 - mean_eps: 0.602 - ale.lives: 2.058
#
# Interval 16 (375000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.6272
# 32 episodes - episode_reward: 491.562 [150.000, 1740.000] - loss: 0.573 - mean_absolute_error: 0.742 - mean_q: 0.768 - mean_eps: 0.598 - ale.lives: 2.056
#
# Interval 17 (400000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.5984
# 32 episodes - episode_reward: 465.938 [230.000, 1050.000] - loss: 0.599 - mean_absolute_error: 0.785 - mean_q: 0.813 - mean_eps: 0.595 - ale.lives: 2.065
#
# Interval 18 (425000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.6956
# 31 episodes - episode_reward: 545.484 [110.000, 1510.000] - loss: 0.594 - mean_absolute_error: 0.815 - mean_q: 0.848 - mean_eps: 0.592 - ale.lives: 2.120
#
# Interval 19 (450000 steps performed)
# 25000/25000 [==============================] - 315s 13ms/step - reward: 0.5296
# 34 episodes - episode_reward: 405.000 [200.000, 970.000] - loss: 0.575 - mean_absolute_error: 0.849 - mean_q: 0.888 - mean_eps: 0.588 - ale.lives: 2.051
#
# Interval 20 (475000 steps performed)
# 25000/25000 [==============================] - 327s 13ms/step - reward: 0.6208
# 33 episodes - episode_reward: 468.485 [160.000, 1450.000] - loss: 0.596 - mean_absolute_error: 0.890 - mean_q: 0.931 - mean_eps: 0.585 - ale.lives: 2.065
#
# Interval 21 (500000 steps performed)
# 25000/25000 [==============================] - 329s 13ms/step - reward: 0.7044
# 30 episodes - episode_reward: 567.667 [130.000, 1750.000] - loss: 0.566 - mean_absolute_error: 0.922 - mean_q: 0.972 - mean_eps: 0.582 - ale.lives: 2.039
#
# Interval 22 (525000 steps performed)
# 25000/25000 [==============================] - 345s 14ms/step - reward: 0.6212
# 32 episodes - episode_reward: 506.250 [140.000, 1980.000] - loss: 0.582 - mean_absolute_error: 0.963 - mean_q: 1.017 - mean_eps: 0.578 - ale.lives: 2.095
#
# Interval 23 (550000 steps performed)
# 25000/25000 [==============================] - 330s 13ms/step - reward: 0.5620
# 35 episodes - episode_reward: 398.286 [130.000, 1310.000] - loss: 0.579 - mean_absolute_error: 0.997 - mean_q: 1.055 - mean_eps: 0.575 - ale.lives: 2.057
#
# Interval 24 (575000 steps performed)
# 25000/25000 [==============================] - 306s 12ms/step - reward: 0.68521s
# 29 episodes - episode_reward: 594.483 [160.000, 2210.000] - loss: 0.589 - mean_absolute_error: 1.029 - mean_q: 1.089 - mean_eps: 0.572 - ale.lives: 2.113
#
# Interval 25 (600000 steps performed)
# 25000/25000 [==============================] - 306s 12ms/step - reward: 0.5604
# 35 episodes - episode_reward: 401.143 [90.000, 1070.000] - loss: 0.586 - mean_absolute_error: 1.061 - mean_q: 1.125 - mean_eps: 0.568 - ale.lives: 2.118
#
# Interval 26 (625000 steps performed)
# 25000/25000 [==============================] - 306s 12ms/step - reward: 0.5568
# 35 episodes - episode_reward: 396.286 [80.000, 1680.000] - loss: 0.584 - mean_absolute_error: 1.096 - mean_q: 1.164 - mean_eps: 0.565 - ale.lives: 2.078
#
# Interval 27 (650000 steps performed)
# 25000/25000 [==============================] - 311s 12ms/step - reward: 0.6132
# 32 episodes - episode_reward: 474.062 [130.000, 1650.000] - loss: 0.596 - mean_absolute_error: 1.128 - mean_q: 1.200 - mean_eps: 0.562 - ale.lives: 2.075
#
# Interval 28 (675000 steps performed)
# 25000/25000 [==============================] - 308s 12ms/step - reward: 0.6756
# 31 episodes - episode_reward: 534.516 [230.000, 1280.000] - loss: 0.579 - mean_absolute_error: 1.157 - mean_q: 1.234 - mean_eps: 0.558 - ale.lives: 2.096
#
# Interval 29 (700000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.6516
# 33 episodes - episode_reward: 502.727 [170.000, 1900.000] - loss: 0.615 - mean_absolute_error: 1.185 - mean_q: 1.261 - mean_eps: 0.555 - ale.lives: 2.082
#
# Interval 30 (725000 steps performed)
# 25000/25000 [==============================] - 299s 12ms/step - reward: 0.5444
# 35 episodes - episode_reward: 397.714 [160.000, 1250.000] - loss: 0.569 - mean_absolute_error: 1.205 - mean_q: 1.290 - mean_eps: 0.552 - ale.lives: 2.111
#
# Interval 31 (750000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.6660
# 32 episodes - episode_reward: 511.562 [120.000, 1720.000] - loss: 0.554 - mean_absolute_error: 1.243 - mean_q: 1.333 - mean_eps: 0.548 - ale.lives: 2.118
#
# Interval 32 (775000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.6944
# 30 episodes - episode_reward: 576.000 [190.000, 2040.000] - loss: 0.568 - mean_absolute_error: 1.275 - mean_q: 1.369 - mean_eps: 0.545 - ale.lives: 2.049
#
# Interval 33 (800000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.6600
# 33 episodes - episode_reward: 506.364 [160.000, 1210.000] - loss: 0.565 - mean_absolute_error: 1.306 - mean_q: 1.404 - mean_eps: 0.542 - ale.lives: 2.027
#
# Interval 34 (825000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.62361
# 30 episodes - episode_reward: 524.333 [60.000, 1070.000] - loss: 0.580 - mean_absolute_error: 1.329 - mean_q: 1.427 - mean_eps: 0.538 - ale.lives: 2.055
#
# Interval 35 (850000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.6800
# 31 episodes - episode_reward: 531.290 [100.000, 1880.000] - loss: 0.572 - mean_absolute_error: 1.352 - mean_q: 1.455 - mean_eps: 0.535 - ale.lives: 2.045
#
# Interval 36 (875000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.59640s - rew
# 35 episodes - episode_reward: 431.429 [80.000, 1390.000] - loss: 0.572 - mean_absolute_error: 1.377 - mean_q: 1.482 - mean_eps: 0.532 - ale.lives: 2.085
#
# Interval 37 (900000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.58360s - re - ETA: 0s - reward: 0.58
# 33 episodes - episode_reward: 447.273 [190.000, 1200.000] - loss: 0.576 - mean_absolute_error: 1.401 - mean_q: 1.510 - mean_eps: 0.528 - ale.lives: 2.085
#
# Interval 38 (925000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6476
# 34 episodes - episode_reward: 470.294 [210.000, 1710.000] - loss: 0.606 - mean_absolute_error: 1.443 - mean_q: 1.552 - mean_eps: 0.525 - ale.lives: 2.142
#
# Interval 39 (950000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6660
# 32 episodes - episode_reward: 518.125 [140.000, 1030.000] - loss: 0.596 - mean_absolute_error: 1.476 - mean_q: 1.591 - mean_eps: 0.522 - ale.lives: 2.049
#
# Interval 40 (975000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.60520s - reward
# 34 episodes - episode_reward: 448.824 [90.000, 1100.000] - loss: 0.586 - mean_absolute_error: 1.501 - mean_q: 1.620 - mean_eps: 0.518 - ale.lives: 2.064
#
# Interval 41 (1000000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.6212
# 33 episodes - episode_reward: 471.515 [120.000, 1290.000] - loss: 0.605 - mean_absolute_error: 1.527 - mean_q: 1.647 - mean_eps: 0.515 - ale.lives: 2.113
#
# Interval 42 (1025000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6256
# 32 episodes - episode_reward: 495.625 [200.000, 1210.000] - loss: 0.594 - mean_absolute_error: 1.565 - mean_q: 1.691 - mean_eps: 0.512 - ale.lives: 2.092
#
# Interval 43 (1050000 steps performed)
# 25000/25000 [==============================] - 299s 12ms/step - reward: 0.59280s - reward: 0.59
# 33 episodes - episode_reward: 448.788 [150.000, 1180.000] - loss: 0.564 - mean_absolute_error: 1.592 - mean_q: 1.725 - mean_eps: 0.508 - ale.lives: 2.099
#
# Interval 44 (1075000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.67680s - reward: - ETA: 0s - reward: 0
# 31 episodes - episode_reward: 532.581 [120.000, 2260.000] - loss: 0.595 - mean_absolute_error: 1.631 - mean_q: 1.766 - mean_eps: 0.505 - ale.lives: 2.129
#
# Interval 45 (1100000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.6752
# 34 episodes - episode_reward: 498.235 [170.000, 1440.000] - loss: 0.578 - mean_absolute_error: 1.667 - mean_q: 1.807 - mean_eps: 0.502 - ale.lives: 2.034
#
# Interval 46 (1125000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.8048
# 31 episodes - episode_reward: 660.968 [190.000, 3440.000] - loss: 0.618 - mean_absolute_error: 1.698 - mean_q: 1.838 - mean_eps: 0.498 - ale.lives: 2.057
#
# Interval 47 (1150000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.7604
# 31 episodes - episode_reward: 608.710 [160.000, 2530.000] - loss: 0.589 - mean_absolute_error: 1.731 - mean_q: 1.881 - mean_eps: 0.495 - ale.lives: 2.030
#
# Interval 48 (1175000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.7044
# 31 episodes - episode_reward: 547.419 [150.000, 1460.000] - loss: 0.603 - mean_absolute_error: 1.755 - mean_q: 1.904 - mean_eps: 0.492 - ale.lives: 2.088
#
# Interval 49 (1200000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.71840s - re
# 33 episodes - episode_reward: 561.515 [120.000, 1150.000] - loss: 0.594 - mean_absolute_error: 1.773 - mean_q: 1.925 - mean_eps: 0.488 - ale.lives: 2.090
#
# Interval 50 (1225000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.6752
# 32 episodes - episode_reward: 528.125 [260.000, 1340.000] - loss: 0.609 - mean_absolute_error: 1.804 - mean_q: 1.958 - mean_eps: 0.485 - ale.lives: 2.085
#
# Interval 51 (1250000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.6256
# 32 episodes - episode_reward: 492.188 [230.000, 1090.000] - loss: 0.617 - mean_absolute_error: 1.831 - mean_q: 1.989 - mean_eps: 0.482 - ale.lives: 2.107
#
# Interval 52 (1275000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7476
# 31 episodes - episode_reward: 590.645 [130.000, 1900.000] - loss: 0.616 - mean_absolute_error: 1.864 - mean_q: 2.026 - mean_eps: 0.478 - ale.lives: 2.073
#
# Interval 53 (1300000 steps performed)
# 25000/25000 [==============================] - 309s 12ms/step - reward: 0.7700
# 33 episodes - episode_reward: 597.273 [240.000, 1370.000] - loss: 0.632 - mean_absolute_error: 1.899 - mean_q: 2.063 - mean_eps: 0.475 - ale.lives: 2.084
#
# Interval 54 (1325000 steps performed)
# 25000/25000 [==============================] - 310s 12ms/step - reward: 0.6076
# 34 episodes - episode_reward: 446.765 [110.000, 940.000] - loss: 0.591 - mean_absolute_error: 1.927 - mean_q: 2.100 - mean_eps: 0.472 - ale.lives: 2.068
#
# Interval 55 (1350000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.8844
# 32 episodes - episode_reward: 692.812 [120.000, 2150.000] - loss: 0.651 - mean_absolute_error: 1.970 - mean_q: 2.140 - mean_eps: 0.468 - ale.lives: 2.108
#
# Interval 56 (1375000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7360
# 32 episodes - episode_reward: 570.312 [150.000, 2110.000] - loss: 0.640 - mean_absolute_error: 2.002 - mean_q: 2.178 - mean_eps: 0.465 - ale.lives: 2.107
#
# Interval 57 (1400000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6664
# 31 episodes - episode_reward: 537.097 [180.000, 1780.000] - loss: 0.635 - mean_absolute_error: 2.023 - mean_q: 2.201 - mean_eps: 0.462 - ale.lives: 2.082
#
# Interval 58 (1425000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7196
# 30 episodes - episode_reward: 594.000 [150.000, 1810.000] - loss: 0.636 - mean_absolute_error: 2.051 - mean_q: 2.233 - mean_eps: 0.458 - ale.lives: 2.115
#
# Interval 59 (1450000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.7004
# 33 episodes - episode_reward: 540.606 [150.000, 1120.000] - loss: 0.638 - mean_absolute_error: 2.084 - mean_q: 2.270 - mean_eps: 0.455 - ale.lives: 2.011
#
# Interval 60 (1475000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.8300
# 28 episodes - episode_reward: 723.571 [220.000, 2450.000] - loss: 0.649 - mean_absolute_error: 2.121 - mean_q: 2.310 - mean_eps: 0.452 - ale.lives: 2.051
#
# Interval 61 (1500000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.6980
# 33 episodes - episode_reward: 543.636 [90.000, 1580.000] - loss: 0.676 - mean_absolute_error: 2.166 - mean_q: 2.358 - mean_eps: 0.448 - ale.lives: 2.089
#
# Interval 62 (1525000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.6904
# 32 episodes - episode_reward: 533.438 [190.000, 1040.000] - loss: 0.646 - mean_absolute_error: 2.201 - mean_q: 2.401 - mean_eps: 0.445 - ale.lives: 2.120
#
# Interval 63 (1550000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.7204
# 31 episodes - episode_reward: 570.323 [50.000, 1500.000] - loss: 0.643 - mean_absolute_error: 2.221 - mean_q: 2.424 - mean_eps: 0.442 - ale.lives: 2.085
#
# Interval 64 (1575000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.6740
# 35 episodes - episode_reward: 496.286 [70.000, 1530.000] - loss: 0.652 - mean_absolute_error: 2.250 - mean_q: 2.455 - mean_eps: 0.438 - ale.lives: 2.052
#
# Interval 65 (1600000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.6596
# 31 episodes - episode_reward: 518.065 [130.000, 1140.000] - loss: 0.623 - mean_absolute_error: 2.270 - mean_q: 2.481 - mean_eps: 0.435 - ale.lives: 2.101
#
# Interval 66 (1625000 steps performed)
# 25000/25000 [==============================] - 306s 12ms/step - reward: 0.8192
# 29 episodes - episode_reward: 714.828 [230.000, 2320.000] - loss: 0.706 - mean_absolute_error: 2.301 - mean_q: 2.506 - mean_eps: 0.432 - ale.lives: 2.082
#
# Interval 67 (1650000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7712
# 33 episodes - episode_reward: 587.879 [140.000, 1350.000] - loss: 0.653 - mean_absolute_error: 2.317 - mean_q: 2.530 - mean_eps: 0.428 - ale.lives: 2.109
#
# Interval 68 (1675000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7816
# 31 episodes - episode_reward: 617.097 [80.000, 2090.000] - loss: 0.664 - mean_absolute_error: 2.348 - mean_q: 2.565 - mean_eps: 0.425 - ale.lives: 2.097
#
# Interval 69 (1700000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6752
# 32 episodes - episode_reward: 533.125 [160.000, 1420.000] - loss: 0.664 - mean_absolute_error: 2.376 - mean_q: 2.595 - mean_eps: 0.422 - ale.lives: 2.048
#
# Interval 70 (1725000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7708
# 30 episodes - episode_reward: 621.000 [210.000, 1210.000] - loss: 0.650 - mean_absolute_error: 2.397 - mean_q: 2.621 - mean_eps: 0.418 - ale.lives: 2.109
#
# Interval 71 (1750000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6856
# 33 episodes - episode_reward: 534.848 [120.000, 1170.000] - loss: 0.693 - mean_absolute_error: 2.431 - mean_q: 2.655 - mean_eps: 0.415 - ale.lives: 2.126
#
# Interval 72 (1775000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.7076
# 30 episodes - episode_reward: 599.000 [200.000, 1410.000] - loss: 0.655 - mean_absolute_error: 2.443 - mean_q: 2.671 - mean_eps: 0.412 - ale.lives: 2.062
#
# Interval 73 (1800000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.66562 -
# 32 episodes - episode_reward: 510.938 [210.000, 1160.000] - loss: 0.681 - mean_absolute_error: 2.476 - mean_q: 2.706 - mean_eps: 0.408 - ale.lives: 2.144
#
# Interval 74 (1825000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7812
# 29 episodes - episode_reward: 672.759 [320.000, 2330.000] - loss: 0.683 - mean_absolute_error: 2.503 - mean_q: 2.737 - mean_eps: 0.405 - ale.lives: 1.964
#
# Interval 75 (1850000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7212
# 34 episodes - episode_reward: 543.529 [230.000, 1030.000] - loss: 0.673 - mean_absolute_error: 2.531 - mean_q: 2.771 - mean_eps: 0.402 - ale.lives: 2.103
#
# Interval 76 (1875000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7964
# 31 episodes - episode_reward: 624.839 [190.000, 1730.000] - loss: 0.674 - mean_absolute_error: 2.551 - mean_q: 2.792 - mean_eps: 0.398 - ale.lives: 2.170
#
# Interval 77 (1900000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7164
# 33 episodes - episode_reward: 557.576 [130.000, 1520.000] - loss: 0.661 - mean_absolute_error: 2.569 - mean_q: 2.813 - mean_eps: 0.395 - ale.lives: 2.136
#
# Interval 78 (1925000 steps performed)
# 25000/25000 [==============================] - 305s 12ms/step - reward: 0.7344
# 32 episodes - episode_reward: 567.812 [130.000, 1670.000] - loss: 0.686 - mean_absolute_error: 2.596 - mean_q: 2.842 - mean_eps: 0.392 - ale.lives: 2.061
#
# Interval 79 (1950000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6316
# 34 episodes - episode_reward: 463.824 [160.000, 1260.000] - loss: 0.680 - mean_absolute_error: 2.622 - mean_q: 2.870 - mean_eps: 0.388 - ale.lives: 2.082
#
# Interval 80 (1975000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6936
# 34 episodes - episode_reward: 517.647 [170.000, 1260.000] - loss: 0.737 - mean_absolute_error: 2.643 - mean_q: 2.886 - mean_eps: 0.385 - ale.lives: 2.093
#
# Interval 81 (2000000 steps performed)
# 25000/25000 [==============================] - 302s 12ms/step - reward: 0.7276
# 30 episodes - episode_reward: 595.667 [90.000, 1800.000] - loss: 0.676 - mean_absolute_error: 2.660 - mean_q: 2.914 - mean_eps: 0.382 - ale.lives: 2.086
#
# Interval 82 (2025000 steps performed)
# 25000/25000 [==============================] - 307s 12ms/step - reward: 0.7240
# 33 episodes - episode_reward: 552.424 [250.000, 1380.000] - loss: 0.687 - mean_absolute_error: 2.688 - mean_q: 2.944 - mean_eps: 0.378 - ale.lives: 2.040
#
# Interval 83 (2050000 steps performed)
# 25000/25000 [==============================] - 310s 12ms/step - reward: 0.8020
# 29 episodes - episode_reward: 680.690 [190.000, 1500.000] - loss: 0.682 - mean_absolute_error: 2.709 - mean_q: 2.968 - mean_eps: 0.375 - ale.lives: 2.117
#
# Interval 84 (2075000 steps performed)
# 25000/25000 [==============================] - 302s 12ms/step - reward: 0.7248
# 31 episodes - episode_reward: 586.774 [140.000, 1320.000] - loss: 0.688 - mean_absolute_error: 2.729 - mean_q: 2.989 - mean_eps: 0.372 - ale.lives: 2.111
#
# Interval 85 (2100000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.6388
# 34 episodes - episode_reward: 475.294 [170.000, 960.000] - loss: 0.714 - mean_absolute_error: 2.762 - mean_q: 3.024 - mean_eps: 0.368 - ale.lives: 2.112
#
# Interval 86 (2125000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7192
# 32 episodes - episode_reward: 562.188 [150.000, 1470.000] - loss: 0.712 - mean_absolute_error: 2.794 - mean_q: 3.060 - mean_eps: 0.365 - ale.lives: 2.150
#
# Interval 87 (2150000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7796
# 33 episodes - episode_reward: 590.000 [240.000, 2070.000] - loss: 0.672 - mean_absolute_error: 2.801 - mean_q: 3.072 - mean_eps: 0.362 - ale.lives: 2.061
#
# Interval 88 (2175000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7280
# 33 episodes - episode_reward: 545.152 [210.000, 2030.000] - loss: 0.716 - mean_absolute_error: 2.829 - mean_q: 3.100 - mean_eps: 0.358 - ale.lives: 2.150
#
# Interval 89 (2200000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.8556
# 34 episodes - episode_reward: 640.294 [120.000, 1980.000] - loss: 0.687 - mean_absolute_error: 2.853 - mean_q: 3.130 - mean_eps: 0.355 - ale.lives: 2.114
#
# Interval 90 (2225000 steps performed)
# 25000/25000 [==============================] - 309s 12ms/step - reward: 0.7516
# 31 episodes - episode_reward: 602.581 [120.000, 1440.000] - loss: 0.688 - mean_absolute_error: 2.871 - mean_q: 3.150 - mean_eps: 0.352 - ale.lives: 2.086
#
# Interval 91 (2250000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.7496
# 31 episodes - episode_reward: 603.871 [200.000, 1870.000] - loss: 0.711 - mean_absolute_error: 2.897 - mean_q: 3.177 - mean_eps: 0.348 - ale.lives: 2.066
#
# Interval 92 (2275000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6884
# 32 episodes - episode_reward: 540.938 [200.000, 1890.000] - loss: 0.687 - mean_absolute_error: 2.927 - mean_q: 3.212 - mean_eps: 0.345 - ale.lives: 2.109
#
# Interval 93 (2300000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.8100
# 32 episodes - episode_reward: 630.312 [170.000, 3530.000] - loss: 0.707 - mean_absolute_error: 2.951 - mean_q: 3.236 - mean_eps: 0.342 - ale.lives: 2.085
#
# Interval 94 (2325000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.7332
# 31 episodes - episode_reward: 587.419 [180.000, 1390.000] - loss: 0.711 - mean_absolute_error: 2.981 - mean_q: 3.270 - mean_eps: 0.338 - ale.lives: 2.170
#
# Interval 95 (2350000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.8408
# 33 episodes - episode_reward: 641.515 [140.000, 2760.000] - loss: 0.686 - mean_absolute_error: 2.994 - mean_q: 3.287 - mean_eps: 0.335 - ale.lives: 2.072
#
# Interval 96 (2375000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.81400s - reward - ETA: 0s - reward: 0
# 31 episodes - episode_reward: 653.226 [180.000, 2190.000] - loss: 0.709 - mean_absolute_error: 3.010 - mean_q: 3.304 - mean_eps: 0.332 - ale.lives: 2.148
#
# Interval 97 (2400000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.7080
# 29 episodes - episode_reward: 613.103 [210.000, 1160.000] - loss: 0.721 - mean_absolute_error: 3.044 - mean_q: 3.340 - mean_eps: 0.328 - ale.lives: 2.082
#
# Interval 98 (2425000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.8332
# 34 episodes - episode_reward: 601.471 [260.000, 1150.000] - loss: 0.732 - mean_absolute_error: 3.064 - mean_q: 3.361 - mean_eps: 0.325 - ale.lives: 2.092
#
# Interval 99 (2450000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.8392
# 34 episodes - episode_reward: 627.353 [190.000, 3420.000] - loss: 0.734 - mean_absolute_error: 3.083 - mean_q: 3.384 - mean_eps: 0.322 - ale.lives: 2.149
#
# Interval 100 (2475000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.7976
# 29 episodes - episode_reward: 677.241 [220.000, 1760.000] - loss: 0.708 - mean_absolute_error: 3.110 - mean_q: 3.417 - mean_eps: 0.318 - ale.lives: 2.126
#
# Interval 101 (2500000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.7008
# 33 episodes - episode_reward: 545.758 [140.000, 1690.000] - loss: 0.722 - mean_absolute_error: 3.124 - mean_q: 3.430 - mean_eps: 0.315 - ale.lives: 2.095
#
# Interval 102 (2525000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.8604
# 30 episodes - episode_reward: 710.667 [180.000, 1660.000] - loss: 0.763 - mean_absolute_error: 3.156 - mean_q: 3.459 - mean_eps: 0.312 - ale.lives: 2.122
#
# Interval 103 (2550000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.68560s - reward: 0.
# 34 episodes - episode_reward: 505.294 [190.000, 1540.000] - loss: 0.717 - mean_absolute_error: 3.174 - mean_q: 3.488 - mean_eps: 0.308 - ale.lives: 2.027
#
# Interval 104 (2575000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.8288
# 30 episodes - episode_reward: 669.333 [290.000, 1340.000] - loss: 0.713 - mean_absolute_error: 3.194 - mean_q: 3.511 - mean_eps: 0.305 - ale.lives: 2.076
#
# Interval 105 (2600000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.7128
# 30 episodes - episode_reward: 612.667 [190.000, 2300.000] - loss: 0.726 - mean_absolute_error: 3.219 - mean_q: 3.539 - mean_eps: 0.302 - ale.lives: 2.141
#
# Interval 106 (2625000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.7224
# 33 episodes - episode_reward: 554.848 [260.000, 1440.000] - loss: 0.731 - mean_absolute_error: 3.242 - mean_q: 3.563 - mean_eps: 0.298 - ale.lives: 2.082
#
# Interval 107 (2650000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.7620
# 34 episodes - episode_reward: 548.529 [150.000, 1910.000] - loss: 0.725 - mean_absolute_error: 3.261 - mean_q: 3.585 - mean_eps: 0.295 - ale.lives: 2.125
#
# Interval 108 (2675000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7968
# 32 episodes - episode_reward: 635.000 [150.000, 1830.000] - loss: 0.752 - mean_absolute_error: 3.288 - mean_q: 3.610 - mean_eps: 0.292 - ale.lives: 2.035
#
# Interval 109 (2700000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.9344
# 29 episodes - episode_reward: 795.862 [200.000, 3420.000] - loss: 0.727 - mean_absolute_error: 3.298 - mean_q: 3.625 - mean_eps: 0.288 - ale.lives: 2.143
#
# Interval 110 (2725000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.8388
# 33 episodes - episode_reward: 631.212 [210.000, 2290.000] - loss: 0.755 - mean_absolute_error: 3.313 - mean_q: 3.640 - mean_eps: 0.285 - ale.lives: 2.063
#
# Interval 111 (2750000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7812
# 34 episodes - episode_reward: 586.765 [130.000, 2200.000] - loss: 0.715 - mean_absolute_error: 3.332 - mean_q: 3.666 - mean_eps: 0.282 - ale.lives: 2.073
#
# Interval 112 (2775000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.8456
# 31 episodes - episode_reward: 678.065 [150.000, 1620.000] - loss: 0.717 - mean_absolute_error: 3.354 - mean_q: 3.691 - mean_eps: 0.278 - ale.lives: 2.088
#
# Interval 113 (2800000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.7480
# 33 episodes - episode_reward: 560.303 [200.000, 2010.000] - loss: 0.745 - mean_absolute_error: 3.390 - mean_q: 3.727 - mean_eps: 0.275 - ale.lives: 2.112
#
# Interval 114 (2825000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.7588
# 33 episodes - episode_reward: 571.515 [170.000, 1990.000] - loss: 0.720 - mean_absolute_error: 3.403 - mean_q: 3.745 - mean_eps: 0.272 - ale.lives: 2.141
#
# Interval 115 (2850000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7848
# 35 episodes - episode_reward: 565.429 [160.000, 1490.000] - loss: 0.773 - mean_absolute_error: 3.436 - mean_q: 3.777 - mean_eps: 0.268 - ale.lives: 2.074
#
# Interval 116 (2875000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.8116
# 32 episodes - episode_reward: 636.875 [230.000, 1140.000] - loss: 0.752 - mean_absolute_error: 3.466 - mean_q: 3.814 - mean_eps: 0.265 - ale.lives: 2.151
#
# Interval 117 (2900000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.8588
# 33 episodes - episode_reward: 656.061 [170.000, 1720.000] - loss: 0.775 - mean_absolute_error: 3.496 - mean_q: 3.843 - mean_eps: 0.262 - ale.lives: 2.155
#
# Interval 118 (2925000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6936
# 34 episodes - episode_reward: 508.235 [140.000, 1230.000] - loss: 0.718 - mean_absolute_error: 3.512 - mean_q: 3.869 - mean_eps: 0.258 - ale.lives: 2.136
#
# Interval 119 (2950000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.7712
# 31 episodes - episode_reward: 600.968 [210.000, 1840.000] - loss: 0.724 - mean_absolute_error: 3.539 - mean_q: 3.896 - mean_eps: 0.255 - ale.lives: 2.070
#
# Interval 120 (2975000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.7984
# 32 episodes - episode_reward: 643.750 [80.000, 1830.000] - loss: 0.694 - mean_absolute_error: 3.559 - mean_q: 3.924 - mean_eps: 0.252 - ale.lives: 2.059
#
# Interval 121 (3000000 steps performed)
# 25000/25000 [==============================] - 290s 12ms/step - reward: 0.8740
# 32 episodes - episode_reward: 672.188 [270.000, 1320.000] - loss: 0.745 - mean_absolute_error: 3.591 - mean_q: 3.955 - mean_eps: 0.248 - ale.lives: 2.108
#
# Interval 122 (3025000 steps performed)
# 25000/25000 [==============================] - ETA: 0s - reward: 0.801 - 292s 12ms/step - reward: 0.8020
# 33 episodes - episode_reward: 610.606 [80.000, 2020.000] - loss: 0.727 - mean_absolute_error: 3.615 - mean_q: 3.984 - mean_eps: 0.245 - ale.lives: 2.040
#
# Interval 123 (3050000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.8112
# 34 episodes - episode_reward: 605.588 [160.000, 1320.000] - loss: 0.757 - mean_absolute_error: 3.631 - mean_q: 3.997 - mean_eps: 0.242 - ale.lives: 2.116
#
# Interval 124 (3075000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.7792
# 34 episodes - episode_reward: 572.059 [120.000, 1860.000] - loss: 0.768 - mean_absolute_error: 3.656 - mean_q: 4.025 - mean_eps: 0.238 - ale.lives: 2.094
#
# Interval 125 (3100000 steps performed)
# 25000/25000 [==============================] - 289s 12ms/step - reward: 0.8332
# 31 episodes - episode_reward: 658.065 [200.000, 1810.000] - loss: 0.761 - mean_absolute_error: 3.690 - mean_q: 4.064 - mean_eps: 0.235 - ale.lives: 2.131
#
# Interval 126 (3125000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.8288
# 35 episodes - episode_reward: 605.143 [130.000, 2180.000] - loss: 0.760 - mean_absolute_error: 3.710 - mean_q: 4.087 - mean_eps: 0.232 - ale.lives: 2.073
#
# Interval 127 (3150000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.7896
# 32 episodes - episode_reward: 615.625 [180.000, 1350.000] - loss: 0.758 - mean_absolute_error: 3.732 - mean_q: 4.113 - mean_eps: 0.228 - ale.lives: 2.087
#
# Interval 128 (3175000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.7864
# 32 episodes - episode_reward: 603.125 [180.000, 1180.000] - loss: 0.766 - mean_absolute_error: 3.758 - mean_q: 4.141 - mean_eps: 0.225 - ale.lives: 2.092
#
# Interval 129 (3200000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.9028
# 31 episodes - episode_reward: 667.097 [200.000, 2030.000] - loss: 0.733 - mean_absolute_error: 3.784 - mean_q: 4.174 - mean_eps: 0.222 - ale.lives: 2.133
#
# Interval 130 (3225000 steps performed)
# 25000/25000 [==============================] - 301s 12ms/step - reward: 0.8672
# 36 episodes - episode_reward: 652.222 [130.000, 2400.000] - loss: 0.766 - mean_absolute_error: 3.810 - mean_q: 4.199 - mean_eps: 0.218 - ale.lives: 2.141
#
# Interval 131 (3250000 steps performed)
# 25000/25000 [==============================] - 307s 12ms/step - reward: 0.7488
# 36 episodes - episode_reward: 527.500 [140.000, 1330.000] - loss: 0.752 - mean_absolute_error: 3.827 - mean_q: 4.220 - mean_eps: 0.215 - ale.lives: 2.057
#
# Interval 132 (3275000 steps performed)
# 25000/25000 [==============================] - 303s 12ms/step - reward: 0.8524
# 32 episodes - episode_reward: 652.188 [170.000, 2250.000] - loss: 0.777 - mean_absolute_error: 3.849 - mean_q: 4.242 - mean_eps: 0.212 - ale.lives: 2.073
#
# Interval 133 (3300000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.7640
# 34 episodes - episode_reward: 570.000 [210.000, 1150.000] - loss: 0.783 - mean_absolute_error: 3.861 - mean_q: 4.253 - mean_eps: 0.208 - ale.lives: 2.047
#
# Interval 134 (3325000 steps performed)
# 25000/25000 [==============================] - 312s 12ms/step - reward: 0.8012
# 35 episodes - episode_reward: 560.000 [220.000, 2000.000] - loss: 0.763 - mean_absolute_error: 3.878 - mean_q: 4.274 - mean_eps: 0.205 - ale.lives: 2.085
#
# Interval 135 (3350000 steps performed)
# 25000/25000 [==============================] - 315s 13ms/step - reward: 0.7164
# 33 episodes - episode_reward: 557.273 [220.000, 1320.000] - loss: 0.736 - mean_absolute_error: 3.879 - mean_q: 4.280 - mean_eps: 0.202 - ale.lives: 2.108
#
# Interval 136 (3375000 steps performed)
# 25000/25000 [==============================] - 308s 12ms/step - reward: 0.7784
# 35 episodes - episode_reward: 564.000 [220.000, 1730.000] - loss: 0.763 - mean_absolute_error: 3.899 - mean_q: 4.300 - mean_eps: 0.198 - ale.lives: 2.123
#
# Interval 137 (3400000 steps performed)
# 25000/25000 [==============================] - 306s 12ms/step - reward: 0.7676
# 31 episodes - episode_reward: 611.935 [260.000, 1390.000] - loss: 0.776 - mean_absolute_error: 3.919 - mean_q: 4.320 - mean_eps: 0.195 - ale.lives: 2.045
#
# Interval 138 (3425000 steps performed)
# 25000/25000 [==============================] - 303s 12ms/step - reward: 0.8752
# 31 episodes - episode_reward: 688.710 [190.000, 1730.000] - loss: 0.756 - mean_absolute_error: 3.938 - mean_q: 4.344 - mean_eps: 0.192 - ale.lives: 2.112
#
# Interval 139 (3450000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.7540
# 32 episodes - episode_reward: 602.812 [210.000, 1880.000] - loss: 0.792 - mean_absolute_error: 3.960 - mean_q: 4.365 - mean_eps: 0.188 - ale.lives: 2.056
#
# Interval 140 (3475000 steps performed)
# 25000/25000 [==============================] - 307s 12ms/step - reward: 0.7912
# 29 episodes - episode_reward: 672.069 [220.000, 2100.000] - loss: 0.776 - mean_absolute_error: 3.970 - mean_q: 4.377 - mean_eps: 0.185 - ale.lives: 2.100
#
# Interval 141 (3500000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.8356
# 33 episodes - episode_reward: 646.364 [180.000, 1980.000] - loss: 0.777 - mean_absolute_error: 3.982 - mean_q: 4.391 - mean_eps: 0.182 - ale.lives: 2.084
#
# Interval 142 (3525000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.6944
# 35 episodes - episode_reward: 495.714 [220.000, 1040.000] - loss: 0.763 - mean_absolute_error: 4.003 - mean_q: 4.417 - mean_eps: 0.178 - ale.lives: 2.157
#
# Interval 143 (3550000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 1.12000s -
# 30 episodes - episode_reward: 903.667 [210.000, 3860.000] - loss: 0.771 - mean_absolute_error: 4.032 - mean_q: 4.447 - mean_eps: 0.175 - ale.lives: 2.079
#
# Interval 144 (3575000 steps performed)
# 25000/25000 [==============================] - 294s 12ms/step - reward: 0.8220
# 34 episodes - episode_reward: 632.059 [130.000, 1690.000] - loss: 0.755 - mean_absolute_error: 4.055 - mean_q: 4.477 - mean_eps: 0.172 - ale.lives: 2.063
#
# Interval 145 (3600000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6736
# 33 episodes - episode_reward: 511.818 [200.000, 1020.000] - loss: 0.769 - mean_absolute_error: 4.073 - mean_q: 4.495 - mean_eps: 0.168 - ale.lives: 2.100
#
# Interval 146 (3625000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.7680
# 32 episodes - episode_reward: 603.750 [240.000, 1120.000] - loss: 0.764 - mean_absolute_error: 4.089 - mean_q: 4.512 - mean_eps: 0.165 - ale.lives: 2.090
#
# Interval 147 (3650000 steps performed)
# 25000/25000 [==============================] - 311s 12ms/step - reward: 0.8060
# 32 episodes - episode_reward: 624.375 [190.000, 1950.000] - loss: 0.789 - mean_absolute_error: 4.110 - mean_q: 4.535 - mean_eps: 0.162 - ale.lives: 2.116
#
# Interval 148 (3675000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.7832
# 32 episodes - episode_reward: 611.250 [210.000, 1290.000] - loss: 0.798 - mean_absolute_error: 4.130 - mean_q: 4.557 - mean_eps: 0.158 - ale.lives: 2.111
#
# Interval 149 (3700000 steps performed)
# 25000/25000 [==============================] - 289s 12ms/step - reward: 0.7808
# 34 episodes - episode_reward: 579.706 [140.000, 1820.000] - loss: 0.760 - mean_absolute_error: 4.134 - mean_q: 4.564 - mean_eps: 0.155 - ale.lives: 2.190
#
# Interval 150 (3725000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.74120s -
# 30 episodes - episode_reward: 580.000 [230.000, 1300.000] - loss: 0.760 - mean_absolute_error: 4.154 - mean_q: 4.587 - mean_eps: 0.152 - ale.lives: 2.099
#
# Interval 151 (3750000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.8272
# 34 episodes - episode_reward: 634.412 [160.000, 1870.000] - loss: 0.773 - mean_absolute_error: 4.165 - mean_q: 4.598 - mean_eps: 0.148 - ale.lives: 2.155
#
# Interval 152 (3775000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.7740
# 35 episodes - episode_reward: 552.857 [260.000, 1570.000] - loss: 0.768 - mean_absolute_error: 4.181 - mean_q: 4.617 - mean_eps: 0.145 - ale.lives: 2.171
#
# Interval 153 (3800000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.7876
# 30 episodes - episode_reward: 657.333 [210.000, 1430.000] - loss: 0.786 - mean_absolute_error: 4.205 - mean_q: 4.643 - mean_eps: 0.142 - ale.lives: 2.148
#
# Interval 154 (3825000 steps performed)
# 25000/25000 [==============================] - 286s 11ms/step - reward: 0.7800
# 34 episodes - episode_reward: 570.294 [210.000, 1830.000] - loss: 0.765 - mean_absolute_error: 4.221 - mean_q: 4.662 - mean_eps: 0.138 - ale.lives: 2.110
#
# Interval 155 (3850000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.7296
# 33 episodes - episode_reward: 556.061 [130.000, 1400.000] - loss: 0.789 - mean_absolute_error: 4.248 - mean_q: 4.689 - mean_eps: 0.135 - ale.lives: 2.092
#
# Interval 156 (3875000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.7384
# 37 episodes - episode_reward: 502.162 [220.000, 1710.000] - loss: 0.782 - mean_absolute_error: 4.249 - mean_q: 4.690 - mean_eps: 0.132 - ale.lives: 2.110
#
# Interval 157 (3900000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.67921s - reward: 0.6
# 32 episodes - episode_reward: 520.312 [110.000, 1540.000] - loss: 0.733 - mean_absolute_error: 4.250 - mean_q: 4.700 - mean_eps: 0.128 - ale.lives: 2.154
#
# Interval 158 (3925000 steps performed)
# 25000/25000 [==============================] - 287s 11ms/step - reward: 0.8536
# 33 episodes - episode_reward: 653.636 [220.000, 1750.000] - loss: 0.730 - mean_absolute_error: 4.271 - mean_q: 4.724 - mean_eps: 0.125 - ale.lives: 2.096
#
# Interval 159 (3950000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.7092
# 35 episodes - episode_reward: 512.000 [210.000, 1540.000] - loss: 0.774 - mean_absolute_error: 4.293 - mean_q: 4.743 - mean_eps: 0.122 - ale.lives: 2.113
#
# Interval 160 (3975000 steps performed)
# 25000/25000 [==============================] - 286s 11ms/step - reward: 0.8520
# 31 episodes - episode_reward: 679.355 [210.000, 1730.000] - loss: 0.768 - mean_absolute_error: 4.309 - mean_q: 4.761 - mean_eps: 0.118 - ale.lives: 2.071
#
# Interval 161 (4000000 steps performed)
# 25000/25000 [==============================] - 285s 11ms/step - reward: 0.6808
# 36 episodes - episode_reward: 479.444 [190.000, 1220.000] - loss: 0.749 - mean_absolute_error: 4.317 - mean_q: 4.772 - mean_eps: 0.115 - ale.lives: 2.086
#
# Interval 162 (4025000 steps performed)
# 25000/25000 [==============================] - 284s 11ms/step - reward: 0.78320s -
# 33 episodes - episode_reward: 573.333 [210.000, 1350.000] - loss: 0.740 - mean_absolute_error: 4.331 - mean_q: 4.789 - mean_eps: 0.112 - ale.lives: 2.153
#
# Interval 163 (4050000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7616
# 33 episodes - episode_reward: 586.061 [210.000, 1230.000] - loss: 0.748 - mean_absolute_error: 4.336 - mean_q: 4.794 - mean_eps: 0.108 - ale.lives: 2.094
#
# Interval 164 (4075000 steps performed)
# 25000/25000 [==============================] - 301s 12ms/step - reward: 0.9564
# 32 episodes - episode_reward: 749.688 [110.000, 2070.000] - loss: 0.737 - mean_absolute_error: 4.354 - mean_q: 4.815 - mean_eps: 0.105 - ale.lives: 2.096
#
# Interval 165 (4100000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.8108
# 35 episodes - episode_reward: 564.571 [220.000, 2200.000] - loss: 0.780 - mean_absolute_error: 4.358 - mean_q: 4.813 - mean_eps: 0.102 - ale.lives: 2.120
#
# Interval 166 (4125000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6512
# 34 episodes - episode_reward: 495.882 [230.000, 1150.000] - loss: 0.768 - mean_absolute_error: 4.369 - mean_q: 4.829 - mean_eps: 0.098 - ale.lives: 2.116
#
# Interval 167 (4150000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.7152
# 33 episodes - episode_reward: 533.939 [260.000, 1590.000] - loss: 0.783 - mean_absolute_error: 4.391 - mean_q: 4.851 - mean_eps: 0.095 - ale.lives: 2.084
#
# Interval 168 (4175000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.6432
# 35 episodes - episode_reward: 472.857 [120.000, 1750.000] - loss: 0.752 - mean_absolute_error: 4.406 - mean_q: 4.875 - mean_eps: 0.092 - ale.lives: 2.146
#
# Interval 169 (4200000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.8256
# 32 episodes - episode_reward: 642.812 [220.000, 2030.000] - loss: 0.775 - mean_absolute_error: 4.440 - mean_q: 4.910 - mean_eps: 0.088 - ale.lives: 2.140
#
# Interval 170 (4225000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.7292
# 33 episodes - episode_reward: 531.515 [180.000, 1190.000] - loss: 0.773 - mean_absolute_error: 4.435 - mean_q: 4.905 - mean_eps: 0.085 - ale.lives: 2.067
#
# Interval 171 (4250000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6456
# 36 episodes - episode_reward: 465.833 [210.000, 940.000] - loss: 0.744 - mean_absolute_error: 4.440 - mean_q: 4.912 - mean_eps: 0.082 - ale.lives: 2.035
#
# Interval 172 (4275000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.7280
# 34 episodes - episode_reward: 515.000 [210.000, 1880.000] - loss: 0.734 - mean_absolute_error: 4.452 - mean_q: 4.926 - mean_eps: 0.078 - ale.lives: 2.143
#
# Interval 173 (4300000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.7220
# 32 episodes - episode_reward: 579.375 [230.000, 1330.000] - loss: 0.774 - mean_absolute_error: 4.473 - mean_q: 4.946 - mean_eps: 0.075 - ale.lives: 2.121
#
# Interval 174 (4325000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.7460
# 31 episodes - episode_reward: 592.258 [210.000, 1110.000] - loss: 0.736 - mean_absolute_error: 4.485 - mean_q: 4.963 - mean_eps: 0.072 - ale.lives: 2.072
#
# Interval 175 (4350000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.6576
# 35 episodes - episode_reward: 481.429 [110.000, 1160.000] - loss: 0.770 - mean_absolute_error: 4.513 - mean_q: 4.992 - mean_eps: 0.068 - ale.lives: 2.123
#
# Interval 176 (4375000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.6940
# 36 episodes - episode_reward: 487.778 [200.000, 1360.000] - loss: 0.750 - mean_absolute_error: 4.526 - mean_q: 5.008 - mean_eps: 0.065 - ale.lives: 2.112
#
# Interval 177 (4400000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.8120
# 32 episodes - episode_reward: 634.375 [210.000, 1910.000] - loss: 0.735 - mean_absolute_error: 4.525 - mean_q: 5.008 - mean_eps: 0.062 - ale.lives: 2.146
#
# Interval 178 (4425000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.6852
# 31 episodes - episode_reward: 528.387 [210.000, 1090.000] - loss: 0.755 - mean_absolute_error: 4.543 - mean_q: 5.026 - mean_eps: 0.058 - ale.lives: 2.071
#
# Interval 179 (4450000 steps performed)
# 25000/25000 [==============================] - 298s 12ms/step - reward: 0.6800
# 34 episodes - episode_reward: 517.941 [160.000, 1350.000] - loss: 0.743 - mean_absolute_error: 4.548 - mean_q: 5.033 - mean_eps: 0.055 - ale.lives: 2.035
#
# Interval 180 (4475000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.7364
# 34 episodes - episode_reward: 545.588 [210.000, 1510.000] - loss: 0.749 - mean_absolute_error: 4.555 - mean_q: 5.039 - mean_eps: 0.052 - ale.lives: 2.051
#
# Interval 181 (4500000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.7064
# 32 episodes - episode_reward: 542.500 [170.000, 2710.000] - loss: 0.748 - mean_absolute_error: 4.568 - mean_q: 5.057 - mean_eps: 0.050 - ale.lives: 2.155
#
# Interval 182 (4525000 steps performed)
# 25000/25000 [==============================] - 296s 12ms/step - reward: 0.6064
# 34 episodes - episode_reward: 450.000 [210.000, 970.000] - loss: 0.750 - mean_absolute_error: 4.580 - mean_q: 5.069 - mean_eps: 0.050 - ale.lives: 2.054
#
# Interval 183 (4550000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.7936
# 34 episodes - episode_reward: 570.882 [160.000, 2240.000] - loss: 0.738 - mean_absolute_error: 4.580 - mean_q: 5.069 - mean_eps: 0.050 - ale.lives: 2.053
#
# Interval 184 (4575000 steps performed)
# 25000/25000 [==============================] - 289s 12ms/step - reward: 0.74960s - rewar
# 34 episodes - episode_reward: 554.706 [210.000, 2380.000] - loss: 0.712 - mean_absolute_error: 4.588 - mean_q: 5.084 - mean_eps: 0.050 - ale.lives: 2.049
#
# Interval 185 (4600000 steps performed)
# 25000/25000 [==============================] - 290s 12ms/step - reward: 0.6348
# 33 episodes - episode_reward: 485.455 [140.000, 1350.000] - loss: 0.731 - mean_absolute_error: 4.602 - mean_q: 5.095 - mean_eps: 0.050 - ale.lives: 2.093
#
# Interval 186 (4625000 steps performed)
# 25000/25000 [==============================] - 288s 12ms/step - reward: 0.6192
# 34 episodes - episode_reward: 460.882 [210.000, 1400.000] - loss: 0.733 - mean_absolute_error: 4.622 - mean_q: 5.118 - mean_eps: 0.050 - ale.lives: 2.078
#
# Interval 187 (4650000 steps performed)
# 25000/25000 [==============================] - 289s 12ms/step - reward: 0.73160s - rewar - ETA: 0s - reward: 0.731
# 34 episodes - episode_reward: 512.059 [150.000, 1820.000] - loss: 0.729 - mean_absolute_error: 4.638 - mean_q: 5.138 - mean_eps: 0.050 - ale.lives: 2.031
#
# Interval 188 (4675000 steps performed)
# 25000/25000 [==============================] - 290s 12ms/step - reward: 0.7224
# 34 episodes - episode_reward: 552.941 [130.000, 1360.000] - loss: 0.714 - mean_absolute_error: 4.658 - mean_q: 5.164 - mean_eps: 0.050 - ale.lives: 2.016
#
# Interval 189 (4700000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.7120
# 33 episodes - episode_reward: 533.333 [200.000, 1790.000] - loss: 0.725 - mean_absolute_error: 4.682 - mean_q: 5.190 - mean_eps: 0.050 - ale.lives: 2.076
#
# Interval 190 (4725000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.7092
# 33 episodes - episode_reward: 551.515 [130.000, 1230.000] - loss: 0.692 - mean_absolute_error: 4.695 - mean_q: 5.206 - mean_eps: 0.050 - ale.lives: 2.120
#
# Interval 191 (4750000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.7172
# 31 episodes - episode_reward: 530.323 [210.000, 1310.000] - loss: 0.704 - mean_absolute_error: 4.696 - mean_q: 5.205 - mean_eps: 0.050 - ale.lives: 2.102
#
# Interval 192 (4775000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.7168
# 33 episodes - episode_reward: 579.697 [160.000, 1490.000] - loss: 0.735 - mean_absolute_error: 4.706 - mean_q: 5.212 - mean_eps: 0.050 - ale.lives: 2.174
#
# Interval 193 (4800000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.7816
# 35 episodes - episode_reward: 561.429 [150.000, 2060.000] - loss: 0.709 - mean_absolute_error: 4.712 - mean_q: 5.223 - mean_eps: 0.050 - ale.lives: 2.107
#
# Interval 194 (4825000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.7020
# 33 episodes - episode_reward: 531.515 [240.000, 1190.000] - loss: 0.694 - mean_absolute_error: 4.724 - mean_q: 5.237 - mean_eps: 0.050 - ale.lives: 2.020
#
# Interval 195 (4850000 steps performed)
# 25000/25000 [==============================] - 292s 12ms/step - reward: 0.7008
# 35 episodes - episode_reward: 478.571 [210.000, 930.000] - loss: 0.717 - mean_absolute_error: 4.717 - mean_q: 5.227 - mean_eps: 0.050 - ale.lives: 2.151
#
# Interval 196 (4875000 steps performed)
# 25000/25000 [==============================] - 310s 12ms/step - reward: 0.6036
# 34 episodes - episode_reward: 469.412 [210.000, 1120.000] - loss: 0.703 - mean_absolute_error: 4.713 - mean_q: 5.227 - mean_eps: 0.050 - ale.lives: 2.098
#
# Interval 197 (4900000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.6864
# 30 episodes - episode_reward: 552.333 [210.000, 1270.000] - loss: 0.675 - mean_absolute_error: 4.722 - mean_q: 5.239 - mean_eps: 0.050 - ale.lives: 2.114
#
# Interval 198 (4925000 steps performed)
# 25000/25000 [==============================] - 301s 12ms/step - reward: 0.6796
# 34 episodes - episode_reward: 497.941 [210.000, 1230.000] - loss: 0.664 - mean_absolute_error: 4.725 - mean_q: 5.243 - mean_eps: 0.050 - ale.lives: 2.066
#
# Interval 199 (4950000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.7188
# 35 episodes - episode_reward: 528.286 [210.000, 2140.000] - loss: 0.671 - mean_absolute_error: 4.725 - mean_q: 5.243 - mean_eps: 0.050 - ale.lives: 2.099
#
# Interval 200 (4975000 steps performed)
# 25000/25000 [==============================] - 304s 12ms/step - reward: 0.7092
# done, took 59292.026 seconds
# Testing for 10 episodes ...
# Episode 1: reward: 210.000, steps: 511
# Episode 2: reward: 210.000, steps: 500
# Episode 3: reward: 210.000, steps: 503
# Episode 4: reward: 210.000, steps: 489
# Episode 5: reward: 210.000, steps: 501
# Episode 6: reward: 210.000, steps: 495
# Episode 7: reward: 210.000, steps: 502
# Episode 8: reward: 210.000, steps: 514
# Episode 9: reward: 210.000, steps: 498
# Episode 10: reward: 210.000, steps: 497

# %%
plt.plot(history.history['episode_reward'])
plt.title('DQN Performance')
plt.ylabel('Reward')
plt.xlabel('Episode')
plt.show()

# %%
#Test
#Atari Testing Processor (Change Reward Metric)
class AtariProcessor_test(Processor):
    
    def process_observation(self, observation):
        # Crop
        img = observation[1:176:2, ::2]
        # Convert the image to greyscale
        img = np.dot(img[...,:3], [0.299, 0.587, 0.144])
        # Resize
        img = img.reshape(INPUT_SHAPE)
        return img.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return reward

weights_filename = 'dqn_{}_weights.h5f'.format(ENV_NAME)

processor = AtariProcessor_test()
dqn = DQNAgent(model=model, nb_actions=n_actions, policy=policy, memory=memory, processor=processor, nb_steps_warmup=start_steps, 
               gamma=discount_factor, target_model_update=batch,train_interval=steps_train, delta_clip=1.)
dqn.compile(Adam(lr=learning_rate), metrics=['mae'])


dqn.load_weights(weights_filename)
history2 = dqn.test(env, nb_episodes=100, visualize=False)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 210.000, steps: 506
# Episode 2: reward: 210.000, steps: 500
# Episode 3: reward: 210.000, steps: 505
# Episode 4: reward: 210.000, steps: 496
# Episode 5: reward: 210.000, steps: 496
# Episode 6: reward: 210.000, steps: 501
# Episode 7: reward: 210.000, steps: 496
# Episode 8: reward: 210.000, steps: 500
# Episode 9: reward: 210.000, steps: 495
# Episode 10: reward: 210.000, steps: 497
# Episode 11: reward: 210.000, steps: 500
# Episode 12: reward: 210.000, steps: 508
# Episode 13: reward: 210.000, steps: 504
# Episode 14: reward: 210.000, steps: 497
# Episode 15: reward: 210.000, steps: 508
# Episode 16: reward: 210.000, steps: 509
# Episode 17: reward: 210.000, steps: 496
# Episode 18: reward: 210.000, steps: 487
# Episode 19: reward: 210.000, steps: 493
# Episode 20: reward: 210.000, steps: 518
# Episode 21: reward: 210.000, steps: 494
# Episode 22: reward: 210.000, steps: 501
# Episode 23: reward: 210.000, steps: 500
# Episode 24: reward: 210.000, steps: 493
# Episode 25: reward: 210.000, steps: 507
# Episode 26: reward: 210.000, steps: 506
# Episode 27: reward: 210.000, steps: 501
# Episode 28: reward: 210.000, steps: 500
# Episode 29: reward: 210.000, steps: 499
# Episode 30: reward: 210.000, steps: 491
# Episode 31: reward: 210.000, steps: 498
# Episode 32: reward: 210.000, steps: 498
# Episode 33: reward: 210.000, steps: 503
# Episode 34: reward: 210.000, steps: 497
# Episode 35: reward: 210.000, steps: 507
# Episode 36: reward: 210.000, steps: 493
# Episode 37: reward: 210.000, steps: 500
# Episode 38: reward: 210.000, steps: 502
# Episode 39: reward: 210.000, steps: 507
# Episode 40: reward: 210.000, steps: 493
# Episode 41: reward: 210.000, steps: 509
# Episode 42: reward: 210.000, steps: 502
# Episode 43: reward: 210.000, steps: 499
# Episode 44: reward: 210.000, steps: 502
# Episode 45: reward: 210.000, steps: 508
# Episode 46: reward: 210.000, steps: 491
# Episode 47: reward: 210.000, steps: 496
# Episode 48: reward: 210.000, steps: 503
# Episode 49: reward: 210.000, steps: 502
# Episode 50: reward: 210.000, steps: 505
# Episode 51: reward: 210.000, steps: 495
# Episode 52: reward: 210.000, steps: 497
# Episode 53: reward: 210.000, steps: 492
# Episode 54: reward: 210.000, steps: 501
# Episode 55: reward: 210.000, steps: 510
# Episode 56: reward: 210.000, steps: 497
# Episode 57: reward: 210.000, steps: 510
# Episode 58: reward: 210.000, steps: 495
# Episode 59: reward: 210.000, steps: 509
# Episode 60: reward: 210.000, steps: 512
# Episode 61: reward: 210.000, steps: 501
# Episode 62: reward: 210.000, steps: 484
# Episode 63: reward: 210.000, steps: 500
# Episode 64: reward: 210.000, steps: 500
# Episode 65: reward: 210.000, steps: 497
# Episode 66: reward: 210.000, steps: 500
# Episode 67: reward: 210.000, steps: 492
# Episode 68: reward: 210.000, steps: 500
# Episode 69: reward: 210.000, steps: 502
# Episode 70: reward: 210.000, steps: 497
# Episode 71: reward: 210.000, steps: 498
# Episode 72: reward: 210.000, steps: 506
# Episode 73: reward: 210.000, steps: 502
# Episode 74: reward: 210.000, steps: 494
# Episode 75: reward: 210.000, steps: 503
# Episode 76: reward: 210.000, steps: 492
# Episode 77: reward: 210.000, steps: 502
# Episode 78: reward: 210.000, steps: 503
# Episode 79: reward: 210.000, steps: 501
# Episode 80: reward: 210.000, steps: 504
# Episode 81: reward: 210.000, steps: 500
# Episode 82: reward: 210.000, steps: 491
# Episode 83: reward: 210.000, steps: 492
# Episode 84: reward: 210.000, steps: 501
# Episode 85: reward: 210.000, steps: 505
# Episode 86: reward: 210.000, steps: 512
# Episode 87: reward: 210.000, steps: 500
# Episode 88: reward: 210.000, steps: 506
# Episode 89: reward: 210.000, steps: 501
# Episode 90: reward: 210.000, steps: 498
# Episode 91: reward: 210.000, steps: 493
# Episode 92: reward: 210.000, steps: 494
# Episode 93: reward: 210.000, steps: 498
# Episode 94: reward: 210.000, steps: 503
# Episode 95: reward: 210.000, steps: 512
# Episode 96: reward: 210.000, steps: 499
# Episode 97: reward: 210.000, steps: 486
# Episode 98: reward: 210.000, steps: 500
# Episode 99: reward: 210.000, steps: 506
# Episode 100: reward: 210.000, steps: 506

# %%
import statistics 

#Testing Plot
plt.plot(history2.history['episode_reward'])
plt.title('DQN Gameplay Performance')
plt.ylabel('Score')
plt.xlabel('Episode')
plt.show()

print("Average Score: ", statistics.mean(history2.history['episode_reward']))
print("Standard Deviation: ", statistics.stdev(history2.history['episode_reward']))
print("Average Steps Taken Per Episode: ", statistics.mean(history2.history['nb_steps']))
# Out:
# Average Score:  210.0
# Standard Deviation:  0.0
# Average Steps Taken Per Episode:  500.18
