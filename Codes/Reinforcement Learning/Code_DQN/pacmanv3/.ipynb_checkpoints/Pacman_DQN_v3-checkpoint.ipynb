# %%
from __future__ import division
import argparse

from PIL import Image
from PIL import ImageFilter
import numpy as np
import gym
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
from keras.optimizers import Adam
from keras.optimizers import SGD
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

import random
from datetime import datetime
import matplotlib.pyplot as plt

INPUT_SHAPE = (88, 80)
WINDOW_LENGTH = 4
ENV_NAME = 'MsPacman-v4'
# Out:
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Drake\.conda\envs\sls\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
#Atari Processor
class AtariProcessor(Processor):
    
    def process_observation(self, observation):
        # Crop
        img = observation[1:176:2, ::2]
        # Convert the image to greyscale
        img = np.dot(img[...,:3], [0.299, 0.587, 0.144])
        # Resize
        img = img.reshape(INPUT_SHAPE)
        return img.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %%
#Make Environment
env = gym.make(ENV_NAME)
np.random.seed(123)
env.seed(123)
n_actions = env.action_space.n
print("Number of Actions:", n_actions)
print(env.env.get_action_meanings())
observation = env.reset()

print("\n\nObserved Starting Position")
plt.imshow(observation)
plt.show() #show initial state

print("Preprocessed Starting Position")
plt.imshow(AtariProcessor.process_observation('',observation))
plt.show() #show preprocessed initial state
# Out:
# Number of Actions: 9
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']
#
#
# Observed Starting Position
# Preprocessed Starting Position

# %%
# Using the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
if K.image_dim_ordering() == 'tf':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_dim_ordering() == 'th':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(n_actions))
model.add(Activation('linear'))
print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 88, 80, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 19, 32)        8224
# _________________________________________________________________
# activation_1 (Activation)    (None, 21, 19, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 8, 64)          32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 6, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2688)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1376768
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 4617
# _________________________________________________________________
# activation_5 (Activation)    (None, 9)                 0
# =================================================================
# Total params: 1,459,369
# Trainable params: 1,459,369
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Hyperparameters
num_steps = 5000000
learning_rate = 0.0002
discount_factor = 0.99
steps_train = 4
start_steps = 2000
eps_min = 0.1 #End with 0.1 epsilon (explore less)
eps_max = 0.5 #Start with 0.5 epsilon (explore more)
eps_decay_steps = 4500000
batch = 25000

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

#DecayingEpsilon
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=eps_max, value_min=eps_min, value_test=.05,
                              nb_steps=eps_decay_steps)

dqn = DQNAgent(model=model, nb_actions=n_actions, policy=policy, memory=memory, processor=processor, nb_steps_warmup=start_steps, 
               gamma=discount_factor, target_model_update=batch,train_interval=steps_train, delta_clip=1.)

dqn.compile(Adam(lr=learning_rate), metrics=['mae'])
# Out:
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\backend\tensorflow_backend.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Drake\.conda\envs\sls\lib\site-packages\rl\util.py:79: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
#Train

weights_filename = 'dqn_{}_weights.h5f'.format(ENV_NAME)

checkpoint_weights_filename = 'dqn_' + ENV_NAME + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(ENV_NAME)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=500000)]
callbacks += [FileLogger(log_filename, interval=100)]
 

history = dqn.fit(env, callbacks=callbacks, nb_steps=num_steps, log_interval=batch, visualize=False)

# After training is done, we save the final weights one more time.
dqn.save_weights(weights_filename, overwrite=True)

# Finally, evaluate our algorithm for 10 episodes.
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# Training for 5000000 steps ...
# Interval 1 (0 steps performed)
# 25000/25000 [==============================] - 261s 10ms/step - reward: 0.0502
# 29 episodes - episode_reward: 42.310 [20.000, 102.000] - loss: 0.023 - mean_absolute_error: 0.062 - mean_q: 0.095 - mean_eps: 0.499 - ale.lives: 2.126
#
# Interval 2 (25000 steps performed)
# 25000/25000 [==============================] - 274s 11ms/step - reward: 0.0508
# 32 episodes - episode_reward: 38.938 [18.000, 100.000] - loss: 0.021 - mean_absolute_error: 0.130 - mean_q: 0.183 - mean_eps: 0.497 - ale.lives: 2.084
#
# Interval 3 (50000 steps performed)
# 25000/25000 [==============================] - 276s 11ms/step - reward: 0.0474
# 33 episodes - episode_reward: 37.303 [18.000, 82.000] - loss: 0.020 - mean_absolute_error: 0.184 - mean_q: 0.252 - mean_eps: 0.494 - ale.lives: 2.092
#
# Interval 4 (75000 steps performed)
# 25000/25000 [==============================] - 275s 11ms/step - reward: 0.0488
# 34 episodes - episode_reward: 35.382 [13.000, 82.000] - loss: 0.019 - mean_absolute_error: 0.229 - mean_q: 0.313 - mean_eps: 0.492 - ale.lives: 2.020
#
# Interval 5 (100000 steps performed)
# 25000/25000 [==============================] - 276s 11ms/step - reward: 0.0542
# 31 episodes - episode_reward: 43.710 [21.000, 74.000] - loss: 0.020 - mean_absolute_error: 0.313 - mean_q: 0.418 - mean_eps: 0.490 - ale.lives: 2.121
#
# Interval 6 (125000 steps performed)
# 25000/25000 [==============================] - 277s 11ms/step - reward: 0.05670s - reward:
# 32 episodes - episode_reward: 44.906 [25.000, 81.000] - loss: 0.020 - mean_absolute_error: 0.356 - mean_q: 0.472 - mean_eps: 0.488 - ale.lives: 2.098
#
# Interval 7 (150000 steps performed)
# 25000/25000 [==============================] - 280s 11ms/step - reward: 0.0560
# 32 episodes - episode_reward: 43.219 [19.000, 67.000] - loss: 0.020 - mean_absolute_error: 0.420 - mean_q: 0.550 - mean_eps: 0.486 - ale.lives: 2.051
#
# Interval 8 (175000 steps performed)
# 25000/25000 [==============================] - 285s 11ms/step - reward: 0.0574
# 32 episodes - episode_reward: 44.844 [24.000, 82.000] - loss: 0.021 - mean_absolute_error: 0.491 - mean_q: 0.636 - mean_eps: 0.483 - ale.lives: 2.119
#
# Interval 9 (200000 steps performed)
# 25000/25000 [==============================] - 286s 11ms/step - reward: 0.0543
# 33 episodes - episode_reward: 40.727 [19.000, 64.000] - loss: 0.024 - mean_absolute_error: 0.567 - mean_q: 0.729 - mean_eps: 0.481 - ale.lives: 2.048
#
# Interval 10 (225000 steps performed)
# 25000/25000 [==============================] - 289s 12ms/step - reward: 0.0567
# 32 episodes - episode_reward: 43.656 [20.000, 59.000] - loss: 0.025 - mean_absolute_error: 0.683 - mean_q: 0.865 - mean_eps: 0.479 - ale.lives: 2.056
#
# Interval 11 (250000 steps performed)
# 25000/25000 [==============================] - 290s 12ms/step - reward: 0.0560
# 31 episodes - episode_reward: 46.355 [27.000, 73.000] - loss: 0.027 - mean_absolute_error: 0.758 - mean_q: 0.951 - mean_eps: 0.477 - ale.lives: 2.010
#
# Interval 12 (275000 steps performed)
# 25000/25000 [==============================] - 291s 12ms/step - reward: 0.0589
# 30 episodes - episode_reward: 48.233 [21.000, 83.000] - loss: 0.028 - mean_absolute_error: 0.828 - mean_q: 1.034 - mean_eps: 0.474 - ale.lives: 2.053
#
# Interval 13 (300000 steps performed)
# 25000/25000 [==============================] - 293s 12ms/step - reward: 0.0611
# 31 episodes - episode_reward: 49.742 [30.000, 90.000] - loss: 0.030 - mean_absolute_error: 0.912 - mean_q: 1.134 - mean_eps: 0.472 - ale.lives: 2.087
#
# Interval 14 (325000 steps performed)
# 25000/25000 [==============================] - 295s 12ms/step - reward: 0.0582
# 30 episodes - episode_reward: 48.900 [28.000, 79.000] - loss: 0.031 - mean_absolute_error: 0.985 - mean_q: 1.219 - mean_eps: 0.470 - ale.lives: 2.047
#
# Interval 15 (350000 steps performed)
# 25000/25000 [==============================] - 300s 12ms/step - reward: 0.06020s - reward: 0.0
# 31 episodes - episode_reward: 48.097 [28.000, 73.000] - loss: 0.033 - mean_absolute_error: 1.095 - mean_q: 1.343 - mean_eps: 0.468 - ale.lives: 2.145
#
# Interval 16 (375000 steps performed)
# 25000/25000 [==============================] - 297s 12ms/step - reward: 0.0585
# 30 episodes - episode_reward: 48.967 [29.000, 74.000] - loss: 0.034 - mean_absolute_error: 1.188 - mean_q: 1.450 - mean_eps: 0.466 - ale.lives: 2.019
#
# Interval 17 (400000 steps performed)
# 25000/25000 [==============================] - 302s 12ms/step - reward: 0.0581
# 31 episodes - episode_reward: 47.032 [21.000, 93.000] - loss: 0.037 - mean_absolute_error: 1.286 - mean_q: 1.562 - mean_eps: 0.463 - ale.lives: 2.159
#
# Interval 18 (425000 steps performed)
# 25000/25000 [==============================] - 307s 12ms/step - reward: 0.0584
# 29 episodes - episode_reward: 50.552 [29.000, 74.000] - loss: 0.039 - mean_absolute_error: 1.377 - mean_q: 1.667 - mean_eps: 0.461 - ale.lives: 2.131
#
# Interval 19 (450000 steps performed)
# 25000/25000 [==============================] - 303s 12ms/step - reward: 0.0632
# 31 episodes - episode_reward: 50.000 [29.000, 92.000] - loss: 0.043 - mean_absolute_error: 1.463 - mean_q: 1.766 - mean_eps: 0.459 - ale.lives: 2.086
#
# Interval 20 (475000 steps performed)
# 25000/25000 [==============================] - 303s 12ms/step - reward: 0.0627
# 29 episodes - episode_reward: 54.690 [27.000, 86.000] - loss: 0.045 - mean_absolute_error: 1.572 - mean_q: 1.892 - mean_eps: 0.457 - ale.lives: 2.199
#
# Interval 21 (500000 steps performed)
# 25000/25000 [==============================] - 306s 12ms/step - reward: 0.0652
# 30 episodes - episode_reward: 53.233 [22.000, 78.000] - loss: 0.047 - mean_absolute_error: 1.645 - mean_q: 1.972 - mean_eps: 0.454 - ale.lives: 2.157
#
# Interval 22 (525000 steps performed)
# 25000/25000 [==============================] - 305s 12ms/step - reward: 0.06280s - rewar
# 30 episodes - episode_reward: 51.333 [32.000, 85.000] - loss: 0.047 - mean_absolute_error: 1.690 - mean_q: 2.023 - mean_eps: 0.452 - ale.lives: 2.118
#
# Interval 23 (550000 steps performed)
# 25000/25000 [==============================] - 308s 12ms/step - reward: 0.06451s - reward: 0. - E
# 32 episodes - episode_reward: 50.875 [10.000, 101.000] - loss: 0.049 - mean_absolute_error: 1.807 - mean_q: 2.157 - mean_eps: 0.450 - ale.lives: 2.103
#
# Interval 24 (575000 steps performed)
# 25000/25000 [==============================] - 311s 12ms/step - reward: 0.0661
# 33 episodes - episode_reward: 51.697 [27.000, 83.000] - loss: 0.050 - mean_absolute_error: 1.884 - mean_q: 2.244 - mean_eps: 0.448 - ale.lives: 2.174
#
# Interval 25 (600000 steps performed)
# 25000/25000 [==============================] - 310s 12ms/step - reward: 0.0681
# 30 episodes - episode_reward: 55.367 [22.000, 101.000] - loss: 0.053 - mean_absolute_error: 1.984 - mean_q: 2.358 - mean_eps: 0.446 - ale.lives: 2.132
#
# Interval 26 (625000 steps performed)
# 25000/25000 [==============================] - 313s 13ms/step - reward: 0.0646
# 34 episodes - episode_reward: 49.029 [26.000, 78.000] - loss: 0.058 - mean_absolute_error: 2.143 - mean_q: 2.541 - mean_eps: 0.443 - ale.lives: 2.062
#
# Interval 27 (650000 steps performed)
# 25000/25000 [==============================] - 315s 13ms/step - reward: 0.0700
# 31 episodes - episode_reward: 55.355 [28.000, 83.000] - loss: 0.058 - mean_absolute_error: 2.233 - mean_q: 2.641 - mean_eps: 0.441 - ale.lives: 2.089
#
# Interval 28 (675000 steps performed)
# 25000/25000 [==============================] - 317s 13ms/step - reward: 0.0696
# 30 episodes - episode_reward: 59.133 [34.000, 91.000] - loss: 0.061 - mean_absolute_error: 2.355 - mean_q: 2.779 - mean_eps: 0.439 - ale.lives: 2.145
#
# Interval 29 (700000 steps performed)
# 25000/25000 [==============================] - 333s 13ms/step - reward: 0.0696
# 33 episodes - episode_reward: 52.727 [18.000, 84.000] - loss: 0.064 - mean_absolute_error: 2.487 - mean_q: 2.930 - mean_eps: 0.437 - ale.lives: 2.068
#
# Interval 30 (725000 steps performed)
# 25000/25000 [==============================] - 327s 13ms/step - reward: 0.0670
# 31 episodes - episode_reward: 52.968 [20.000, 95.000] - loss: 0.064 - mean_absolute_error: 2.549 - mean_q: 2.995 - mean_eps: 0.434 - ale.lives: 2.072
#
# Interval 31 (750000 steps performed)
# 25000/25000 [==============================] - 321s 13ms/step - reward: 0.0709
# 34 episodes - episode_reward: 52.824 [24.000, 95.000] - loss: 0.066 - mean_absolute_error: 2.612 - mean_q: 3.064 - mean_eps: 0.432 - ale.lives: 2.119
#
# Interval 32 (775000 steps performed)
# 25000/25000 [==============================] - 325s 13ms/step - reward: 0.06861s - rewar -
# 33 episodes - episode_reward: 52.152 [24.000, 94.000] - loss: 0.065 - mean_absolute_error: 2.682 - mean_q: 3.141 - mean_eps: 0.430 - ale.lives: 2.082
#
# Interval 33 (800000 steps performed)
# 25000/25000 [==============================] - 328s 13ms/step - reward: 0.0683
# 30 episodes - episode_reward: 56.967 [35.000, 103.000] - loss: 0.067 - mean_absolute_error: 2.756 - mean_q: 3.225 - mean_eps: 0.428 - ale.lives: 2.071
#
# Interval 34 (825000 steps performed)
# 25000/25000 [==============================] - 331s 13ms/step - reward: 0.0684
# 30 episodes - episode_reward: 54.933 [30.000, 93.000] - loss: 0.069 - mean_absolute_error: 2.862 - mean_q: 3.346 - mean_eps: 0.426 - ale.lives: 2.073
#
# Interval 35 (850000 steps performed)
# 25000/25000 [==============================] - 332s 13ms/step - reward: 0.0695
# 31 episodes - episode_reward: 56.452 [39.000, 81.000] - loss: 0.073 - mean_absolute_error: 2.988 - mean_q: 3.490 - mean_eps: 0.423 - ale.lives: 2.089
#
# Interval 36 (875000 steps performed)
# 25000/25000 [==============================] - 333s 13ms/step - reward: 0.0688
# 30 episodes - episode_reward: 58.933 [36.000, 93.000] - loss: 0.075 - mean_absolute_error: 3.090 - mean_q: 3.605 - mean_eps: 0.421 - ale.lives: 2.034
#
# Interval 37 (900000 steps performed)
# 25000/25000 [==============================] - 335s 13ms/step - reward: 0.0725
# 32 episodes - episode_reward: 56.500 [39.000, 86.000] - loss: 0.079 - mean_absolute_error: 3.210 - mean_q: 3.741 - mean_eps: 0.419 - ale.lives: 2.108
#
# Interval 38 (925000 steps performed)
# 25000/25000 [==============================] - 346s 14ms/step - reward: 0.0733
# 30 episodes - episode_reward: 59.967 [29.000, 107.000] - loss: 0.079 - mean_absolute_error: 3.276 - mean_q: 3.814 - mean_eps: 0.417 - ale.lives: 2.131
#
# Interval 39 (950000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0708
# 33 episodes - episode_reward: 53.727 [23.000, 91.000] - loss: 0.081 - mean_absolute_error: 3.326 - mean_q: 3.868 - mean_eps: 0.414 - ale.lives: 2.063
#
# Interval 40 (975000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0752
# 34 episodes - episode_reward: 55.735 [29.000, 91.000] - loss: 0.083 - mean_absolute_error: 3.350 - mean_q: 3.898 - mean_eps: 0.412 - ale.lives: 2.174
#
# Interval 41 (1000000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0726
# 34 episodes - episode_reward: 53.118 [28.000, 96.000] - loss: 0.084 - mean_absolute_error: 3.518 - mean_q: 4.090 - mean_eps: 0.410 - ale.lives: 2.133
#
# Interval 42 (1025000 steps performed)
# 25000/25000 [==============================] - 365s 15ms/step - reward: 0.0743
# 32 episodes - episode_reward: 57.844 [22.000, 94.000] - loss: 0.085 - mean_absolute_error: 3.517 - mean_q: 4.088 - mean_eps: 0.408 - ale.lives: 2.148
#
# Interval 43 (1050000 steps performed)
# 25000/25000 [==============================] - 362s 14ms/step - reward: 0.0742
# 33 episodes - episode_reward: 56.636 [38.000, 91.000] - loss: 0.086 - mean_absolute_error: 3.601 - mean_q: 4.182 - mean_eps: 0.406 - ale.lives: 2.058
#
# Interval 44 (1075000 steps performed)
# 25000/25000 [==============================] - 362s 14ms/step - reward: 0.0715
# 31 episodes - episode_reward: 57.355 [34.000, 92.000] - loss: 0.088 - mean_absolute_error: 3.649 - mean_q: 4.237 - mean_eps: 0.403 - ale.lives: 2.079
#
# Interval 45 (1100000 steps performed)
# 25000/25000 [==============================] - 361s 14ms/step - reward: 0.0728
# 30 episodes - episode_reward: 60.900 [28.000, 88.000] - loss: 0.088 - mean_absolute_error: 3.763 - mean_q: 4.361 - mean_eps: 0.401 - ale.lives: 2.038
#
# Interval 46 (1125000 steps performed)
# 25000/25000 [==============================] - 361s 14ms/step - reward: 0.0753
# 33 episodes - episode_reward: 57.727 [26.000, 89.000] - loss: 0.091 - mean_absolute_error: 3.845 - mean_q: 4.450 - mean_eps: 0.399 - ale.lives: 2.109
#
# Interval 47 (1150000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0714
# 32 episodes - episode_reward: 55.750 [23.000, 103.000] - loss: 0.090 - mean_absolute_error: 3.878 - mean_q: 4.483 - mean_eps: 0.397 - ale.lives: 2.050
#
# Interval 48 (1175000 steps performed)
# 25000/25000 [==============================] - 374s 15ms/step - reward: 0.0718
# 33 episodes - episode_reward: 54.455 [32.000, 100.000] - loss: 0.091 - mean_absolute_error: 3.965 - mean_q: 4.581 - mean_eps: 0.394 - ale.lives: 2.092
#
# Interval 49 (1200000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0752
# 30 episodes - episode_reward: 61.200 [31.000, 103.000] - loss: 0.095 - mean_absolute_error: 4.023 - mean_q: 4.644 - mean_eps: 0.392 - ale.lives: 2.080
#
# Interval 50 (1225000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0741
# 35 episodes - episode_reward: 52.714 [17.000, 87.000] - loss: 0.096 - mean_absolute_error: 4.064 - mean_q: 4.692 - mean_eps: 0.390 - ale.lives: 2.100
#
# Interval 51 (1250000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0748
# 33 episodes - episode_reward: 56.909 [24.000, 83.000] - loss: 0.097 - mean_absolute_error: 4.115 - mean_q: 4.749 - mean_eps: 0.388 - ale.lives: 2.054
#
# Interval 52 (1275000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0734
# 33 episodes - episode_reward: 56.939 [28.000, 85.000] - loss: 0.098 - mean_absolute_error: 4.204 - mean_q: 4.848 - mean_eps: 0.386 - ale.lives: 2.110
#
# Interval 53 (1300000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0770
# 31 episodes - episode_reward: 60.290 [22.000, 104.000] - loss: 0.095 - mean_absolute_error: 4.261 - mean_q: 4.910 - mean_eps: 0.383 - ale.lives: 2.100
#
# Interval 54 (1325000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0759
# 31 episodes - episode_reward: 61.968 [27.000, 100.000] - loss: 0.095 - mean_absolute_error: 4.281 - mean_q: 4.931 - mean_eps: 0.381 - ale.lives: 2.127
#
# Interval 55 (1350000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0790
# 31 episodes - episode_reward: 62.452 [22.000, 106.000] - loss: 0.096 - mean_absolute_error: 4.379 - mean_q: 5.039 - mean_eps: 0.379 - ale.lives: 2.040
#
# Interval 56 (1375000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0747
# 31 episodes - episode_reward: 61.871 [39.000, 92.000] - loss: 0.095 - mean_absolute_error: 4.471 - mean_q: 5.144 - mean_eps: 0.377 - ale.lives: 2.154
#
# Interval 57 (1400000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0750
# 33 episodes - episode_reward: 56.879 [23.000, 94.000] - loss: 0.096 - mean_absolute_error: 4.539 - mean_q: 5.218 - mean_eps: 0.374 - ale.lives: 2.058
#
# Interval 58 (1425000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0809
# 30 episodes - episode_reward: 66.300 [32.000, 114.000] - loss: 0.096 - mean_absolute_error: 4.587 - mean_q: 5.271 - mean_eps: 0.372 - ale.lives: 2.153
#
# Interval 59 (1450000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0738
# 30 episodes - episode_reward: 61.233 [33.000, 99.000] - loss: 0.096 - mean_absolute_error: 4.623 - mean_q: 5.316 - mean_eps: 0.370 - ale.lives: 2.011
#
# Interval 60 (1475000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0756
# 32 episodes - episode_reward: 60.156 [24.000, 105.000] - loss: 0.099 - mean_absolute_error: 4.634 - mean_q: 5.329 - mean_eps: 0.368 - ale.lives: 2.109
#
# Interval 61 (1500000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0772
# 30 episodes - episode_reward: 64.567 [40.000, 98.000] - loss: 0.099 - mean_absolute_error: 4.653 - mean_q: 5.349 - mean_eps: 0.366 - ale.lives: 2.096
#
# Interval 62 (1525000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0782
# 32 episodes - episode_reward: 61.125 [30.000, 99.000] - loss: 0.100 - mean_absolute_error: 4.719 - mean_q: 5.423 - mean_eps: 0.363 - ale.lives: 2.133
#
# Interval 63 (1550000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0754
# 33 episodes - episode_reward: 56.758 [32.000, 90.000] - loss: 0.106 - mean_absolute_error: 4.805 - mean_q: 5.523 - mean_eps: 0.361 - ale.lives: 2.098
#
# Interval 64 (1575000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0756
# 30 episodes - episode_reward: 62.767 [29.000, 127.000] - loss: 0.106 - mean_absolute_error: 4.906 - mean_q: 5.638 - mean_eps: 0.359 - ale.lives: 2.134
#
# Interval 65 (1600000 steps performed)
# 25000/25000 [==============================] - 348s 14ms/step - reward: 0.0779
# 29 episodes - episode_reward: 65.897 [33.000, 112.000] - loss: 0.107 - mean_absolute_error: 4.956 - mean_q: 5.693 - mean_eps: 0.357 - ale.lives: 2.078
#
# Interval 66 (1625000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0778
# 30 episodes - episode_reward: 65.867 [38.000, 98.000] - loss: 0.106 - mean_absolute_error: 5.020 - mean_q: 5.762 - mean_eps: 0.354 - ale.lives: 2.069
#
# Interval 67 (1650000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0785
# 31 episodes - episode_reward: 63.258 [30.000, 93.000] - loss: 0.104 - mean_absolute_error: 5.071 - mean_q: 5.818 - mean_eps: 0.352 - ale.lives: 2.141
#
# Interval 68 (1675000 steps performed)
# 25000/25000 [==============================] - 349s 14ms/step - reward: 0.0779
# 28 episodes - episode_reward: 68.536 [34.000, 105.000] - loss: 0.101 - mean_absolute_error: 5.119 - mean_q: 5.873 - mean_eps: 0.350 - ale.lives: 2.057
#
# Interval 69 (1700000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0777
# 31 episodes - episode_reward: 62.613 [24.000, 89.000] - loss: 0.102 - mean_absolute_error: 5.153 - mean_q: 5.911 - mean_eps: 0.348 - ale.lives: 2.144
#
# Interval 70 (1725000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0765
# 28 episodes - episode_reward: 70.393 [44.000, 104.000] - loss: 0.104 - mean_absolute_error: 5.195 - mean_q: 5.957 - mean_eps: 0.346 - ale.lives: 2.113
#
# Interval 71 (1750000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0805
# 28 episodes - episode_reward: 69.464 [47.000, 84.000] - loss: 0.106 - mean_absolute_error: 5.229 - mean_q: 5.995 - mean_eps: 0.343 - ale.lives: 2.040
#
# Interval 72 (1775000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0791
# 31 episodes - episode_reward: 66.387 [32.000, 101.000] - loss: 0.106 - mean_absolute_error: 5.313 - mean_q: 6.092 - mean_eps: 0.341 - ale.lives: 2.072
#
# Interval 73 (1800000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0773
# 28 episodes - episode_reward: 69.036 [35.000, 100.000] - loss: 0.108 - mean_absolute_error: 5.386 - mean_q: 6.178 - mean_eps: 0.339 - ale.lives: 2.126
#
# Interval 74 (1825000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0809
# 30 episodes - episode_reward: 65.600 [34.000, 108.000] - loss: 0.108 - mean_absolute_error: 5.461 - mean_q: 6.259 - mean_eps: 0.337 - ale.lives: 2.008
#
# Interval 75 (1850000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0793
# 31 episodes - episode_reward: 63.806 [20.000, 90.000] - loss: 0.110 - mean_absolute_error: 5.517 - mean_q: 6.323 - mean_eps: 0.334 - ale.lives: 2.088
#
# Interval 76 (1875000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0834
# 32 episodes - episode_reward: 66.812 [44.000, 99.000] - loss: 0.111 - mean_absolute_error: 5.619 - mean_q: 6.437 - mean_eps: 0.332 - ale.lives: 2.095
#
# Interval 77 (1900000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0800
# 30 episodes - episode_reward: 66.767 [32.000, 100.000] - loss: 0.113 - mean_absolute_error: 5.607 - mean_q: 6.422 - mean_eps: 0.330 - ale.lives: 2.125
#
# Interval 78 (1925000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0818
# 27 episodes - episode_reward: 74.444 [43.000, 106.000] - loss: 0.113 - mean_absolute_error: 5.653 - mean_q: 6.474 - mean_eps: 0.328 - ale.lives: 2.192
#
# Interval 79 (1950000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0840
# 30 episodes - episode_reward: 68.900 [39.000, 98.000] - loss: 0.111 - mean_absolute_error: 5.666 - mean_q: 6.489 - mean_eps: 0.326 - ale.lives: 2.033
#
# Interval 80 (1975000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0782
# 30 episodes - episode_reward: 66.767 [33.000, 113.000] - loss: 0.112 - mean_absolute_error: 5.734 - mean_q: 6.565 - mean_eps: 0.323 - ale.lives: 2.127
#
# Interval 81 (2000000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0810
# 33 episodes - episode_reward: 61.455 [38.000, 96.000] - loss: 0.111 - mean_absolute_error: 5.755 - mean_q: 6.587 - mean_eps: 0.321 - ale.lives: 2.152
#
# Interval 82 (2025000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0800
# 30 episodes - episode_reward: 67.267 [33.000, 104.000] - loss: 0.113 - mean_absolute_error: 5.850 - mean_q: 6.693 - mean_eps: 0.319 - ale.lives: 2.108
#
# Interval 83 (2050000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0802
# 29 episodes - episode_reward: 67.690 [45.000, 103.000] - loss: 0.110 - mean_absolute_error: 5.903 - mean_q: 6.752 - mean_eps: 0.317 - ale.lives: 2.198
#
# Interval 84 (2075000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0773
# 29 episodes - episode_reward: 67.586 [28.000, 127.000] - loss: 0.111 - mean_absolute_error: 5.910 - mean_q: 6.758 - mean_eps: 0.314 - ale.lives: 2.108
#
# Interval 85 (2100000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0806
# 27 episodes - episode_reward: 72.704 [41.000, 99.000] - loss: 0.112 - mean_absolute_error: 5.888 - mean_q: 6.732 - mean_eps: 0.312 - ale.lives: 2.135
#
# Interval 86 (2125000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0791
# 29 episodes - episode_reward: 69.793 [29.000, 112.000] - loss: 0.117 - mean_absolute_error: 5.967 - mean_q: 6.823 - mean_eps: 0.310 - ale.lives: 2.142
#
# Interval 87 (2150000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0820
# 26 episodes - episode_reward: 79.077 [35.000, 119.000] - loss: 0.114 - mean_absolute_error: 5.977 - mean_q: 6.832 - mean_eps: 0.308 - ale.lives: 2.081
#
# Interval 88 (2175000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0817
# 27 episodes - episode_reward: 73.778 [38.000, 105.000] - loss: 0.109 - mean_absolute_error: 6.029 - mean_q: 6.890 - mean_eps: 0.306 - ale.lives: 2.117
#
# Interval 89 (2200000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0797
# 27 episodes - episode_reward: 76.333 [38.000, 117.000] - loss: 0.113 - mean_absolute_error: 6.052 - mean_q: 6.916 - mean_eps: 0.303 - ale.lives: 2.053
#
# Interval 90 (2225000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0823
# 26 episodes - episode_reward: 75.423 [39.000, 105.000] - loss: 0.113 - mean_absolute_error: 6.081 - mean_q: 6.950 - mean_eps: 0.301 - ale.lives: 2.090
#
# Interval 91 (2250000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0856
# 29 episodes - episode_reward: 75.207 [37.000, 108.000] - loss: 0.115 - mean_absolute_error: 6.122 - mean_q: 6.994 - mean_eps: 0.299 - ale.lives: 2.025
#
# Interval 92 (2275000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0816
# 28 episodes - episode_reward: 73.214 [29.000, 105.000] - loss: 0.112 - mean_absolute_error: 6.158 - mean_q: 7.032 - mean_eps: 0.297 - ale.lives: 2.131
#
# Interval 93 (2300000 steps performed)
# 25000/25000 [==============================] - 345s 14ms/step - reward: 0.0855
# 28 episodes - episode_reward: 77.286 [46.000, 110.000] - loss: 0.112 - mean_absolute_error: 6.166 - mean_q: 7.042 - mean_eps: 0.294 - ale.lives: 2.102
#
# Interval 94 (2325000 steps performed)
# 25000/25000 [==============================] - 346s 14ms/step - reward: 0.0815
# 28 episodes - episode_reward: 70.107 [45.000, 99.000] - loss: 0.114 - mean_absolute_error: 6.198 - mean_q: 7.076 - mean_eps: 0.292 - ale.lives: 2.091
#
# Interval 95 (2350000 steps performed)
# 25000/25000 [==============================] - 346s 14ms/step - reward: 0.0849
# 28 episodes - episode_reward: 79.179 [48.000, 101.000] - loss: 0.114 - mean_absolute_error: 6.200 - mean_q: 7.082 - mean_eps: 0.290 - ale.lives: 2.139
#
# Interval 96 (2375000 steps performed)
# 25000/25000 [==============================] - 347s 14ms/step - reward: 0.0840
# 28 episodes - episode_reward: 73.750 [35.000, 109.000] - loss: 0.114 - mean_absolute_error: 6.272 - mean_q: 7.161 - mean_eps: 0.288 - ale.lives: 2.126
#
# Interval 97 (2400000 steps performed)
# 25000/25000 [==============================] - 347s 14ms/step - reward: 0.0790
# 26 episodes - episode_reward: 76.308 [29.000, 117.000] - loss: 0.116 - mean_absolute_error: 6.326 - mean_q: 7.222 - mean_eps: 0.286 - ale.lives: 2.105
#
# Interval 98 (2425000 steps performed)
# 25000/25000 [==============================] - 347s 14ms/step - reward: 0.0862
# 29 episodes - episode_reward: 72.897 [38.000, 107.000] - loss: 0.117 - mean_absolute_error: 6.358 - mean_q: 7.258 - mean_eps: 0.283 - ale.lives: 2.109
#
# Interval 99 (2450000 steps performed)
# 25000/25000 [==============================] - 349s 14ms/step - reward: 0.0823
# 28 episodes - episode_reward: 75.857 [37.000, 112.000] - loss: 0.118 - mean_absolute_error: 6.469 - mean_q: 7.386 - mean_eps: 0.281 - ale.lives: 2.088
#
# Interval 100 (2475000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0853
# 28 episodes - episode_reward: 76.214 [34.000, 114.000] - loss: 0.112 - mean_absolute_error: 6.479 - mean_q: 7.395 - mean_eps: 0.279 - ale.lives: 2.091
#
# Interval 101 (2500000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0828
# 27 episodes - episode_reward: 75.778 [37.000, 105.000] - loss: 0.112 - mean_absolute_error: 6.520 - mean_q: 7.437 - mean_eps: 0.277 - ale.lives: 2.078
#
# Interval 102 (2525000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0846
# 25 episodes - episode_reward: 81.200 [42.000, 109.000] - loss: 0.110 - mean_absolute_error: 6.587 - mean_q: 7.513 - mean_eps: 0.274 - ale.lives: 2.102
#
# Interval 103 (2550000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0830
# 29 episodes - episode_reward: 73.172 [32.000, 119.000] - loss: 0.111 - mean_absolute_error: 6.560 - mean_q: 7.483 - mean_eps: 0.272 - ale.lives: 2.144
#
# Interval 104 (2575000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0889
# 27 episodes - episode_reward: 83.556 [50.000, 115.000] - loss: 0.111 - mean_absolute_error: 6.605 - mean_q: 7.535 - mean_eps: 0.270 - ale.lives: 2.160
#
# Interval 105 (2600000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0871
# 29 episodes - episode_reward: 75.931 [46.000, 104.000] - loss: 0.116 - mean_absolute_error: 6.634 - mean_q: 7.569 - mean_eps: 0.268 - ale.lives: 2.077
#
# Interval 106 (2625000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0860
# 26 episodes - episode_reward: 81.692 [47.000, 125.000] - loss: 0.117 - mean_absolute_error: 6.659 - mean_q: 7.595 - mean_eps: 0.266 - ale.lives: 2.088
#
# Interval 107 (2650000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0837
# 25 episodes - episode_reward: 81.920 [53.000, 115.000] - loss: 0.117 - mean_absolute_error: 6.658 - mean_q: 7.593 - mean_eps: 0.263 - ale.lives: 2.184
#
# Interval 108 (2675000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0865
# 27 episodes - episode_reward: 82.667 [45.000, 116.000] - loss: 0.117 - mean_absolute_error: 6.745 - mean_q: 7.693 - mean_eps: 0.261 - ale.lives: 2.120
#
# Interval 109 (2700000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0861
# 27 episodes - episode_reward: 79.815 [50.000, 117.000] - loss: 0.117 - mean_absolute_error: 6.779 - mean_q: 7.731 - mean_eps: 0.259 - ale.lives: 2.126
#
# Interval 110 (2725000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0867
# 25 episodes - episode_reward: 84.680 [44.000, 129.000] - loss: 0.115 - mean_absolute_error: 6.824 - mean_q: 7.785 - mean_eps: 0.257 - ale.lives: 2.106
#
# Interval 111 (2750000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0866
# 28 episodes - episode_reward: 77.071 [46.000, 124.000] - loss: 0.115 - mean_absolute_error: 6.803 - mean_q: 7.762 - mean_eps: 0.254 - ale.lives: 2.175
#
# Interval 112 (2775000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0850
# 28 episodes - episode_reward: 76.571 [41.000, 117.000] - loss: 0.120 - mean_absolute_error: 6.860 - mean_q: 7.826 - mean_eps: 0.252 - ale.lives: 2.144
#
# Interval 113 (2800000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0872
# 25 episodes - episode_reward: 84.680 [48.000, 130.000] - loss: 0.118 - mean_absolute_error: 6.912 - mean_q: 7.886 - mean_eps: 0.250 - ale.lives: 2.089
#
# Interval 114 (2825000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0851
# 26 episodes - episode_reward: 84.115 [43.000, 122.000] - loss: 0.118 - mean_absolute_error: 6.916 - mean_q: 7.889 - mean_eps: 0.248 - ale.lives: 2.115
#
# Interval 115 (2850000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0837
# 28 episodes - episode_reward: 75.143 [43.000, 101.000] - loss: 0.117 - mean_absolute_error: 6.867 - mean_q: 7.833 - mean_eps: 0.246 - ale.lives: 2.167
#
# Interval 116 (2875000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0794
# 26 episodes - episode_reward: 75.423 [47.000, 117.000] - loss: 0.117 - mean_absolute_error: 6.917 - mean_q: 7.891 - mean_eps: 0.243 - ale.lives: 2.037
#
# Interval 117 (2900000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0885
# 27 episodes - episode_reward: 81.296 [42.000, 112.000] - loss: 0.121 - mean_absolute_error: 6.923 - mean_q: 7.895 - mean_eps: 0.241 - ale.lives: 2.089
#
# Interval 118 (2925000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0867
# 27 episodes - episode_reward: 81.148 [47.000, 114.000] - loss: 0.120 - mean_absolute_error: 6.956 - mean_q: 7.933 - mean_eps: 0.239 - ale.lives: 2.174
#
# Interval 119 (2950000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0859
# 29 episodes - episode_reward: 74.690 [36.000, 106.000] - loss: 0.119 - mean_absolute_error: 6.958 - mean_q: 7.936 - mean_eps: 0.237 - ale.lives: 2.161
#
# Interval 120 (2975000 steps performed)
# 25000/25000 [==============================] - 361s 14ms/step - reward: 0.0873
# 26 episodes - episode_reward: 84.269 [41.000, 122.000] - loss: 0.117 - mean_absolute_error: 6.967 - mean_q: 7.946 - mean_eps: 0.234 - ale.lives: 2.079
#
# Interval 121 (3000000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0868
# 26 episodes - episode_reward: 83.615 [47.000, 108.000] - loss: 0.119 - mean_absolute_error: 6.977 - mean_q: 7.958 - mean_eps: 0.232 - ale.lives: 2.144
#
# Interval 122 (3025000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0892
# 27 episodes - episode_reward: 81.593 [41.000, 120.000] - loss: 0.112 - mean_absolute_error: 6.950 - mean_q: 7.924 - mean_eps: 0.230 - ale.lives: 2.085
#
# Interval 123 (3050000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0881
# 26 episodes - episode_reward: 83.077 [46.000, 118.000] - loss: 0.112 - mean_absolute_error: 6.924 - mean_q: 7.897 - mean_eps: 0.228 - ale.lives: 2.122
#
# Interval 124 (3075000 steps performed)
# 25000/25000 [==============================] - 349s 14ms/step - reward: 0.0894
# 27 episodes - episode_reward: 85.926 [47.000, 114.000] - loss: 0.114 - mean_absolute_error: 6.910 - mean_q: 7.883 - mean_eps: 0.226 - ale.lives: 2.119
#
# Interval 125 (3100000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0876
# 26 episodes - episode_reward: 82.654 [48.000, 121.000] - loss: 0.111 - mean_absolute_error: 6.888 - mean_q: 7.855 - mean_eps: 0.223 - ale.lives: 2.134
#
# Interval 126 (3125000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0892
# 27 episodes - episode_reward: 81.370 [41.000, 120.000] - loss: 0.112 - mean_absolute_error: 6.927 - mean_q: 7.898 - mean_eps: 0.221 - ale.lives: 2.176
#
# Interval 127 (3150000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0901
# 27 episodes - episode_reward: 85.519 [55.000, 121.000] - loss: 0.110 - mean_absolute_error: 6.907 - mean_q: 7.876 - mean_eps: 0.219 - ale.lives: 2.118
#
# Interval 128 (3175000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0921
# 26 episodes - episode_reward: 86.154 [56.000, 114.000] - loss: 0.112 - mean_absolute_error: 7.011 - mean_q: 7.991 - mean_eps: 0.217 - ale.lives: 2.203
#
# Interval 129 (3200000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0894
# 26 episodes - episode_reward: 84.731 [47.000, 120.000] - loss: 0.112 - mean_absolute_error: 6.992 - mean_q: 7.972 - mean_eps: 0.214 - ale.lives: 2.131
#
# Interval 130 (3225000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0808
# 24 episodes - episode_reward: 87.708 [39.000, 111.000] - loss: 0.109 - mean_absolute_error: 6.999 - mean_q: 7.982 - mean_eps: 0.212 - ale.lives: 2.178
#
# Interval 131 (3250000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0923
# 25 episodes - episode_reward: 92.360 [61.000, 116.000] - loss: 0.112 - mean_absolute_error: 7.004 - mean_q: 7.985 - mean_eps: 0.210 - ale.lives: 2.184
#
# Interval 132 (3275000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0890
# 27 episodes - episode_reward: 80.778 [33.000, 107.000] - loss: 0.113 - mean_absolute_error: 7.055 - mean_q: 8.044 - mean_eps: 0.208 - ale.lives: 2.145
#
# Interval 133 (3300000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0912
# 26 episodes - episode_reward: 88.923 [67.000, 112.000] - loss: 0.113 - mean_absolute_error: 7.071 - mean_q: 8.061 - mean_eps: 0.206 - ale.lives: 2.114
#
# Interval 134 (3325000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0895
# 25 episodes - episode_reward: 89.000 [54.000, 132.000] - loss: 0.112 - mean_absolute_error: 7.083 - mean_q: 8.076 - mean_eps: 0.203 - ale.lives: 2.035
#
# Interval 135 (3350000 steps performed)
# 25000/25000 [==============================] - 366s 15ms/step - reward: 0.0904
# 26 episodes - episode_reward: 86.769 [48.000, 125.000] - loss: 0.110 - mean_absolute_error: 7.097 - mean_q: 8.092 - mean_eps: 0.201 - ale.lives: 2.062
#
# Interval 136 (3375000 steps performed)
# 25000/25000 [==============================] - 372s 15ms/step - reward: 0.0905
# 27 episodes - episode_reward: 84.667 [51.000, 129.000] - loss: 0.109 - mean_absolute_error: 7.052 - mean_q: 8.041 - mean_eps: 0.199 - ale.lives: 2.170
#
# Interval 137 (3400000 steps performed)
# 25000/25000 [==============================] - 370s 15ms/step - reward: 0.0890
# 26 episodes - episode_reward: 86.654 [43.000, 120.000] - loss: 0.109 - mean_absolute_error: 7.085 - mean_q: 8.078 - mean_eps: 0.197 - ale.lives: 2.142
#
# Interval 138 (3425000 steps performed)
# 25000/25000 [==============================] - 369s 15ms/step - reward: 0.0891
# 23 episodes - episode_reward: 92.522 [42.000, 135.000] - loss: 0.109 - mean_absolute_error: 7.070 - mean_q: 8.061 - mean_eps: 0.194 - ale.lives: 2.185
#
# Interval 139 (3450000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0906
# 25 episodes - episode_reward: 93.040 [40.000, 139.000] - loss: 0.111 - mean_absolute_error: 7.066 - mean_q: 8.058 - mean_eps: 0.192 - ale.lives: 2.125
#
# Interval 140 (3475000 steps performed)
# 25000/25000 [==============================] - 366s 15ms/step - reward: 0.09490s - reward
# 27 episodes - episode_reward: 86.407 [57.000, 119.000] - loss: 0.110 - mean_absolute_error: 7.063 - mean_q: 8.053 - mean_eps: 0.190 - ale.lives: 2.188
#
# Interval 141 (3500000 steps performed)
# 25000/25000 [==============================] - 369s 15ms/step - reward: 0.0897
# 27 episodes - episode_reward: 82.889 [40.000, 121.000] - loss: 0.112 - mean_absolute_error: 7.063 - mean_q: 8.051 - mean_eps: 0.188 - ale.lives: 2.133
#
# Interval 142 (3525000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0866
# 27 episodes - episode_reward: 83.296 [48.000, 125.000] - loss: 0.109 - mean_absolute_error: 7.087 - mean_q: 8.080 - mean_eps: 0.186 - ale.lives: 2.137
#
# Interval 143 (3550000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0882
# 24 episodes - episode_reward: 88.583 [48.000, 130.000] - loss: 0.108 - mean_absolute_error: 7.083 - mean_q: 8.073 - mean_eps: 0.183 - ale.lives: 2.076
#
# Interval 144 (3575000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0924
# 29 episodes - episode_reward: 82.345 [35.000, 127.000] - loss: 0.110 - mean_absolute_error: 7.140 - mean_q: 8.137 - mean_eps: 0.181 - ale.lives: 2.201
#
# Interval 145 (3600000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0915
# 26 episodes - episode_reward: 88.000 [40.000, 119.000] - loss: 0.112 - mean_absolute_error: 7.181 - mean_q: 8.183 - mean_eps: 0.179 - ale.lives: 2.229
#
# Interval 146 (3625000 steps performed)
# 25000/25000 [==============================] - 363s 15ms/step - reward: 0.0933
# 26 episodes - episode_reward: 88.538 [41.000, 113.000] - loss: 0.109 - mean_absolute_error: 7.179 - mean_q: 8.179 - mean_eps: 0.177 - ale.lives: 2.188
#
# Interval 147 (3650000 steps performed)
# 25000/25000 [==============================] - 362s 14ms/step - reward: 0.0941
# 24 episodes - episode_reward: 95.458 [45.000, 133.000] - loss: 0.110 - mean_absolute_error: 7.167 - mean_q: 8.167 - mean_eps: 0.174 - ale.lives: 2.187
#
# Interval 148 (3675000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0880
# 23 episodes - episode_reward: 99.696 [74.000, 134.000] - loss: 0.110 - mean_absolute_error: 7.144 - mean_q: 8.140 - mean_eps: 0.172 - ale.lives: 2.099
#
# Interval 149 (3700000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0975
# 27 episodes - episode_reward: 86.556 [58.000, 115.000] - loss: 0.111 - mean_absolute_error: 7.196 - mean_q: 8.203 - mean_eps: 0.170 - ale.lives: 2.184
#
# Interval 150 (3725000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0964
# 27 episodes - episode_reward: 90.111 [29.000, 130.000] - loss: 0.109 - mean_absolute_error: 7.181 - mean_q: 8.184 - mean_eps: 0.168 - ale.lives: 2.244
#
# Interval 151 (3750000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0992
# 27 episodes - episode_reward: 92.000 [66.000, 119.000] - loss: 0.108 - mean_absolute_error: 7.203 - mean_q: 8.210 - mean_eps: 0.166 - ale.lives: 2.230
#
# Interval 152 (3775000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0954
# 27 episodes - episode_reward: 89.926 [44.000, 126.000] - loss: 0.112 - mean_absolute_error: 7.176 - mean_q: 8.177 - mean_eps: 0.163 - ale.lives: 2.099
#
# Interval 153 (3800000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0933
# 25 episodes - episode_reward: 91.160 [59.000, 116.000] - loss: 0.115 - mean_absolute_error: 7.171 - mean_q: 8.172 - mean_eps: 0.161 - ale.lives: 2.155
#
# Interval 154 (3825000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0940
# 27 episodes - episode_reward: 87.407 [49.000, 120.000] - loss: 0.112 - mean_absolute_error: 7.156 - mean_q: 8.156 - mean_eps: 0.159 - ale.lives: 2.197
#
# Interval 155 (3850000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0888
# 25 episodes - episode_reward: 87.680 [47.000, 125.000] - loss: 0.110 - mean_absolute_error: 7.160 - mean_q: 8.160 - mean_eps: 0.157 - ale.lives: 2.204
#
# Interval 156 (3875000 steps performed)
# 25000/25000 [==============================] - 351s 14ms/step - reward: 0.0891
# 24 episodes - episode_reward: 93.042 [57.000, 131.000] - loss: 0.111 - mean_absolute_error: 7.118 - mean_q: 8.114 - mean_eps: 0.154 - ale.lives: 2.258
#
# Interval 157 (3900000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0953
# 27 episodes - episode_reward: 90.926 [69.000, 122.000] - loss: 0.110 - mean_absolute_error: 7.148 - mean_q: 8.149 - mean_eps: 0.152 - ale.lives: 2.224
#
# Interval 158 (3925000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0942
# 25 episodes - episode_reward: 92.480 [61.000, 124.000] - loss: 0.113 - mean_absolute_error: 7.180 - mean_q: 8.184 - mean_eps: 0.150 - ale.lives: 2.180
#
# Interval 159 (3950000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0915
# 24 episodes - episode_reward: 94.958 [54.000, 133.000] - loss: 0.118 - mean_absolute_error: 7.192 - mean_q: 8.198 - mean_eps: 0.148 - ale.lives: 2.233
#
# Interval 160 (3975000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0960
# 25 episodes - episode_reward: 95.200 [52.000, 132.000] - loss: 0.116 - mean_absolute_error: 7.208 - mean_q: 8.216 - mean_eps: 0.146 - ale.lives: 2.198
#
# Interval 161 (4000000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0960
# 26 episodes - episode_reward: 94.269 [69.000, 129.000] - loss: 0.116 - mean_absolute_error: 7.323 - mean_q: 8.345 - mean_eps: 0.143 - ale.lives: 2.202
#
# Interval 162 (4025000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0919
# 24 episodes - episode_reward: 94.833 [44.000, 128.000] - loss: 0.115 - mean_absolute_error: 7.340 - mean_q: 8.364 - mean_eps: 0.141 - ale.lives: 2.182
#
# Interval 163 (4050000 steps performed)
# 25000/25000 [==============================] - 350s 14ms/step - reward: 0.0917
# 25 episodes - episode_reward: 94.480 [60.000, 127.000] - loss: 0.114 - mean_absolute_error: 7.285 - mean_q: 8.300 - mean_eps: 0.139 - ale.lives: 2.115
#
# Interval 164 (4075000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0978
# 25 episodes - episode_reward: 96.400 [54.000, 136.000] - loss: 0.112 - mean_absolute_error: 7.328 - mean_q: 8.347 - mean_eps: 0.137 - ale.lives: 2.241
#
# Interval 165 (4100000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0930
# 24 episodes - episode_reward: 96.125 [57.000, 127.000] - loss: 0.113 - mean_absolute_error: 7.307 - mean_q: 8.324 - mean_eps: 0.134 - ale.lives: 2.241
#
# Interval 166 (4125000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0981
# 27 episodes - episode_reward: 90.630 [57.000, 124.000] - loss: 0.111 - mean_absolute_error: 7.347 - mean_q: 8.367 - mean_eps: 0.132 - ale.lives: 2.319
#
# Interval 167 (4150000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0968
# 27 episodes - episode_reward: 89.704 [42.000, 133.000] - loss: 0.112 - mean_absolute_error: 7.360 - mean_q: 8.385 - mean_eps: 0.130 - ale.lives: 2.192
#
# Interval 168 (4175000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0905
# 25 episodes - episode_reward: 92.000 [42.000, 133.000] - loss: 0.110 - mean_absolute_error: 7.361 - mean_q: 8.387 - mean_eps: 0.128 - ale.lives: 2.166
#
# Interval 169 (4200000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0958
# 24 episodes - episode_reward: 100.583 [54.000, 138.000] - loss: 0.110 - mean_absolute_error: 7.322 - mean_q: 8.342 - mean_eps: 0.126 - ale.lives: 2.158
#
# Interval 170 (4225000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0933
# 24 episodes - episode_reward: 94.000 [46.000, 129.000] - loss: 0.108 - mean_absolute_error: 7.312 - mean_q: 8.329 - mean_eps: 0.123 - ale.lives: 2.221
#
# Interval 171 (4250000 steps performed)
# 25000/25000 [==============================] - 356s 14ms/step - reward: 0.0928
# 26 episodes - episode_reward: 90.385 [47.000, 125.000] - loss: 0.108 - mean_absolute_error: 7.289 - mean_q: 8.303 - mean_eps: 0.121 - ale.lives: 2.222
#
# Interval 172 (4275000 steps performed)
# 25000/25000 [==============================] - 355s 14ms/step - reward: 0.0992
# 27 episodes - episode_reward: 93.519 [37.000, 142.000] - loss: 0.108 - mean_absolute_error: 7.262 - mean_q: 8.275 - mean_eps: 0.119 - ale.lives: 2.176
#
# Interval 173 (4300000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0970
# 23 episodes - episode_reward: 104.391 [79.000, 130.000] - loss: 0.108 - mean_absolute_error: 7.246 - mean_q: 8.255 - mean_eps: 0.117 - ale.lives: 2.277
#
# Interval 174 (4325000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0948
# 24 episodes - episode_reward: 97.292 [42.000, 126.000] - loss: 0.111 - mean_absolute_error: 7.222 - mean_q: 8.229 - mean_eps: 0.114 - ale.lives: 2.094
#
# Interval 175 (4350000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0942
# 25 episodes - episode_reward: 91.920 [46.000, 131.000] - loss: 0.108 - mean_absolute_error: 7.255 - mean_q: 8.267 - mean_eps: 0.112 - ale.lives: 2.205
#
# Interval 176 (4375000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0993
# 25 episodes - episode_reward: 101.600 [25.000, 139.000] - loss: 0.108 - mean_absolute_error: 7.246 - mean_q: 8.258 - mean_eps: 0.110 - ale.lives: 2.225
#
# Interval 177 (4400000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0948
# 23 episodes - episode_reward: 100.696 [67.000, 147.000] - loss: 0.104 - mean_absolute_error: 7.237 - mean_q: 8.245 - mean_eps: 0.108 - ale.lives: 2.164
#
# Interval 178 (4425000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0991
# 26 episodes - episode_reward: 96.385 [51.000, 126.000] - loss: 0.106 - mean_absolute_error: 7.231 - mean_q: 8.240 - mean_eps: 0.106 - ale.lives: 2.216
#
# Interval 179 (4450000 steps performed)
# 25000/25000 [==============================] - 367s 15ms/step - reward: 0.09420s - reward: 0.09
# 24 episodes - episode_reward: 97.875 [55.000, 135.000] - loss: 0.107 - mean_absolute_error: 7.254 - mean_q: 8.268 - mean_eps: 0.103 - ale.lives: 2.263
#
# Interval 180 (4475000 steps performed)
# 25000/25000 [==============================] - 365s 15ms/step - reward: 0.0949
# 24 episodes - episode_reward: 98.750 [52.000, 141.000] - loss: 0.100 - mean_absolute_error: 7.241 - mean_q: 8.252 - mean_eps: 0.101 - ale.lives: 2.200
#
# Interval 181 (4500000 steps performed)
# 25000/25000 [==============================] - 363s 15ms/step - reward: 0.0963
# 25 episodes - episode_reward: 96.600 [52.000, 132.000] - loss: 0.102 - mean_absolute_error: 7.261 - mean_q: 8.275 - mean_eps: 0.100 - ale.lives: 2.180
#
# Interval 182 (4525000 steps performed)
# 25000/25000 [==============================] - 361s 14ms/step - reward: 0.0979
# 25 episodes - episode_reward: 97.240 [56.000, 134.000] - loss: 0.106 - mean_absolute_error: 7.249 - mean_q: 8.262 - mean_eps: 0.100 - ale.lives: 2.153
#
# Interval 183 (4550000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0970
# 23 episodes - episode_reward: 107.870 [78.000, 143.000] - loss: 0.106 - mean_absolute_error: 7.244 - mean_q: 8.257 - mean_eps: 0.100 - ale.lives: 2.195
#
# Interval 184 (4575000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.1006
# 25 episodes - episode_reward: 102.400 [54.000, 139.000] - loss: 0.101 - mean_absolute_error: 7.274 - mean_q: 8.292 - mean_eps: 0.100 - ale.lives: 2.152
#
# Interval 185 (4600000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.0979
# 24 episodes - episode_reward: 99.167 [65.000, 129.000] - loss: 0.106 - mean_absolute_error: 7.304 - mean_q: 8.325 - mean_eps: 0.100 - ale.lives: 2.185
#
# Interval 186 (4625000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0984
# 24 episodes - episode_reward: 104.042 [74.000, 134.000] - loss: 0.105 - mean_absolute_error: 7.307 - mean_q: 8.325 - mean_eps: 0.100 - ale.lives: 2.142
#
# Interval 187 (4650000 steps performed)
# 25000/25000 [==============================] - 352s 14ms/step - reward: 0.0946
# 23 episodes - episode_reward: 102.739 [54.000, 129.000] - loss: 0.107 - mean_absolute_error: 7.276 - mean_q: 8.290 - mean_eps: 0.100 - ale.lives: 2.303
#
# Interval 188 (4675000 steps performed)
# 25000/25000 [==============================] - 353s 14ms/step - reward: 0.1027
# 25 episodes - episode_reward: 100.640 [63.000, 129.000] - loss: 0.106 - mean_absolute_error: 7.305 - mean_q: 8.323 - mean_eps: 0.100 - ale.lives: 2.224
#
# Interval 189 (4700000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0958
# 24 episodes - episode_reward: 100.750 [51.000, 144.000] - loss: 0.107 - mean_absolute_error: 7.263 - mean_q: 8.279 - mean_eps: 0.100 - ale.lives: 2.214
#
# Interval 190 (4725000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0943
# 22 episodes - episode_reward: 104.682 [74.000, 138.000] - loss: 0.108 - mean_absolute_error: 7.238 - mean_q: 8.250 - mean_eps: 0.100 - ale.lives: 2.153
#
# Interval 191 (4750000 steps performed)
# 25000/25000 [==============================] - 354s 14ms/step - reward: 0.0988
# 24 episodes - episode_reward: 103.375 [76.000, 124.000] - loss: 0.105 - mean_absolute_error: 7.234 - mean_q: 8.246 - mean_eps: 0.100 - ale.lives: 2.234
#
# Interval 192 (4775000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0999
# 25 episodes - episode_reward: 100.640 [56.000, 133.000] - loss: 0.102 - mean_absolute_error: 7.300 - mean_q: 8.320 - mean_eps: 0.100 - ale.lives: 2.254
#
# Interval 193 (4800000 steps performed)
# 25000/25000 [==============================] - ETA: 0s - reward: 0.100 - 361s 14ms/step - reward: 0.1001
# 24 episodes - episode_reward: 105.083 [63.000, 149.000] - loss: 0.105 - mean_absolute_error: 7.333 - mean_q: 8.357 - mean_eps: 0.100 - ale.lives: 2.286
#
# Interval 194 (4825000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0979
# 25 episodes - episode_reward: 98.320 [48.000, 128.000] - loss: 0.102 - mean_absolute_error: 7.347 - mean_q: 8.372 - mean_eps: 0.100 - ale.lives: 2.262
#
# Interval 195 (4850000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0962
# 25 episodes - episode_reward: 96.440 [23.000, 135.000] - loss: 0.106 - mean_absolute_error: 7.382 - mean_q: 8.413 - mean_eps: 0.100 - ale.lives: 2.239
#
# Interval 196 (4875000 steps performed)
# 25000/25000 [==============================] - 360s 14ms/step - reward: 0.0925
# 22 episodes - episode_reward: 102.818 [52.000, 148.000] - loss: 0.105 - mean_absolute_error: 7.425 - mean_q: 8.462 - mean_eps: 0.100 - ale.lives: 2.170
#
# Interval 197 (4900000 steps performed)
# 25000/25000 [==============================] - 357s 14ms/step - reward: 0.0901
# 21 episodes - episode_reward: 112.238 [69.000, 137.000] - loss: 0.109 - mean_absolute_error: 7.428 - mean_q: 8.466 - mean_eps: 0.100 - ale.lives: 2.114
#
# Interval 198 (4925000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0961
# 21 episodes - episode_reward: 107.667 [88.000, 143.000] - loss: 0.105 - mean_absolute_error: 7.410 - mean_q: 8.445 - mean_eps: 0.100 - ale.lives: 2.085
#
# Interval 199 (4950000 steps performed)
# 25000/25000 [==============================] - 358s 14ms/step - reward: 0.0979
# 24 episodes - episode_reward: 103.750 [74.000, 147.000] - loss: 0.108 - mean_absolute_error: 7.463 - mean_q: 8.505 - mean_eps: 0.100 - ale.lives: 2.178
#
# Interval 200 (4975000 steps performed)
# 25000/25000 [==============================] - 359s 14ms/step - reward: 0.0965
# done, took 69157.724 seconds
# Testing for 10 episodes ...
# Episode 1: reward: 87.000, steps: 800
# Episode 2: reward: 106.000, steps: 1111
# Episode 3: reward: 81.000, steps: 1152
# Episode 4: reward: 68.000, steps: 903
# Episode 5: reward: 89.000, steps: 769
# Episode 6: reward: 130.000, steps: 1344
# Episode 7: reward: 99.000, steps: 1077
# Episode 8: reward: 64.000, steps: 795
# Episode 9: reward: 100.000, steps: 1065
# Episode 10: reward: 80.000, steps: 912

# %%
#Training Plot

plt.plot(history.history['episode_reward'])
plt.title('DQN Performance')
plt.ylabel('Reward')
plt.xlabel('Episode')
plt.show()

# %%
#Test
#Atari Testing Processor (Change Reward Metric)
class AtariProcessor_test(Processor):
    
    def process_observation(self, observation):
        # Crop
        img = observation[1:176:2, ::2]
        # Convert the image to greyscale
        img = np.dot(img[...,:3], [0.299, 0.587, 0.144])
        # Resize
        img = img.reshape(INPUT_SHAPE)
        return img.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return reward

weights_filename = 'dqn_{}_weights.h5f'.format(ENV_NAME)

processor = AtariProcessor_test()
dqn = DQNAgent(model=model, nb_actions=n_actions, policy=policy, memory=memory, processor=processor, nb_steps_warmup=start_steps, 
               gamma=discount_factor, target_model_update=batch,train_interval=steps_train, delta_clip=1.)
dqn.compile(Adam(lr=learning_rate), metrics=['mae'])


dqn.load_weights(weights_filename)
history2 = dqn.test(env, nb_episodes=100, visualize=False)
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 1300.000, steps: 979
# Episode 2: reward: 1880.000, steps: 1147
# Episode 3: reward: 1350.000, steps: 1051
# Episode 4: reward: 1210.000, steps: 912
# Episode 5: reward: 1580.000, steps: 1098
# Episode 6: reward: 1510.000, steps: 1147
# Episode 7: reward: 1410.000, steps: 977
# Episode 8: reward: 1230.000, steps: 814
# Episode 9: reward: 930.000, steps: 723
# Episode 10: reward: 1310.000, steps: 853
# Episode 11: reward: 1440.000, steps: 1049
# Episode 12: reward: 1650.000, steps: 1133
# Episode 13: reward: 1720.000, steps: 869
# Episode 14: reward: 1420.000, steps: 952
# Episode 15: reward: 850.000, steps: 702
# Episode 16: reward: 1190.000, steps: 1106
# Episode 17: reward: 1730.000, steps: 1133
# Episode 18: reward: 1280.000, steps: 1023
# Episode 19: reward: 1320.000, steps: 852
# Episode 20: reward: 1370.000, steps: 856
# Episode 21: reward: 1280.000, steps: 934
# Episode 22: reward: 1700.000, steps: 1303
# Episode 23: reward: 1890.000, steps: 1242
# Episode 24: reward: 1600.000, steps: 1079
# Episode 25: reward: 1440.000, steps: 1346
# Episode 26: reward: 1340.000, steps: 832
# Episode 27: reward: 1170.000, steps: 737
# Episode 28: reward: 1450.000, steps: 1151
# Episode 29: reward: 1390.000, steps: 889
# Episode 30: reward: 1140.000, steps: 839
# Episode 31: reward: 1280.000, steps: 1048
# Episode 32: reward: 1730.000, steps: 1550
# Episode 33: reward: 1100.000, steps: 862
# Episode 34: reward: 1360.000, steps: 879
# Episode 35: reward: 840.000, steps: 781
# Episode 36: reward: 1370.000, steps: 946
# Episode 37: reward: 1590.000, steps: 1154
# Episode 38: reward: 1540.000, steps: 1242
# Episode 39: reward: 1500.000, steps: 1351
# Episode 40: reward: 1200.000, steps: 1026
# Episode 41: reward: 1540.000, steps: 1103
# Episode 42: reward: 1220.000, steps: 1030
# Episode 43: reward: 690.000, steps: 798
# Episode 44: reward: 1480.000, steps: 1243
# Episode 45: reward: 1140.000, steps: 973
# Episode 46: reward: 1220.000, steps: 871
# Episode 47: reward: 1250.000, steps: 1012
# Episode 48: reward: 1530.000, steps: 922
# Episode 49: reward: 1180.000, steps: 854
# Episode 50: reward: 1250.000, steps: 914
# Episode 51: reward: 1680.000, steps: 1344
# Episode 52: reward: 2010.000, steps: 1093
# Episode 53: reward: 1620.000, steps: 1132
# Episode 54: reward: 840.000, steps: 891
# Episode 55: reward: 1170.000, steps: 753
# Episode 56: reward: 1120.000, steps: 722
# Episode 57: reward: 1840.000, steps: 1177
# Episode 58: reward: 1700.000, steps: 1210
# Episode 59: reward: 1340.000, steps: 1113
# Episode 60: reward: 1450.000, steps: 1146
# Episode 61: reward: 1170.000, steps: 913
# Episode 62: reward: 1420.000, steps: 1376
# Episode 63: reward: 1710.000, steps: 1323
# Episode 64: reward: 1150.000, steps: 1176
# Episode 65: reward: 2120.000, steps: 1283
# Episode 66: reward: 1170.000, steps: 1070
# Episode 67: reward: 1390.000, steps: 1017
# Episode 68: reward: 1320.000, steps: 1155
# Episode 69: reward: 1660.000, steps: 1414
# Episode 70: reward: 1290.000, steps: 1258
# Episode 71: reward: 1310.000, steps: 880
# Episode 72: reward: 1970.000, steps: 1120
# Episode 73: reward: 1040.000, steps: 729
# Episode 74: reward: 1050.000, steps: 855
# Episode 75: reward: 1820.000, steps: 1073
# Episode 76: reward: 1530.000, steps: 1313
# Episode 77: reward: 1420.000, steps: 1072
# Episode 78: reward: 1070.000, steps: 820
# Episode 79: reward: 1280.000, steps: 1191
# Episode 80: reward: 1560.000, steps: 1155
# Episode 81: reward: 1640.000, steps: 1031
# Episode 82: reward: 1890.000, steps: 983
# Episode 83: reward: 1370.000, steps: 1159
# Episode 84: reward: 1270.000, steps: 949
# Episode 85: reward: 1850.000, steps: 1116
# Episode 86: reward: 1260.000, steps: 902
# Episode 87: reward: 1620.000, steps: 1223
# Episode 88: reward: 1400.000, steps: 951
# Episode 89: reward: 1400.000, steps: 1047
# Episode 90: reward: 1730.000, steps: 1122
# Episode 91: reward: 1230.000, steps: 960
# Episode 92: reward: 1070.000, steps: 874
# Episode 93: reward: 1100.000, steps: 786
# Episode 94: reward: 1930.000, steps: 1001
# Episode 95: reward: 1250.000, steps: 748
# Episode 96: reward: 1680.000, steps: 1063
# Episode 97: reward: 1260.000, steps: 987
# Episode 98: reward: 1450.000, steps: 1100
# Episode 99: reward: 1080.000, steps: 739
# Episode 100: reward: 1060.000, steps: 1167

# %%
import statistics 

#Testing Plot
plt.plot(history2.history['episode_reward'])
plt.title('DQN Gameplay Performance')
plt.ylabel('Score')
plt.xlabel('Episode')
plt.show()

print("Average Score: ", statistics.mean(history2.history['episode_reward']))
print("Standard Deviation: ", statistics.stdev(history2.history['episode_reward']))
print("Average Steps Taken Per Episode: ", statistics.mean(history2.history['nb_steps']))
# Out:
# Average Score:  1398.5
# Standard Deviation:  279.27168987864985
# Average Steps Taken Per Episode:  1029.69
